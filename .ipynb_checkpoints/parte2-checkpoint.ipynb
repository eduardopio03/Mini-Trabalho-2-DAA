# %% [markdown]
# # Minitrabalho 2 – "Seis graus de separação"

# %% [markdown]
# ## 1) Representação dos dados

# %% [markdown]
# ##### A tarefa inicial consiste em ler e carregar os dados numa estrutura de dados adequada. Isto implica, essencialmente, em concetualizar a relação ator-filme como um grafo.
# ##### Para a sua implementação, deverá usar como base a classe Graph/Digraph fornecida nos exercícios da Semana 7, ou deve implementar a sua classe Graph de raiz. Não é permitida a utilização de outros módulos Python para a representação de grafos.
# ##### Com base no conjunto de operações que devem ser suportadas pela sua aplicação (apresentadas na Secção 2), descreva nesta secção os detalhes da estrutura de dados escolhida e o tipo de grafo resultante da sua interpretação do problema. Note que não existe apenas uma "única" representação possível, mas algumas representações podem ser mais/menos eficientes e mais fáceis/difíceis de programar. Você, como desenvolvedor, deve analisar qual será a melhor solução para o problema, mantê-la consistente e fazê-la funcionar.

# %%
import random as rnd
from operator import attrgetter
from collections import deque

# %%
# Class Vertice
class Vertex:
    ''' Estrutura de Vértice para um grafo: encapsula um elemento que é o identificador deste nó.
        O elemento deve ser hashable:
        - Um objeto hashable é aquele que pode ser utilizado como uma chave num dicionário Python.
        - Isto inclui strings, números, tuplas, etc.
    '''

    def __init__(self, x, type):
        self._elemento = x
        self._type = type  # 'actor' or 'movie'

    def get_type(self):
        return self._type

    def __hash__(self):
        ''' o valor do elemento é usado como hash para o vértice (o elemento deve ser hashable)'''
        return hash(self._elemento)  # devolve o hash do elemento

    def __str__(self):
        '''Devolve a representação do objeto vértice em string.'''
        return'{0}'.format(self._elemento)

    def __eq__(self, x):
        return x == self._elemento # Deve-se garantir que: se hash(x)==hash(elemento), entao x==elemento

    def vertice(self):
        '''Devolve o elemento guardado neste vértice'''
        return self._elemento


# #### Class Edge
class Edge:
    '''Estrutura de Aresta para um Grafo: (origem, destino)'''

    #! Como é um grafo não pesaddo, nao é necessário pesos
    def __init__(self, u, v):
        self._vertex1 = u   #! vértice origem
        self._vertex2 = v   #! vértice destino

    def __hash__(self):
        # Função que mapeia a aresta a uma posição no dicionário (hash map)
        return hash((self._vertex1, self._vertex2))

    def __str__(self):
        '''Devolve a representação do objeto aresta em string: (origem, destino)'''
        #! Peso retirado
        return'({0},{1})'.format(self._vertex1, self._vertex2)

    def __eq__(self, other):
        # define igualdade de duas arestas (deve ser consistente com a função hash)
        return self._vertex1 == other._vertex1 and self._vertex2 == other._vertex2

    def endpoints(self):
        '''Devolve a tupla (u,v) que indica os vértices antecessor e sucessor.'''
        return (self._vertex1, self._vertex2)

    #! Método do custo retirado

    #! Método showEgde retirado

    # métodos novas
    def get_ant(self):
        return self._vertex1

    def get_suc(self):
        return self._vertex2

    def opposite(self, v):
        '''Indica o vértice oposto ao v neste arco; v tem de ser um dos vértices.'''
        return self._vertex2 if v is self._vertex1 else self._vertex1

# %%
class Graph:
    '''
    Representação de um grafo usando dicionários encadeados (nested dictionaries).

    Atributos:
    ----------
    vertices: Dicionário exterior que associa um vértice (Vertex) a um mapa de adjacências (dicionario)
    n: Número de vértices no Grafo
    m: Número de arestas no Grafo
    ----------
'''

    def __init__(self, directed=False):
        '''Construtor: Cria um grafo vazio (dicionário de _vertices).'''
        self._vertices = {}         # dicionário com chave vértice e valor mapa de adjacência
        self._n = 0                 # número de vértices do grafo
        self._m = 0                 # número de arestas do grafo
        self._directed = directed

      
    def _incident_edges(self, v):
        '''Gerador: devolve todas as arestas de um vértice v.'''
        for edge in self._vertices[v].values(): # para todas as arestas incidentes em v:
            yield edge
    
    def __str__(self):
        if self._n == 0:
            ret = "DAA-Graph: <empty>\n"
        else:
            ret = "DAA-Graph:\n"
            for v in self._vertices.keys():
                ret += "vertex "
                ret += str(v) + ": "
                for edge in self._incident_edges(v):
                    ret += str(edge) + "; "
                ret += "\n"
        return ret

    #! Método is_directed retirado

    def order(self):
        '''Ordem de um grafo: a quantidade de vértices no Grafo'''
        return self._n

    def size(self):
        '''Dimensão de um grafo: a quantidade total de arestas do Grafo'''
        return self._m

    def has_node(self, v):
        """Verifica se o vértice v está no grafo."""
        return v in self._vertices

    def has_edge(self, u, v):
        if not self.has_node(u) or not self.has_node(v):
            return False
        else:
            return Vertex(v, 'actor') in self._vertices[Vertex(u, 'actor')].keys() or Vertex(v, 'movie') in self._vertices[Vertex(u, 'movie')].keys()


    def insert_vertex(self, x, type):
        '''Insere e devolve um novo vértice com o elemento x e o tipo type'''
        v = Vertex(x, type)
        self._vertices[v] = {}      # inicializa o dicionário de adjacências deste vértice a vazio
        self._n +=1                 # mais um vértice no grafo
        return v


    #! Peso da aresta retirado
    def insert_edge(self, u, v):
        ''' Cria e insere uma nova aresta entre u e v.
            Se a aresta já existe no grafo, atualiza-se o seu filme. '''
        e = Edge(u, v)

        if not self.has_node(u):
            self.insert_vertex(u)
        if not self.has_node(v):
            self.insert_vertex(v)
        if not self.has_edge(u, v):
            self._m +=1           # atualiza m apenas se a aresta ainda não existir no grafo

        self._vertices[u][v] = e  # coloca v nas adjacências de u
        self._vertices[v][u] = e  # e u nas adjacências de v (para facilitar a procura de todas as arestas incidentes num vértice)



    def degree(self, v, outgoing=True):
        '''Quantidade de arestas originárias ou incidentes no vértice v
           Se for um grafo dirigido, conta as arestas outgoing ou incoming,         #! alterar pois nao é dirigido  
           de acordo com o valor de outgoing (True or False)
        '''
        adj = self._vertices
        if not self._directed:
            count = len(adj[v])
        else:
            count = 0
            for edge in adj[v].values():
                x, y = edge.endpoints()
                if (outgoing and x == v) or (not outgoing and y == v):
                    count += 1
        return count

    def get_edge(self, u, v):
        '''Método interno: Devolve a aresta que liga u a v ou None se não forem adjacentes'''
        edge = self._vertices[u].get(v)     # returns None se não existir aresta entre u e v
        if edge and self._directed: # se é dirigido
            x = edge.endpoints()        # vai confirmar se é o arco u --> v
            if x[1] != v:
                edge = None
        return edge

    def vertices(self):
        '''Devolve um iterável sobre todos os vértices do Grafo'''
        return self._vertices.keys()

    def edges(self):
        '''Devolve o conjunto (set) de todas as arestas do Grafo'''
        result = set()      # avoid double-reporting edges in undirected graph
        for secondary_map in self._vertices.values():
            result.update(secondary_map.values())  # add edges to resulting set
        return list(result)

    def remove_vertex(self, v):
        '''remove o vértice v. Se o vertice não existir, não faz nada.'''
        # remover todas as arestas de [v]
        # remover todas as arestas com v noutros vertices
        # remover o vértice v
        if v in self._vertices.keys():
            lst = [i for i in self.incident_edges(v)]
            for i in lst:
                x, y = i.endpoints()
                self.remove_edge(x,y)
            del self._vertices[v]
            self._n -=1

    def remove_edge(self, u, v):
        '''Remove a aresta entre u e v. Se a aresta não existir, não faz nada.'''
        if  u in self._vertices.keys() and v in self._vertices[u].keys():
            del self._vertices[u][v]
            del self._vertices[v][u]
            self._m -=1

    def has_neighbors(self, v):
        if self.incident_edges(v) != None:
            return True
        else:
            return False

    def incident_edges(self, v, incoming=True):
        '''Gerador: indica todas as arestas incoming de v
           Se for um grafo dirigido e incoming for False, devolve as arestas outgoing
        '''
        for edge in self._vertices[v].values(): # para todas as arestas relativas a v:
            if not self._directed:
                    yield edge
            else:  # senão deve ir procurar em todas as arestas para saber quais entram ou saiem
                x, y = edge.endpoints()
                if (incoming and y == v) or (not incoming and x == v):
                    yield edge

    def get_neighbors(self, v):
        '''Retorna uma lista dos vizinhos do vértice v.'''
        neighbors = []
        for edge in self.incident_edges(v):
            # Para cada aresta incidente no vértice v, adiciona o vértice oposto à lista de vizinhos
            neighbors.append(edge.opposite(v))
        return neighbors

    def is_successor(self, v, x):
        for edge in self.incident_edges(v):
            if edge.get_ant() == x:
                return True
        return False

    def is_predecessor(self, u, v):
      for edge in self.incident_edges(u):
          if edge.get_ant() == v:
              return True
      return False


    def printG(self):
        '''Mostra o grafo por linhas'''
        if self._n == 0:
            print('O grafo está vazio!')
        else:
            print('Grafo orientado:', self._directed)
            for v in self.vertices():
                print('\nvertex ', v, ' grau_in: ', self.degree(v,False), end=' ')# mostra o grau (de saída se orientado)
                for i in self.incident_edges(v):
                    print(' ', i, end=' ')
                if self._directed:          # se orientado, mostrar o grau de saida
                    print('\n \t   grau_out: ', self.degree(v, True), end=' ')
                    for i in self.incident_edges(v, False):    # e mostrar os arcos de saída
                        print(' ', i, end=' ')

    def shortest_path(self, start, end):
        '''Devolve o caminho mais curto entre os vértices start e end usando BFS'''
        queue = deque([(start, [start])])  # fila para BFS, contém tuplas de vértice e caminho
        visited = set([start])  # conjunto de vértices visitados

        while queue:
            (vertex, path) = queue.popleft()  # remove o próximo vértice e caminho da fila
            for neighbor in self.get_neighbors(vertex):  # itera sobre os vizinhos do vértice
                if neighbor not in visited:  # se o vizinho não foi visitado
                    if neighbor == end:  # se o vizinho é o vértice final
                        return path + [end]  # devolve o caminho atual mais o vértice final
                    visited.add(neighbor)  # marca o vizinho como visitado
                    queue.append((neighbor, path + [neighbor]))  # adiciona o vizinho e o novo caminho à fila

        return None  # se não houver caminho entre start e end, devolve None

# %% [markdown]
# ##### 1.a) [2 valores] Descreva o modelo de grafo que utilizou para concetualizar a relação ator-filme do problema proposto. Liste quais foram os critérios que levaram à sua decisão e as possíveis vantagens e desvantagens da representação usada.
# Nota: São listadas abaixo algumas perguntas que devem estar claras na sua resposta:
#
#         • O que são os vértices e as arestas no seu modelo de grafo. Qual foi o critério para esta escolha? Por exemplo, a sua escolha facilita a implementação de alguma operação específica? Ou faz com que as operações fiquem mais eficientes (em relação ao tempo e ao espaço em memória)?
#
#         • A sua representação do problema resulta em que tipo de grafo (não orientado, orientado, pesado, com multiarestas, acíclico, cíclico, bipartido, etc)?
#
#         • Que tipo de modificações teve de realizar na classe Graph fornecida (teve de inserir novos atributos/métodos e porquê?); ou como implementou a sua classe Graph?

# %% [markdown]
# ***Resposta:***
#
# * ***Vértices: Os vértices do grafo podem ser atores e filmes sendo que cada ator corresponde a um único vértice no grafo, tal como cada filme.***
#
# * ***Arestas: As arestas podem representar a relação entre dois atores que atuaram num mesmo filme, isto é, se dois atores participaram no mesmo filme, há uma aresta entre eles. Além disso, as arestas guardam os filmes em que os atores co-atuaram***
#
# * ***Tipo de grafo: O grafo resultante é um grafo não orientado e não pesado. É não orientado porque a relação de participação é não é direcional - se o ator A atuou num filme B, então num filme B também atuou o ator A. É não pesado porque todas as arestas têm o mesmo peso - a participação num filme.***
#
# * ***Modificações na classe Graph: Há a necessidade de adicionar um método que calcule o caminho mais próximo entre dois vértices, que será útil para determinar o "número de Bacon" de um ator. Além disso, devemos adicionar um método para obter todos os vértices adjacentes a um vértice em específico, o que é útil quando há necessidade de explorar o grafo.***

# %% [markdown]
# ##### 1.b) [1,5 valores] Implemente uma função auxiliar que irá construir um grafo (do tipo Graph implementado) a partir dos dados de um ficheiro .txt fornecido. A função deve receber como argumento o nome do ficheiro e devolver um objeto do tipo Graph.
# Nota 1: Cada linha do ficheiro fornecido apresenta o nome de um filme seguido de uma lista dos atores
# que participaram no filme. Para separar os nomes que aparecem numa linha, o caracter '/' é utilizado
# como delimitador.
#
# Harry Potter and the Chamber of Secrets (2002)/Davis, Warwick (I)/Knight, Tom (I)/…
#
# Harry Potter and the Goblet of Fire (2005)/Gambon, Michael/Claydon, Steve (II)/…
#
# Harry Potter and the Prisoner of Azkaban (2004)/Phelps, James (I)/Murray, Devon/…
#
# …
#
# São anexadas duas bases de dados ao enunciado do projeto:
#
#     • small_dataset.txt: Contém a lista de filmes classificados no IMBD em 2011: 4.527 filmes e 122.406 atores (~3,5MB). Deve ser utilizada para realizar testes enquanto implementa a sua API.
#
#     • large_dataset.txt: Contém todos os filmes do IMBD em 2011: 285.460 filmes e 933.864 atores (~60MB). Deve ser usada para gerar os resultados dos testes definidos na Secção 3. Note que, para conseguir testar com esta base de dados, terá de ter disponível um espaço de memória RAM suficiente, uma vez que o grafo irá ser todo carregado para a memória.
#
# Nota 2: Se achar mais fácil ter esta função implementada na classe HollywoodOracle (Secção 2), é livre
# de o fazer.

# %%
from collections import deque

def build_graph_from_file(filename):
    # Cria um grafo vazio
    graph = Graph()

    # Abre o arquivo para leitura
    with open(filename, 'r', encoding='utf-8') as file:
        # Lê cada linha do arquivo
        for line in file:
            # Divide a linha em filme e lista de atores
            movie, *actors = line.strip().split('/')
            print(movie, actors)
            
            # Verifica se o filme já existe no grafo, se não, insere
            if not graph.has_node(movie):
                graph.insert_vertex(movie, 'movie')

            # Para cada ator, insere um vértice e uma aresta entre o ator e o filme
            for actor in actors:
                # Verifica se o ator já existe no grafo, se não, insere
                if not graph.has_node(actor):
                    graph.insert_vertex(actor, 'actor')
                
                # Insere a aresta entre o ator e o filme
                graph.insert_edge(actor, movie)

    return graph

# %%
#Test build_graph_from_file
graph = build_graph_from_file('small_dataset_utf8.txt')
# Out:
# 'Breaker' Morant (1980) ['Fitz-Gerald, Lewis', 'Steele, Rob (I)', 'Wilson, Frank (II)', "Tingwell, Charles 'Bud'", 'Cassell, Alan (I)', 'Rodger, Ron', 'Knez, Bruno', 'Woodward, Edward', 'Cisse, Halifa', 'Quin, Don', 'Kiefel, Russell', 'Meagher, Ray', 'Procanin, Michael', 'Bernard, Hank', 'Gray, Ian (I)', 'Brown, Bryan (I)', 'Ball, Ray (I)', 'Mullinar, Rod', 'Donovan, Terence (I)', 'Ball, Vincent (I)', 'Pfitzner, John', 'Currer, Norman', 'Thompson, Jack (I)', 'Nicholls, Jon', 'Haywood, Chris (I)', 'Smith, Chris (I)', 'Mann, Trevor (I)', 'Henderson, Dick (II)', 'Lovett, Alan', 'Bell, Wayne (I)', 'Waters, John (III)', 'Osborn, Peter', 'Peterson, Ron', 'Cornish, Bridget', 'Horseman, Sylvia', 'Seidel, Nellie', 'West, Barbara', 'Radford, Elspeth', 'Reed, Maria', 'Erskine, Ria', 'Dick, Judy', 'Walton, Laurie (I)']
# 'burbs, The (1989) ['Gage, Kevin', 'Hahn, Archie', 'Feldman, Corey', 'Gordon, Gale', 'Drier, Moosie', 'Theodore, Brother', 'Katt, Nicky', 'Miller, Dick (I)', 'Hanks, Tom', 'Dern, Bruce', 'Turner, Arnold F.', 'Howard, Rance', 'Ducommun, Rick', 'Danziger, Cory', 'Ajaye, Franklyn', 'Scott, Carey', 'Kramer, Jeffrey (I)', 'Olsen, Dana (I)', 'Gains, Courtney', 'Picardo, Robert', 'Hays, Gary', 'Davis, Sonny Carl', 'Gibson, Henry (I)', 'Jayne, Billy', 'Stevenson, Bill (I)', 'Katz, Phyllis', 'Vorgan, Gigi', 'Darbo, Patrika', 'Schaal, Wendy', 'French, Leigh', 'Fisher, Carrie', 'Benner, Brenda', 'Newman, Tracy (I)', 'Stewart, Lynne Marie', 'Haase, Heather (I)']
# 'Crocodile' Dundee II (1988) ['Carrasco, Carlos', 'Folger, Mark', 'Guzmán, Luis (I)', 'Ramsey, John (I)', 'Spindell, Ahvi', 'Creighton, Rhett', 'Shams, Homay', 'Yamamoto, Ronald', 'Asai, Hisayo', 'Serbagi, Roger', 'Skilton, Gerry', 'Skinner, Doug', 'Boutsikaris, Dennis', 'Crivello, Anthony (I)', 'Arvanites, Steven', 'Jbara, Gregory', 'Holt, Jim (I)', 'Vasquez, Alberto (I)', 'Batten, Tom (I)', 'Rios, Julio', 'Wilson, Alec', 'Jerosa, Vincent', 'Mercurio, Gus', 'Arriaga, Luis', 'Segura, Fernando', 'Dingo, Ernie', 'Sandy, Bill', 'Hogan, Paul (I)', 'Ruiz, Anthony (I)', 'Andrews, Jose', 'Alexander, Jace', 'Ubarry, Hechter', 'Cooper, Jim (I)', 'Soriero, Jim', 'Cooper, Sam (I)', 'Fernández, Juan (I)', 'Rackman, Steve', 'Meillon, John', 'Krivak, Bryan', 'Dutton, Charles S.', 'Saunders, Mark (I)', 'Maldonado, Edwin', 'Yasuda, Doug', 'Root, Stephen (I)', 'Cerullo, Al', 'Welsh, Kenneth', 'Quinn, Colin', 'Essman, Susie', 'Castle, Angela', 'Cox, Hannah', 'Blinco, Maggie', 'Lane, Rita', 'Sokol, Marilyn', 'Crittenden, Dianne', 'Kozlowski, Linda', 'Rockafellow, Stacey', 'Ali, Tatyana', 'Rogers, Maria Antoinette', 'Bobbit, Betty']
# (T)Raumschiff Surprise - Periode 1 (2004) ['Danner, Olaf', 'Queck, Maverick', 'Lesotho, Albee', 'Herbig, Michael', 'Dumont, Sky', 'Herbst, Christoph Maria', 'Terpoorten, Sigi', 'Hallwachs, Hans Peter', 'Grap, Klaus-Peter', 'Wolf, Thorsten', 'Gladhart, Eric', 'Trotman-Harewood, Errol', 'Van Ulzen, Herman', 'Silbermann, Hans-Jürgen', 'Schreiner, Jumbo', 'Bischoff, Marc', 'Sikder, Stephen', 'Schöne, Reiner', 'Figl, Anton', 'Jones, Sirone', 'Geier, Conrad F.', 'H2O2', 'Kobus, Waldemar', 'Tramitz, Christian', 'Rigauer, Gerd', 'Schweiger, Til', 'Rossié, Michael', 'Kavanian, Rick', 'Wilde, Tim', 'Rehberg, Hans-Michael', 'Seifert, Andreas', 'Herold, Diana', 'Bartholomäus, Heidrun', 'Beyeler, Brigitte', 'Schubert, Edeltraud', 'Widmer, Stacia', 'Kling, Anja']
# *batteries not included (1987) ['Vasquez, David (I)', 'Schwary, Ronald L.', 'Renensland, Howard', 'Arceri, John', 'Boutsikaris, Dennis', 'Carmine, Michael (II)', 'Guzmán, Luis (I)', 'Santana, José Angel', 'Raymond, Charles (II)', 'Pankow, John', 'Aldredge, Tom', 'Cronyn, Hume', 'Kurtz, Shelly (I)', 'LeGros, James', 'Martinsen, Dick', 'DiSanti, John', 'Hamer, Joe', 'Colon, Riki', 'Greene, Michael (I)', 'Dixon, MacIntyre', 'Imparato, Jon', 'Dear, H. Clay', 'McRae, Frank', 'Shoffner, Susan', 'Belack, Doris', 'Grafe, Judy', 'Hoffman, Jane (I)', 'Beardsley, Alice', 'Schaal, Wendy', 'Peña, Elizabeth', 'Tandy, Jessica']
# ...And Justice for All (1979) ['Blackmore, Stephen', 'Zwerling, Darrell', 'Christian, Robert', 'Forsythe, John (I)', 'Bogazianos, Vasili', 'Clute, Sidney', 'Sliwka, Frank', 'Gorrin, Michael', 'Bryggman, Larry', 'Pistilli, Carl', 'North, Alan', 'Currier, Terrence', 'Tambor, Jeffrey', 'Aquino, John (I)', 'Duncan, Angus', 'Hollander, Jack', 'Quinn, Tom (II)', 'Scott, Newton', 'Symonds, Robert', 'Saiontz, Donald', 'Levene, Sam (I)', 'Davy, Walter (II)', 'Andes, Keith', 'Patterson, Kenneth (I)', 'Warden, Jack', 'Beck, Vincent', 'Williams, Jonathan (XI)', 'Polk, Bill (I)', 'Strasberg, Lee', 'Waites, Thomas G.', 'Siebert, Charles (I)', 'Harris, Baxter', 'Haymer, Johnny', 'Pacino, Al', 'Morton, Joe', 'Arnold, Victor (II)', 'Dunbar, Julius', 'Nelson, Craig T.', 'Hawkins, McLindsey', 'Chianese, Dominic', 'Hertzler, J.G.', 'Cartwright, Bonita', 'Sanders, Beverly', 'Wooten, Terri', 'Kohler, Molly', 'Sawyer, Connie (I)', 'Lahti, Christine', 'Council, Allisha', 'Forbes, Angelyn', 'Schurr, Cathleen', 'Fredricks, Rita']
# 10 (1979) ['Anderson, Adam (I)', 'Hawker, John (I)', 'Calfa, Don', 'Carr, Laurence', 'Noble, James (I)', 'Hancock, John (I)', 'Sullivan, Owen (I)', 'Chase, Gregory', 'Jones, Sam J. (I)', 'Chappell, John (I)', 'Colombatto, S. (I)', 'Byrnes, Burke', 'Webber, Robert (I)', 'Kassul, Art', 'Dennehy, Brian', 'Moore, Dudley', 'Goldman, Lorry', 'Sheehan, Doug', 'Daly, Rad', 'Tanney, Herb', 'Showalter, Max', 'López, J. Víctor', 'Alton, Walter George', 'Champion, Michael', 'Lucking, William', 'Linton, Jon', 'Rosenberg, Arthur', 'Le May, Dorothy', 'White, Debbie (I)', 'Aron, Adrian', 'Derek, Bo', 'Farrell, Lynn', 'Andrews, Julie (I)', 'Wallace, Dee (II)', 'Bowman, Gail', 'Arnette, Jeanetta', 'Gorman, Mari', 'Chess, Lisa', 'Rush, Deborah', 'DeCarlo, Kitty', 'Cassidy, Sheila', 'Ashland, Camila', 'Serena (I)', 'Crosby, Denise', 'Zak, Sherri', 'Volz, Nedra', 'Royale, Candida', 'Alter, Julie', 'Haven, Annette', 'Galardo, Yolanda', 'Hanson, Marcy', 'Clark, Ellen', 'Ellis, Antonia (I)', 'Money, Constance', 'Kiser, Virginia', 'Farren, Vivian']
# 10 Things I Hate About You (1999) ['Kennedy, Aidan', 'Inglis, Joster', 'Ledger, Heath', 'Mosley, Dennis', 'Therol, Aaron', 'Karczag, Ari', 'Thorpe, Joshua', 'Hood, Brian', 'Gordon-Levitt, Joseph', 'Jackson, Greg (II)', 'Brown, Nick (IV)', 'Johnson, J.R.', 'Fraser, Cameron (I)', 'Bennett, Tim (III)', 'Mashburn, Brian', 'Junger, Gil', 'Eisenstein, Michael (II)', 'Cease, Kyle', 'Butler, Todd', 'Dyer, Jesse', 'Laurance, Benjamin', 'Muller, Travis', 'Kountz, Daniel', 'Kimbrough, Demegio', 'Riedmann, Eric (I)', 'Vukelic, Nick', 'Lacamara, Carlos', 'Houston, Tarance', 'Keegan, Andrew', 'Krumholtz, David', 'Maixner, Quinn', 'Miller, Larry (I)', 'Mitchell, Daryl', 'Leisure, David', 'Taylor, Heather (I)', 'Stiles, Julia', 'Evans, Alice (II)', 'Quinn, Jelani', 'Union, Gabrielle', 'Kajlich, Bianca', 'Powell, Monique', 'Gottlieb, Wendy', 'Janney, Allison', 'Kenny, Laura', "O'Neill, Bridget (III)", 'Oleynik, Larisa', 'Hanley, Kay', 'Pratt, Susan May', 'Mackay, Alisa', 'Matthews, Amber']
# 100 Girls (2000) ['Green, Johnny (V)', 'Michael, Terence (I)', 'Green, Donald (II)', 'Bleiberg, Ehud', 'Courtney, Dustin', 'Szmanda, Eric', 'Tucker, Jonathan (I)', 'Bustard, Chris', 'Howard, Walker', 'Nagel, Seth', 'Davila, Edward', "O'Hara, John (VIII)", 'Ross, Bradley K.', 'Corpas, Londonn', 'Madalone, Dennis', 'Payne, Allen (II)', 'DeBello, James', 'McNet, Mike', 'Herold, Kristin', 'Chriqui, Emmanuelle', 'Marina, Anya', 'Krinsky, Tamara Lee', 'Angelini, Josephine', 'Patterson, Deenah', 'Bozilovic, Ivana', 'Elahna, Sonnie', 'Farrokh, Farinaz', 'Grant, Tanisha', 'Lindquist, Kerstin', 'Hiraizumi, Gina', 'Rey, Adrienne', 'Rullo, Cynthia', 'Hoover, Danielle', 'Houston, Holly', 'James, Susan (II)', 'Billman, Ange', 'Ramos, Stephanie', 'Ribisi, Marissa', 'Thomas, Anita', 'Oleynik, Larisa', 'Mercedes, Alley', 'Blair, Joan (III)', 'Castro, Lydia', 'Mars, Felicity', 'Pho, Lon', 'Brandon, Madison', 'Gonzalez, Esther (I)', 'Heigl, Katherine', 'Anderson, Lorie Katherine', 'Evangelisti, Noel', 'Musiala, Agnieszka', 'Ortiz, Dorlinda', 'Mars, Rainbeau', 'Filipovic, Biljana', 'Steger, Julieanne', 'Huarte, Monica', 'Fioretta, Amy', 'Graham, Aimee', 'Tyranny, Tanya', 'Carmichael, Sarah', 'Pressly, Jaime', 'Fried, Cindy', 'Khomute, Anna', 'Anapau, Kristina', 'Walters, Nancy (II)', 'Clough, Patty', 'McLaren, Reilly', 'Gray, Laura', 'Severson, Candra', 'Kwon, Crystal', 'Strain, Maria', 'Reeves, Kimberly']
# 101 Dalmatians (1996) ['Peters, John (I)', 'Paris, Gerald', 'Haddigan, Mark', 'Shrapnel, John', 'McInnerny, Tim', 'Daniels, Jeff (I)', 'Fraser, Hugh (I)', 'Williams, Mark (I)', 'Percival, Michael (I)', 'Benfield, John', 'Mullard, Arthur', 'Capron, Brian', 'Lacey, Joe', 'Evans, John (II)', 'Laurie, Hugh', 'Readman, Andrew', 'Phillips, Neville', 'Weiss, Zohren', 'Stewart, Bill (I)', 'Welker, Frank', 'Braid, Hilda', 'Mason, Margery', 'Richardson, Joely', 'Close, Glenn', 'Plowright, Joan']
# 101 Reykjavík (2000) ['Ólafsson, Ólafur Darri', 'Einarsson, Pétur (I)', 'Guðjónsson, Bjarki', 'Sigurðsson, Atli Rafn', 'Sigurðarson, Jóhann', 'Valsson, Konráð', 'Jonsson, Hilmar', 'Sigurbjörnsson, Sigurður Pálmi', 'Egilsson, Agnar Jón', 'Þorvaldsson, Guðmundur Ingi', 'Hattari, Rósi', 'Eyjólfsson, Gunnar', 'Guðnason, Hilmir Snær', 'Sighvatsson, Sturla', 'Gunnarsson, Þröstur Leó', 'Ægisson, Steinar V.', 'Haraldsson, Ingi', 'Armannsson, Benedikt Ingi', 'Ulfsson, Ólafur Evert', 'Baltasarsson, Baltasar Breki', 'Gunnarsson, Gunnar H.', 'Kormákur, Baltasar', 'Gylfason, Halldór', 'Erlendsson, Eyvindur', 'Einarsson, Cosimo Heimir F.', 'Johnson, Elmar', 'Karlsson, Eyvindur', 'Þorsteinsson, Jón Pétur', 'Heldadóttir, Sigríður', 'Bjarnadóttir, Guðrún María', 'Vilhjálmsdóttir, Þrúður', 'Gunnarsdóttir, Ingibjörg', 'Valdimarsdóttir, Inga Maria', 'Þórarinsdóttir, Lilja Nótt', 'Maríasdóttir, Guðrún Ósk', 'Anderson, Fida Bonnie', 'Helgadóttir, Dagbjört Rós', 'Jökulsdóttir, Esther', 'Hjaltadóttir, Charlotta Maria', 'Yngvadóttir, Sólrún', 'Gunnarsdóttir, Lilja Björg', 'Björnsdóttir, Halldóra', 'Guðnadóttir, Ragnhildur', 'Abendorth, Monica', 'Sigurbjörnsdóttir, Sól', 'Steinarsdóttir, Berglind', 'Kristjánsdóttir, Lísa', 'Ólafsdóttir, Jónína', 'Þorvaldsdóttir, Elín', 'Karlsdóttir, Hanna María', 'Backman, Edda Heidrún', 'Gunnarsdóttir, Kristín Hrönn', 'Abril, Victoria']
# 102 Dalmatians (2000) ['Crompton, Ben', 'Ruskin, Ian', 'Shale, Kerry', 'Willcox, Tim', 'Depardieu, Gérard', 'Cook, Ron (I)', 'Richardson, Ian (I)', 'Meaney, Nick', 'Horovitch, David', 'Gruffudd, Ioan', 'Bluto, Tony', 'Mason, Jack (III)', 'Carter, Jim (I)', 'Simon, Charles (II)', 'Hayley, Mike', 'Gomez, John (II)', 'Lawson, Thierry', 'Brannick, Dick', 'Ball, Sherwood', 'Boo Khoo, Ian', 'Hutchison, Nicholas (I)', 'West, Timothy', 'Idle, Eric', 'Futcher, Hugh', 'Blanc, JB', 'Styles, John', 'McInnerny, Tim', 'Annaiis, Delphine', 'MacReady, Carol', 'Mills, Ann (I)', 'Vale, Tessa', 'Evans, Alice (I)', 'Phillips, Dorothea', 'de Turckheim, Delphine', 'Close, Glenn', 'Kewer, Suzy', 'Watson, June', 'Carter, Carmen', 'Bridgeman, Julia']
# 11'09''01 - September 11 (2002) ['Idani, Rodrigue André', 'Taguchi, Tomorowo', 'Seksan, Aleksandar', 'Sheffey, George R.', 'Allende, Salvador', 'Russo, Tomer', 'Pinochet, Augusto', 'Vega, Vladimir', 'Levo, Liron', 'Folikoue, Lionel Gaël', 'Baral, Anil', 'Adlah, Taleb', 'Ogata, Ken', 'Guire, Lionel Zizréel', 'Borgnine, Ernest', 'Bassinga, René Aimé', 'Tamba, Tetsuro', 'Bush, George W.', 'Haroun, Ahmed', 'Bawa, Kapil', 'Kissinger, Henry', 'Emoto, Akira', 'Horry, Jérôme', 'El-Sherif, Nour', 'Traoré, Alex Martial', 'Bern, Jake', 'Mor, Keren', 'Azmi, Tanvi', 'Mooney, Nell', 'Baisho, Mitsuko', 'Aso, Kumiko', 'Laborit, Emmanuelle', 'Sojic, Tatjana', 'Karimi, Maryam (I)', 'Pinjo, Dzana']
# 11:14 (2003) ['Foster, Ben (I)', 'Thomas, Henry (I)', 'Segel, Jason', 'Swayze, Patrick', 'Hatosy, Shawn', 'Sands, Stark (I)', 'Hanks, Colin', 'Gomez, Rick (II)', 'Gregg, Clark', 'Heron, Blake', 'Hershey, Barbara', 'Cook, Rachael Leigh', 'Swank, Hilary']
# 12 Angry Men (1957) ['Fiedler, John (I)', 'Kelly, James (V)', 'Sweeney, Joseph (I)', 'Savoca, John', 'Bond, Rudy', 'Binns, Ed', 'Cobb, Lee J.', 'Voskovec, George', 'Marshall, E.G.', 'Balsam, Martin', 'Klugman, Jack', 'Warden, Jack', 'Begley, Ed (I)', 'Fonda, Henry', 'Webber, Robert (I)', 'Nelson, Billy (I)']
# 13 Going on 30 (2004) ['Black, Alex (I)', 'Horton, Ward', 'Pfaff, Shambo', 'Kotsatos, Bill', 'Pedron, Luis (I)', 'Rambo, Bubba Dean', 'Cohn, Jeffrey Shane', 'Higgins, Michael William', 'Diorio, Keith', 'White, Kevin D.', 'Reeves, Phil', 'Grifasi, Joe', 'Summers, Stewart', 'Jobrani, Maz', 'Grant, John W.', 'Serkis, Andy', 'Yribar, Jason', 'Pavel, Philip', 'Marquette, Sean', 'Calmettes, Fabrice', 'Burke, Justin (I)', 'Otcasek, Eron', 'Gaffigan, Jim', 'Barford, Ian', 'Armas, Adrian', 'Henschel, Brandon', 'Ball, Samuel (I)', 'Whitebear, Richard', 'Ruffalo, Mark', 'Pomichter, James', 'Anderson, Timothy (II)', 'Wright, Darrel W.', 'Caldwell, Douglas', 'Tiemann, Brad', 'Stea, Kevin Alexander', 'Vigus, Larry', 'Hine, George', 'Makely, Jason', 'Allen, Christa B.', 'Swain, Sara', 'Michelle, Crystal', 'Olstead, Renee', 'Miller, Katie (I)', 'Curran, Brittany', 'Beaudoin, Sydni', 'Lee, Robinne', 'Wyatt, Kimberly', 'Chase, Corena', 'Sweeney, Kadee', 'Baker, Kathy (I)', 'Lusk, Megan', 'Mantegna, Gina', 'Ellis, Nadine', 'Roth, Julia', 'Warren, Kiersten', 'Greer, Judy', 'Bland, Rita', 'Cultraro, Candace Elaine', 'Collins, Lynn', 'Egan, Susan', "O'Meara, Nancy", 'DeBonis, Marcia', 'Garraway, Janina', 'Nall, Benita Krista', 'Gristak, Amber', 'Garner, Jennifer (I)', 'Hoffman, Irena A.', 'Rice, Caroline A.', 'Bachar, Carmit', 'Harper, Stacey (I)', 'Kyle, Alexandra', 'Guidarelli, Megan', 'Krell, Melody', 'Suyama, Michon', 'Sprung-Keyser, Madeline', 'Gleason, Mary Pat', 'Larson, Brie', 'Willes, Natalie', 'Combs, Catherine', 'Benson, Ashley', 'Loew, Sarah']
# 13th Warrior, The (1999) ['Jolly, Malcolm', 'Hausserman, Mischa', 'Elam, Scott', 'Sveinall, Oliver', 'Van der Driesen, Jeremy', 'Kulich, Vladimir', 'Hachlaf, Al', 'Southern, Daniel', 'Pedersen, Bjørn Ove', 'Acheson, Mark', "Riis, Asbjørn 'Bear'", 'Bulatti, Joe', 'Russell, Clive', 'Storhøi, Dennis', 'Angel, Chris', 'Zahara, Alex', 'Batal, Tarik', 'Maffin, Neil', 'Woodley, Dylan Gray', 'Jonsson, Michael', 'Wollter, Sven', 'Bremmer, Richard', 'Michaels, Greg (I)', 'Curtis, John Bear', 'Curran, Tony (I)', 'Skjavestad, Gunnar', 'Jensen, Brian (I)', 'Kavadas, Andrew', 'Thorsen, Sven-Ole', 'Andersen, Anders T. (I)', 'Sharif, Omar', 'Reyez, Brett', 'Banderas, Antonio (I)', 'DeSantis, John', 'Avari, Erick', 'Walstrom, Owen', 'Ooms, Richard', 'Mina, Mina E.', 'Woodington, Albie', 'Tazmini, Ghoncheh', 'Venora, Diane', 'Bavan, Yolande', 'Storhøi, Mona', 'Bonnevie, Maria', 'Lander, Alaina', 'Bertish, Suzanne', 'Alizada, Layla', 'de Zilva, Kaaren', 'Balke, Turid', 'Willis, Susan', 'Mohammed MacLeod, Natalia', 'Lapinskie, Clare', 'Gill, Akesh']
# 1492: Conquest of Paradise (1992) ['Waddington, Steven', 'Botto, Juan Diego', 'Langella, Frank', 'Mañas, Achero', 'Sullivan, Billy L.', 'Taylor, Jack (II)', 'Guillén Cuervo, Fernando', 'Dean, Loren (I)', 'Vidal, Albert', 'Ferrer, José Luis', 'Heffernan, John (I)', 'Rey, Fernando (I)', 'García Rimada, Fernando', 'Vosloo, Arnold', 'Wincott, Michael', 'Depardieu, Gérard', 'Assante, Armand', 'Margolis, Mark', 'Karyo, Tchéky', 'Moya, Bercelio', 'Salem, Kario', 'Dunn, Kevin (I)', 'Molina, Ángela', 'Rosal, Ángela', 'Montero, Maria Laura', 'Prinz, Isabel', 'Weaver, Sigourney', 'Montero, Silvia']
# 15 Minutes (2001) ['Alfieri, Joseph (II)', 'Dane, Ashton', 'Yelchin, Anton', 'Garibyan, Haik', 'DiResta, John', 'Field, Bobby', 'Haddad, Zuhair', 'Roden, Karel (I)', 'Andon, Kurt', 'Camello, Mike', 'Davis, Stephen (VIII)', 'Herman, Paul (I)', 'Handy, James', 'Caruso, Phillip V.', 'Arnett, Peter', 'Taktarov, Oleg', 'Brooks, Avery (I)', 'Grammer, Kelsey', 'Khan, Marco', 'Roché, Sebastian', 'Bush, Brantley', 'Burns, Edward (I)', 'McCrary, Darius', 'Blueian, Barry', 'Runyan, Tygh', 'Resnick, Floyd', 'Burns, William H.', 'Matthews Jr., Riley G.', 'Primus, Barry', 'Garcia, Louis F.', 'Cutler, Bruce', 'Lawrence, Everton', 'Fiore, Ben', 'Miller, George F.', 'Foster, Bryan (I)', 'De Niro, Robert', 'Dillin, Scott', 'Brown, Lennox', 'Stamboulis, Spero', 'Wall, Ron', 'Coster, Ritchie (I)', 'Poulos, George', 'Cohen, Alan (IV)', 'Casseus, Gabriel', 'Stanton, William (I)', 'Mashkov, Vladimir', 'Lisi, Joe (I)', 'Guzman, Jorge H.', 'Grier, David Alan', 'Warner, Malcolm-Jamal', 'Maglione, Dominic', 'Mulholland, Leda', 'Marin, Mindy', 'Mariani, Janean Christine', 'Colasanti, Rose', 'Greaves, Gail', 'Roseanne', 'Cattrall, Kim', 'Kalem, Toni', 'Gregoire, Celeste', 'Dobó, Kata', 'Burton-Oare, Jamie', 'Klieman, Rikki', 'Morgunova, Olga', 'Abrusci, Christine', 'Merced, Macy', 'Vann, Elma', 'Farmiga, Vera', 'Gasanova, Irina', 'Espinoza, Julieta', 'Mulqueen, Tracey', 'Kanakaredes, Melina', 'Velez-Mitchell, Jane', 'Evans, Noelle', 'Alexis, Sophia', 'Sauer, Dorit', 'Lopez, Sylvia (II)', 'Claibourne, Christine', 'Theron, Charlize', 'Ruiz, Lynette']
# 16 Blocks (2006) ['Campbell, Jimmy (I)', 'Morse, David (I)', 'Lima, Danny', 'Wenk, Richard', 'Dismond, Daryl', 'Paterson, Bradley', 'Roiz, Sasha', 'McRobbie, Peter', 'Formosa, Victor', 'Wong, Emerson', 'Nicholsen, J.D.', 'Sullivan, Jeremy J.', 'Ferguson, Aaron (IV)', 'McCarthy, Kevin P.', 'Scrymgeour, Alex', 'Donner, Richard', 'McCord, Scott', 'Fitzpatrick, Richard (I)', 'Bizik, Robert', 'Racki, Robert', 'Douglas, Scott (II)', 'Andersson, Brian', 'Alachiotis, Nick', 'Factora, Marshall', 'Siravo, Joseph', 'Li, Ben', 'Segovia, Michael', 'Collier, Richard (II)', 'Harris, Eli', 'Wulff, Ryan', 'Gibbons, Jess Mal', 'Rosario, Joe (II)', 'Otuomagie, Efosa', 'Gomez, Eduardo', 'Duic, Albert', 'Masciulli, Claudio', 'Zayas, David', 'Cozart, Cylk', 'DeBona, Joseph', 'McKeown, Denis', 'Tuerpe, Paul', 'Kung, Sam', 'Burke, Jason (I)', 'Pla, Conrad', 'McGuckian, Liam', 'Phillips, Cecil', 'Lee, Paul J.Q.', 'Moses, Sam', 'Keenan, Michael F.', 'Sander, Casey', 'Weithoff, Rob', 'Hoffman, Derek (I)', 'Wlaschiha, Tom', 'Wong, Will', 'Sparrow, David', 'Lavin, Jim (I)', 'Def, Mos', 'Louangxay, Kameron', 'Vellozzi, Sonny', 'Ubarry, Hechter', 'Henry, Bernie', 'Garrow, Patrick', 'Clohessy, Robert', 'Kahan, Steve', 'Read, Brian (II)', 'Chong, Jim', 'Vance, Schuster', 'Tolby, Joshua', 'Giacoman, Rolando Alvarez', 'Willis, Bruce', 'Chan, Kim (I)', 'Schleiffer, Norman', 'Talbolt, David', 'Fong, Tig', 'Kean', 'Lee, Alan (XII)', 'Chong, Betty', 'Pressley, Brenda', 'Dawn, Heather', 'Yuste, Beatriz', 'Ritter, Allison Lee', 'Russo, Talia', 'Lopez, Carmen', 'Craggs, Vicky', 'Mitchell, Victoria (I)', 'López, Carmen (I)', 'Labao, Cece Neber', 'Titova, Svetlana (II)', 'Orjalo, Christina', 'Stern, Jenna', 'Imrie, Kathy', 'Ellwand, Toni', 'Seto, Angela']
# 1776 (1972) ["O'Shea, Dick", 'Jentzsch, Heber', 'Duell, William', 'Hansen, William (I)', 'Madden, Donald', 'Forster, Peter (I)', 'Rhodes, Jordan', 'Holgate, Ron', 'Downs, Frederic', 'Rule, Charles', 'Bass, Emory', 'Hines, Patrick', 'Nathan, Stephen', 'Poole, Roy (I)', 'Cullum, John (I)', 'Holland, John (I)', 'Middleton, Ray', 'Keyes, Daniel (I)', 'Devol, Gordon', 'Howard, Ken (I)', 'Hill, Ralston', 'Moore, Jonathan (I)', 'De Mave, Jack', "O'Hara, Barry", 'Caine, Howard', 'Daniels, William (I)', 'Myhers, John', 'Leyden, Leo', 'Montgomery, Mark (I)', 'Da Silva, Howard', 'Noble, James (I)', 'Albin, Andy', 'Robbins, Rex', 'Slyter, Fred', 'Bassett, William', 'McMurray, Richard', 'Ford, David (I)', 'Vestoff, Virginia', 'Danner, Blythe']
# 1941 (1979) ['Tennant, Andy', 'Deezen, Eddie', 'Williams, Treat', 'Oates, Warren', 'Wolfington, Iggie', 'Fuller, Samuel', 'Cook Jr., Elisha', 'Aykroyd, Dan', 'McKee, John (II)', 'Rourke, Mickey', 'Olkewicz, Walter', 'Miller, Dick (I)', 'Beatty, Ned', 'Zika, Christian', 'Contreras, Luis (I)', 'Caan, James', 'Matheson, Tim (I)', 'Scott, Donovan (I)', 'Rydbeck, Whitney', 'Lander, David L.', 'Stander, Lionel', 'Lassick, Sydney', 'Houston, Robert (I)', 'Lang, Perry', 'Brian, Jordan', 'Cervantes, Gary', 'Carenzo, Vito (I)', 'Frishman, Brian (I)', 'Carlton, Mark', 'Thompson, Galen', 'McMillan, Ronnie', 'Lee, Christopher (I)', 'Cameron, Dave (II)', 'Calfa, Don', 'Shimizu, Hiroshi (II)', 'Cloud, Paul', 'Marias, Mark', 'Di Cicco, Bobby', 'McKean, Michael (I)', 'Belushi, John', 'Flaherty, Joe (I)', 'McNamara, J. Patrick', 'Hamilton, Murray (I)', 'Taylor, Dub (I)', 'Frederickson, Gray', 'Silva, Geno', 'Mitamura, Dr. Akio', 'Verroca, Frank', 'Hardin, Jerry', 'McNally, Dan', 'Thibeau, Jack', 'Voldstad, John', 'McRae, Frank', 'Landis, John (I)', 'Candy, John', 'Mond, Steven', 'Stack, Robert', 'Mifune, Toshirô', 'Pickens, Slim (I)', 'Beagle, E. Hampton', 'Gorman, Brad (I)', 'Taggart, Rita', 'Gannen, Barbara (I)', 'Molinari, Antoinette', 'Teefy, Maureen', 'Gaines, Marjorie', 'Kay, Dianne', 'Backlinie, Susan', 'Garland, Trish', 'Culver, Carol', 'LuPone, Patti', 'Williams, Carol Ann', 'Dooling, Lucinda', 'Hardin, Diane (I)', 'Gallup, Denise', 'Cheshire, Denise', 'Benson, Deborah (II)', 'Rothstein, Debbie', 'Marshall, Penny (I)', 'Sherman, Kerry', 'Gallup, Dian', 'Benson, Lucille', 'Sperber, Wendie Jo', 'Williams, Jenny (I)', 'Gary, Lorraine', 'Allen, Nancy (I)', 'Landers, Audrey']
# 2 Days in the Valley (1996) ['Daniels, Jeff (I)', 'Mazursky, Paul', 'Aiello, Danny', 'Stoltz, Eric', 'Horton, Peter (I)', 'Carradine, Keith', 'White, Michael Jai', 'Cruttwell, Greg', 'Stanton, William (I)', 'Williams, Cress', 'Tierney, Lawrence', 'Pendleton, Austin', 'Spader, James', 'Benson-Wald, Deborah', 'Hatcher, Teri', 'Mercurio, Micole', 'Luong, Kathleen', 'Theron, Charlize', 'Mason, Marsha', 'Maris, Ada', 'Fletcher, Louise', 'Headly, Glenne']
# 2 Fast 2 Furious (2003) ['Hauser, Cole', 'Brown, Troy (I)', 'Mann, Zachary L.', 'Perez, Jose (I)', 'Bolano, Tony', 'Auyeung, Jin', 'Maloof, Sam', 'Barry, Thom', 'Gibson, Tyrese', 'Nolasco, Amaury', 'Ludacris', 'Eubanks, Corey Michael', 'Boone Junior, Mark', 'Robinson, Troy', 'Gallini, Matt', 'Moritz, Neal H.', 'Etebari, Eric', 'Herreros, Mateo', "Foster, Walter 'Duke'", 'Walker, Paul (I)', 'Cenatiempo, John', 'Macaulay, Marc', 'Finlay, Edward (I)', 'Harper, Cobette', 'Ealy, Michael', "Sanchez, Roberto 'Sanz'", 'Remar, James', 'Hill, Tequilla', 'Agosto, Limary', 'Huffer, Bettina', 'Carroll, Tara', 'Dubuque, Nievecita', 'Ward, Sincerely A.', 'Tuyet Vo, Phuong', 'Jones, Tamara (I)', 'Mendes, Eva', 'Rafield, Felecia', 'Arreaga, Marianne M.', 'Aoki, Devon']
# 200 Cigarettes (1999) ['Janney, Eli', 'Rudd, Paul (I)', 'Merchant, Kiran', 'Vause, Stephen', 'Costello, Elvis', 'Meyers, Michael J.', 'Frederic, Patrick', 'Temple, Johnny (I)', 'Affleck, Casey', 'Díaz, Guillermo (I)', 'Stellate, Nick', 'McNally, Seamus', 'DuMont, James', 'Mohr, Jay', 'McCardie, Brian', 'Brown, Morgan (II)', 'Carr, Caleb', 'Johansen, David', 'McCloud, Scott (II)', 'Chappelle, Dave', 'Affleck, Ben', 'Fleisig, Alexis', 'Murphy, James F.', 'Berrebbi, Brian', 'Parker, Nicole Ari', 'Garofalo, Janeane', 'Searle, Kathy', 'Tavoularis, Oriana Nicole', 'Blong, Jenni', 'Love, Courtney', 'Kellner, Catherine', 'Wible, Patricia', 'Plimpton, Martha', 'Bonelli, Jamie', 'Featherstone, Angela', 'Hoffmann, Gaby (I)', 'Albano, Jennifer', 'Hudson, Kate (I)', 'Ricci, Christina']
# 20000 Leagues Under the Sea (1954) ['Graham, Fred (I)', 'Monaghan, T.', 'Helton, Percy', 'Douglas, Kirk (I)', 'Harvey, Harry (II)', 'Lukas, Paul', 'Mason, James (I)', 'Wilke, Robert J.', 'Vigran, Herb', 'Young, Carleton', 'Cooper, Ted (I)', 'Lummis, Dayton', 'de Corsia, Ted', 'Daheim, John', 'Lorre, Peter (I)', 'Marr, Eddie (I)', 'Kerrigan, J.M.', 'Stoney, Jack', 'Grodin, Charles (I)', 'Gargan, Jack', 'Pennick, Jack', 'Tarnell, S.', 'Pall, Gloria', 'Mitchell, Laurie']
# 2001: A Space Odyssey (1968) ['Miller, Frank (I)', 'Rain, Douglas', 'Paes, Darryl', 'Sullivan, Sean (I)', 'Beck, Glenn (I)', 'Dullea, Keir', 'Delmár, Péter', 'Hines, David (I)', 'Lockwood, Gary', 'Ashley, John (III)', 'Swindells, John', 'Grover, Danny (I)', 'Charkham, David', 'Scott, Kevin (I)', 'Amor, Martin (I)', 'MacKee, Scott', 'Marchant, Laurence', 'Beatty, Robert (I)', 'Kendall, Kenneth', 'Fleetwood, David (II)', 'Duggan, Terry (I)', 'Woods, Richard (II)', 'Bishop, Ed (I)', 'Davis, Simon (I)', 'Daw, Jonathan', 'Lovell, Mike', 'Jordan, John (X)', 'Wilyman, Bob', 'Wallace, Andy (I)', 'Richter, Daniel (I)', 'Bell, Jimmy (I)', 'Rossiter, Leonard', 'Hawley, Brian (I)', 'Clifford, John (I)', 'Sylvester, William', 'Weston, Bill (I)', 'Jackson, Tony (I)', 'Gifford, Alan', 'Anderson, S. Newton', 'Refalo, Joe', 'Tucker, Burnell', 'Marr, Krystyna', 'Marr, Irena', 'Pearl, Jane', 'Markham, Marcella', 'Neil, Kim', 'Francis, Penny', 'Tyzack, Margaret', 'Bormann, Ann', 'Hayward, Jane', 'Pearl, Penny', 'Croft, Julie', 'Gillis, Ann (I)', 'Carroll, Edwina', 'Downham, Heather', 'Kubrick, Vivian', 'Blount, Sheraton', 'Brahms, Penny']
# 2001: A Space Travesty (2000) ['Samuel, Martin (II)', 'Bisson, Jean-Marc', 'Tsar, Mike', 'Ducharme, Yvan', 'Millman, Jason', 'Suetsugu, Robert', 'Lenoir, Pierre (II)', 'Alon, Noam', 'Nielsen, Leslie', 'Laroche, Armand', 'Edwards, Pierre', 'Normandin, Stéphane', 'Stevens, Mark (XIV)', 'Canestrari, Perry', 'Papasoff, Charles', 'Campeau, Luc', 'El-Onsi, Kareem', 'Ghandi', 'Bérard, Alain', 'Dennis, Charles', 'Alvarez, Daniel (I)', 'Côté, Jean-Luc', 'Francis, David (I)', 'Jutras, Richard (I)', 'Schnurmacher, Tommy', 'Weissman, Jeffrey', 'Rainville, Paul', 'Fox, David (I)', 'Shearman, Alan', 'Ruiz, Carlos (I)', 'Vezina, Christian', 'Flatley, Michael (I)', 'Frappier, Dany', 'Egan, Peter (I)', 'Asato, Reid', 'Smiley, Matthew', 'Perron, Michel', 'Greggio, Ezio', 'Jordan, Don (I)', 'Millbern, David', 'Masson, Damien', 'Stone, Sam (I)', 'Hervieux, Marc', 'Jeperson, Rachel A.', 'Kamp-Groeneveld, Alexandra', 'Gray, Natalie', 'Winter, Ophélie', 'Dumolin-Shaw, Stephanie', 'Scarabelli, Michele', 'Feldbusch, Verona', 'Gravel, Mikael', 'Kay, Una', 'Hinz, Marion', 'Torsein, Annabelle', 'Farley, Marianne', 'Sherwood, Toni (I)', 'David, Ellen', 'Soo, Betsy', 'Davis, Cindy', 'Andre, Caroline', 'Barnwell, Teresa', 'Sudonim, Ima']
# 2010 (1984) ['McGarr, Gene', 'Dullea, Keir', 'Carroll, Larry (I)', 'Steinbach, Victor', 'Triska, Jan', 'Rain, Douglas', 'Elcar, Dana', 'Kramarov, Saveli', 'Baskin, Elya', 'Lesser, Robert', 'Balaban, Bob', 'Lithgow, John', 'Jaffe, Taliesin', 'Clarke, Arthur C.', 'Recasner, Ron', 'Scheider, Roy', 'Skomarovsky, Vladimir', 'McEachin, James', 'Rudnik, Oleg', 'Osborne, Madolyn Smith', 'Ware, Herta', 'Shneider, Natasha', 'Michaels, Delana', 'Carter, Cheryl', 'Deschanel, Mary Jo', 'Bergen, Candice', 'Mirren, Helen']
# 2046 (2004) ['Kimura, Takuya', 'Leung Chiu Wai, Tony', 'Ng, Ting Yip', 'Chang, Chen', 'McIntyre, Thongchai', 'Sum, Wang', 'Siu, Ping Lam', 'Gong, Li (I)', 'Cheung, Maggie', 'Zhang, Ziyi', 'Dong, Jie', 'Wong, Faye', 'Lau, Carina']
# 21 Grams (2003) ['Nichols, Nick (III)', 'Medina, Roberto (I)', 'Corrigan, Juan', 'Roberts, Barclay', 'Del Toro, Benicio', 'Harris, Antef A.', 'Schmidt, Jeff', 'Brown, Charlie B.', 'Irwin, Tom (II)', 'Chipman, Jerry', "O'Hare, Denis (I)", 'Marsan, Eddie', 'Guyton, Tony', 'Chapman, Kevin (I)', 'Bridgewater, Stephen', 'West, John Boyd', 'Johnson, Keith Lamont', 'Hartzog, Randall', 'Romero, Chance', 'Salter, Loyd Keith', 'Calderon, Paul (I)', 'Tran, Hai Quang', 'Huston, Danny', 'Alban, Carlo', 'Musso, Marc', 'Dee, Trent', 'Beech Jr., Wayne E.', 'Ingle, Rodney', 'Penn, Sean (I)', 'Shiver, Arron', 'Temple, Lew', 'Finnell, Michael', 'Vaughn, Tony', 'Finnell, Michael W.', 'Rubinstein, John', 'Chattam, David', 'Blair, Pamela', 'Branch, Tricia', 'Armstrong-Miles, Dorothy', 'Bishop, Sharon', 'Pfalzgraff, Jennifer', 'Herin, Anastasia', 'Watts, Naomi', 'Gainsbourg, Charlotte', 'Leo, Melissa', 'Pakis, Claire', 'Davenport, Verda', 'Corley, Annie', 'Trahan, Arita', 'Sanchez, Lisa', 'DuVall, Clea', 'Dent, Catherine', 'Delgado, Teresa (I)', 'Scott, Jessica (VII)', 'Nahon, Carly']
# 24 Hour Party People (2002) ['Haslam, Dave', 'Bowser, Mr. A.', 'Murray, Conrad', 'Pop, Iggy', 'Clarke, Nick (I)', 'Cilenti, Enzo', 'Pivaro, Nigel', 'Tighe, Darren', 'McNicholas, Joshua', 'Cook, Ron (I)', 'Simm, John', 'Kay, Peter (I)', 'Swan, Paul (II)', 'Wilson, Tony (II)', 'Salaman, Toby', 'Gorman, Dave (I)', 'Hancock, Martin (I)', 'Windows, Mark', 'Coogan, Steve', 'Smith, Mark E.', 'Little, Ralf', 'Waring, Raymond', 'Riley, Sam (II)', 'Hope, Dan', 'Lydon, John (I)', 'Coghill, Chris', 'Cross, Aidan', 'Coogan, Martin', 'James, Lennie', 'Considine, Paddy', 'Brydon, Rob', 'Boon, Clint', 'Roberts, Smug', 'Whitworth, Duncan', 'Severin, Steven', 'Roberts, Gary (IV)', 'Mani (III)', 'Allen, Keith (I)', 'Kennedy, Roger (III)', 'Johnson, Trevor (I)', 'Davey, Martin Nigel', 'Horrocks, Tim', 'Dino (IV)', 'Serkis, Andy', 'Ryder, Paul (II)', 'Ryder, Shaun', 'Cartwright, James (I)', 'Thomson, John (I)', 'Baker, Kenny (I)', 'Mitchell Jr., Michael', 'Pegg, Simon', 'Tildesley, Mark', 'Weller, Paul (I)', 'Pickering, Mike (I)', 'Devoto, Howard', 'Gunn, Peter (I)', 'Burnell, Jean-Jacques', "O'Brien, Kieran", 'Bell, Neil (I)', 'Eccleston, Christopher', 'Popplewell, Paul', 'Moscrop, Martin', 'Cernow, Sean', 'Harris, Sean (I)', 'Cunningham, Danny', 'Radcliffe, Naomi', 'Tyborczyk, Anna', 'Cooper, Collette', 'Sioux, Siouxsie', 'Henderson, Shirley (I)', 'Lever, Claire', 'Cunliffe, Tracy', 'Clarke, Margi', 'Kelly, Elizabeth (I)', 'Seymour, Terri', 'Schlesinger, Helen', 'Allen, Fiona', 'Magowan, Kate', 'Satchell, Rowetta']
# 25th Hour (2002) ['DeGennaro, Vinny', 'Orvis, Greg', 'Hoffman, Philip Seymour', 'Bergen, John', 'Palagonia, Al', 'Fortt, Guy A.', 'Reton, Daniel', 'Matthews, Frank (III)', 'Zhivotovsky, Igor', 'DJ Cipha Sounds', 'Norton, Edward (I)', 'Kelsch, Peter James', 'Modafferi, Louis', 'Mascall, Joseph', 'Palazzo, Jeffrey', 'Miller, Douglas (VII)', 'Cox, Brian (I)', "Jackson, Rodney 'Bear'", 'Prudius, Oleg Aleksandrovich', 'Spinghel, Radu', 'Wallace, Mark (I)', 'Taraseiwicz, Alan', 'Pierce, Jason (VII)', 'Mundi, Coati', 'Fiore, Mike (I)', 'Kuznetsov, Misha', 'Simon, Marc H.', 'Uchaneishvili, Levan', 'Diomede, Paul', 'Williams, Brad (V)', 'Rubeo, Ed', 'Bini, Carl', 'Bright, Keith (I)', 'Stanford, Aaron', 'Castillo, Doy Gabriel', 'Cecere, Sal', 'Siragusa, Tony', 'Illig, Patrick', "O'Neal, Patrice", 'Genet, Michael', 'Brazil, R.L.', 'Crowns, Howard', 'Fletcher, Andre', 'McCoy, A.J.', 'Devon, Tony', 'Whitlock Jr., Isiah', 'Pepper, Barry', 'Bullock, Lawrence', 'Rossomodo, Nicholas', 'Riesco, Armando', 'Nobbs, Keith', 'Pepe, Christine', 'Ferlito, Vanessa', 'White, Michole', 'Finley, Felicia', 'Spierer, Stacy Lynn', 'Darlow, Cynthia', 'Niles, Maja', 'Cornelisse, Tonya', 'Dawson, Rosario', 'Drekonja, Larissa', 'Paquin, Anna', 'Mullen, Jamil', 'Reston, Arloa', 'Ramirez, Dania', 'Rahman, Rumaisa']
# 28 Days (2000) ['Nayyar, Harsh', 'Gioiello, Bruno', 'Armstrong, Jack (I)', 'McCary, Rod', 'Taylor, Frank Hoyt', 'Byrd, Dan (I)', 'Santoni, Reni', 'Buscemi, Steve', 'Ponder, Brent', 'Dolan, Andrew', 'Cedeño, Matt', 'Wainwright III, Loudon', 'Dooly, Mike', 'Reitz, Ric', "O'Malley, Mike (I)", 'Moody, Jim (I)', 'Anagnos, Bill', 'Kelley, Elijah (I)', 'Tudyk, Alan', 'Wood, Stan', 'Mortensen, Viggo', 'West, Dominic', 'Pervis, Adam', 'Skye, Azura', 'Chapman, Judith', 'Yates, Suellen', 'Sutton, Lisa (I)', 'Reilly, Corinne', 'Chang, Christina', 'Payne, Kathy (I)', 'Perkins, Elizabeth (I)', 'Fairchild, Patricia M.', 'Pratt, Wendee', 'Bullock, Sandra', 'Martindale, Margo', 'McGuire, Maeve (I)', 'Scharf, Katie', 'Ladd, Diane', 'Krebs, Susan', 'Jean-Baptiste, Marianne', 'Davis, Suzanne (I)', 'Warrick, Brittani', 'Pankow, Joanne', 'Ruscio, Elizabeth', 'Deane, Meredith']
# 28 Days Later... (2002) ['Harnett, Ricci', 'Schneider, David (IV)', 'Knapp, Sebastian', 'Murphy, Cillian', 'Campbell, Marvin', 'Young, Steen', 'McQuarrie, Stuart', 'Mably, Luke', 'Dunne, Christopher', 'Rambaruth, Sanjay', 'Christopher, Adrian', 'Hiltunen, Jukka (I)', 'Lush, Jenni', 'Laniyan, Junior', 'Dwyer, Richard (I)', 'Hackney, Justin', 'Delamere, Alexander', 'Bill, Leo', 'Kasey, Paul', 'Rann, Jeffrey', 'Huntley, Noah', 'Eccleston, Christopher', 'Gleeson, Brendan', 'Lewis, Nicholas James', 'Sedgwick, Toby', 'Matthiae, Tristan', 'John, Terry', 'Panthaki, Ray', 'Palmer, Alex', 'Stokes, Al (II)', 'Ewans, Nick', 'McGarrity, Kim', 'Simpson, Joelle', 'De Stoppani, Bindu', 'Burns, Megan', 'Hitching, Emma', 'Harris, Naomie']
# 3 Men and a Little Lady (1990) ['Hunt, Neil', 'Pringle, Bryan', 'Richards, Charles David', 'Guttenberg, Steve', 'Boswall, John', 'Wong, Everett', 'Redford, Ian', 'Danson, Ted', 'Lynn, Jonathan', 'Selleck, Tom', 'Cazenove, Christopher', 'Vaughn, Steven L.', 'Allen, Rosalind (I)', 'Shaw, Fiona', 'Hancock, Sheila', 'Hurley, Melissa (I)', 'Fields, Edith (I)', 'Travis, Nancy', 'Walsh, Sydney', 'Gaul, Patricia', 'Weisman, Robin', 'Neal, Lucia', 'Moore, Edwina', 'Pulliam, Darcy', 'Marta, Lynne']
# 3 Ninjas (1992) ['Slade, Max Elliott', 'Nelson, Race', 'Swetow, Joel', 'McRae, Alan', 'Power, Chad', 'Labyorteaux, Patrick', 'Septien, Al', 'Tanaka, Professor Toru', 'Harder, D.J.', 'Caudill, Scott', 'Jackson, Baha', 'Kingsley, Rand', 'Powell, Clifton', 'Treanor, Michael', 'Chou, Tasen', 'Wong, Victor (III)', 'Sargeant, Kate', 'Franco, Margarita', 'Burr, Fritzi']
# 3 Ninjas: High Noon at Mega Mountain (1998) ['McRae, Alan', 'Roeske II, James Paul', 'Mahoney, Pat (I)', 'Brewster, Julian', 'Hogan, Hulk', 'Yerbey, Roy', 'Fiorino, Anthony', 'Ackler, Joseph', 'Wiles, Rick', 'Himber, Robert', 'Anderson, Ed (V)', 'Wong, Victor (III)', 'Carrington, Dwayne', 'Punito, Pete (I)', 'Dente, Eric C.', 'Smith, Ryan Gardner', 'Adamson, Patrick', 'Price, Craig (V)', "O'Laskey II, Michael", 'Williams, Carl L.', 'Berkfeldt, Denis', 'Hogue, Kenneth', 'McKenna, Travis', "O'Brien, Brendan (II)", 'Zondler, Andrea', 'Shugart, Craig', 'Vecqueray, Michael', 'Shadwell, Dan', 'Jackson, Duke', 'Krebs, Jeff', 'Hudson, Charles', 'Anglin, Brian', 'Galleoos, Lawrence E.', 'Swanson, Mark (II)', 'Backstrom, Greg', 'Newton, Walter', 'Gale, James', 'Baily, Kirk', 'Varney, Jim', 'Dirker, Jim', 'Morse, J. Bryan', 'Dirker, James B.', 'Botuchis, Mathew', 'Woods, Jacqueline', 'Roeske, Emily', 'Merrick, Dawn', 'Johnson, Holly (VII)', 'Anderson, Loni', 'Ryder, Syntrell', 'Franco, Margarita', 'Jasionowski, Mary (I)', 'Nelson, Aimee J.', 'Felton, Lindsay', 'Earlywine, Chelsey', 'Ross, Susan (III)']
# 3000 Miles to Graceland (2001) ['Haines, Ross', 'Owen, Jim (II)', 'McMurray, Lawrence', 'Puccio, Kerry', 'Termath, Steve J.', 'Lichtenstein, Demian', 'Staz', 'Green, Alex (I)', 'Woodbine, Bokeem', 'Misney, Timothy', 'Drummond, Brian', 'Swanson, Scott (I)', 'Casino, John', 'Skylark', 'Bryant, Peter (I)', 'Claggett, Bruce', 'Long, Howie', 'Leboeuf, Jim', 'Kopsa, Michael', 'Turner, Frank C. (I)', 'Slater, Christian', 'Russell, Kurt (I)', 'Lombardi, Louis', 'Arlt, Eric', 'von Watts, Hamilton', 'Garon, Jesse (II)', 'Hoctor, Tim', 'Babych, Dave', 'Brown, R. Nelson', 'Mastrangelo, Alberto', 'Lake, Rod', 'Lake, Rob', 'Ganeev, Raoul', 'Connolly, Steve', 'Sadler, Jody', 'Lane, Campbell', 'Gibbon, Mark (I)', 'Kent, Peter (I)', 'James, Eric (I)', 'Dorsa, Bart', 'Lovitz, Jon', 'Powers, Eddie', 'Margolis, Morgan H.', "O'Faolain, Colm", 'Honeywell, Rice', "D'Ambruoso, Dante", "Grant, 'J.G.' Jim", 'Mundy, Kevin', 'Klush, Shawn Wayne', 'Ice-T', 'Moro, Luis', 'MacKay, Don', 'Martin, Robert (XIII)', 'Carroll, J. Winston (I)', 'Andre, Charles (II)', 'Anderson, Kenneth (I)', "Zajonc, Robert 'Bobby Z'", 'St. John Smith, Michael', 'Arquette, David', 'Jordan, Aubrey', 'Sembach, Jerry', 'March, Craig', 'Alderman, Ralph J.', 'Russo, Gianni (I)', 'Chen, Terry', 'Dunlap, Dave (I)', 'Keller, Duncan', 'Allan, Jay (II)', 'Church, Thomas Haden', 'Pollak, Kevin', 'Harter, Wayne', 'Howard, Shawn Michael', 'Alves, Tony', 'Welch, Tim (I)', 'Holdridge, Larry', 'Busswood, Michael', 'Destry, John B.', 'Kaye, David (II)', 'Goldblatt, Max', 'Heaton, Tom', 'Anka, Paul', 'Costner, Kevin', 'Meeker, David (II)', 'Conti, Michael J.', 'Miller, Greg (II)', 'Abrahams, Doug', 'Acheson, Mark', 'Edwards, Johnny', 'Chatelain, Christine', 'Campbell, Norma', 'Hawthorne, Kimberly', 'McCoy, Angelina', 'Cherrier, Renee', 'Lien, Shelly', 'Harambasic, Melinda', 'Lake, Marci', 'Cox, Courteney', 'Lee, Jeanette', 'Leigh, Sharron', 'Skoll, Mary Ann', 'Swinney, Stephanie', 'Landess, Jill', 'Murray, Daniella', 'Cote, Lorraine', 'Gomez, Terri', 'Preston, Jamie', 'McCrackin, Daisy', 'Lago, Laura', 'Budde, Susse', 'Gagliano, Jennifer Crick', 'Bernasek, Georgie', 'Carlson, Kelly (I)', 'Grace, Yvonne']
# 36 Quai des Orfèvres (2004) ['Auteuil, Daniel', 'Figlarz, Alain', 'Lecluyse, Guy', 'Franek, Ivan', 'Dussollier, André', 'Prestia, Jo', 'Hertel, Cyrille', 'Guerrib, Thierry', 'Duval, Daniel', 'Berthillot, Ludovic', 'Depardieu, Gérard', 'Beuchat, Serge', 'Metzger, Stéphane', 'Hoehn, Robert (I)', 'Rouzaud, Christophe', 'Moscato, Vincent', 'Orsolani, Stéphane', 'Renaud, Francis', 'Maranber, Frédéric', 'Odone, Martial', 'Bihoreau, Jean-Louis', 'Geffroy, Christian', 'Chaubet, Philippe', 'Médioni, Patrick', 'Marchal, Olivier', 'Defosse, Eric', 'Zem, Roschdy', 'Bowen, Vincent', 'Sabah, Mickaël', 'Olmédo, Laurent', 'Sylvain, Denis', 'Biasch, Solène', "D'Annunzio, Anna", 'Golino, Valeria', 'Coubard, Stéphanie', 'Marchal, Catherine', 'Chansou, Christine', 'Demongeot, Mylène', 'Jampanoï, Mylène', 'Auteuil, Aurore', 'Consigny, Anne']
# 37°2 le matin (1986) ['Julien, André', 'Bellanti, Louis', 'Lindon, Vincent', 'Robin, Bernard', 'Bisson, Jean-Pierre', 'La Brosse, Simon de', 'Verbiest, Stéphane', 'Billerey, Raoul', 'Laudenbach, Philippe', 'Confortès, Claude', 'Berthier, Eugène', 'Bonnet, Franck-Olivier', 'Pinon, Dominique', 'Loucif, Rabah', 'Julien, Raymond', 'Anglade, Jean-Hugues', 'Mathou, Jacques', 'Hug, Bernard', 'Duneton, Claude', 'Béhar, Fabien', 'Galibert, Jacky', 'Jalowyj, Nicolas', 'Darmon, Gérard', 'Caratini, Frédéric', 'Besnehard, Dominique (I)', 'Aufaure, Claude', 'Millot, Daniel', 'Berthuit, Leonie', 'Dalle, Béatrice', 'Renn, Laurence', 'Moudiki-Moreau, Marthe', 'Dalyan, Nathalie', "D'At, Catherine", 'De Haviland, Consuelo', 'Célarié, Clémentine', 'Datnowsky, Christine', 'Palas, Bernadette', 'Forde, Jessica']
# 39 Steps, The (1935) ['Tearle, Godfrey', 'Laurie, John (I)', 'Verno, Jerry', 'Hagate, Pat', 'Knight, James (I)', 'Barnard, Ivor', 'Warmington, S.J.', 'Brambell, Wilfrid', 'Turnbull, John (I)', 'Malleson, Miles', 'Piper, Frederick', 'Hitchcock, Alfred (I)', 'Cellier, Frank', 'McPhearson, Quentin', 'Watson, Wylie', 'McNaughton, Gus', 'Donat, Robert', 'Ashcroft, Peggy', 'Inglis, Elizabeth', 'Trevelyan, Hilda', 'Mannheim, Lucie', 'Simpson, Peggy (I)', 'Carroll, Madeleine', 'Haye, Helen']
# 40 Days and 40 Nights (2002) ['Gauthier, Chris', 'Fitzgerald, Glenn', 'Trainor, Aaron', 'Costanzo, Paulo', 'Chen, Terry', 'Anderson, Stanley', 'Grundy, Rueben', 'Trese, Adam', 'Maronna, Michael C.', 'Newman, Barry (I)', 'Paul, Jarrad', 'Low, Jason', 'Draven, Alan', 'Hartnett, Josh', 'Neal, Dylan', 'Lennox, Kai', 'Dunne, Griffin', 'Malthe, Natassia', 'Chatelain, Christine', 'Zanni, Chiara', 'von Pfetten, Stefanie', 'Gross, Mary', 'Gyllenhaal, Maggie', 'Welles, Amanda', 'Shaw, Vinessa', 'Sossamon, Shannyn', 'Harrison, Michelle (II)', 'DeVettori, Gina', 'Patterson, Deenah', 'Mazur, Monet', 'Ruiz, Angie', 'Wilder, Nicole (II)', 'Vaugier, Emmanuelle', 'Tracy, Keegan Connor', 'Bain, Susan', 'Kyser, Tracy', 'Heath, Lorin', 'Alexandria, Theresa']
# 40 Year Old Virgin, The (2005) ['Marasco, Ron', 'Jazzmun', 'Masterson, Jordy', 'Hartsock, Charlie', 'Rudd, Paul (I)', 'Wainwright III, Loudon', 'McKane, Matthew', 'Killham, Brandon', 'Nunez, Joe (I)', 'Malco, Romany', 'Bierman, Michael', 'Hill, Jonah', 'Carell, Steve', 'Foster, Julian', 'Malil, Shelley', 'Hart, Kevin (I)', 'Lashaway, Nick', 'Kahn, Jeff (I)', 'Bannos, Steve', 'Rogen, Seth', 'Yarbrough, Cedric', 'Weaver, Lee (II)', 'Wood, Christopher T.', 'Bednob, Gerry', 'Koechner, David', 'Berman, Loren (II)', 'Mastrolia, Joseph T.', 'Smith, Wyatt (II)', 'Federman, Wayne (I)', 'Kaling, Mindy', 'Goines, Siena', 'Banks, Elizabeth (II)', 'Lynch, Jane', 'Mia, Miki', 'Dennings, Kat', 'Fischer, Jenna', 'Drake, Penny', 'Abdoo, Rose', 'Dominczyk, Marika', 'Johnson, Nicole Randall', 'Collins, Mo (I)', 'Luyben, Kate', 'Brown, Brianna', 'Page, Kimberly', 'Mann, Leslie', 'Mann, Jamie Elle', 'Lemelin, Stephanie', 'Carey, Elizabeth', 'Smith, Chelsea (II)', 'Smith, Phyllis', 'Gallo, Carla', 'Skye, Brittany', 'Guterman, Marisa', 'Phillips, Erica Vittina', 'Jones, Gloria Helena', 'Stormy (III)', 'Vigman, Gillian', 'Keener, Catherine', 'Walls, Nancy', 'DeCicco, Elizabeth', 'Bottrell, Laura', 'Hamlin, Brooke', 'Bradley, Shannon (I)', 'Turnage, Kira', 'Swatek, Barret', 'Freund, Mandy', 'Shepard, Hilary', 'Nakamura, Suzy', 'Dodds Frank, Marilyn', 'Shimosawa, Miyoko', 'Meyerson, Denise']
# 42nd Street (1933) ['Stone, George E. (I)', 'Walthall, Henry B.', 'Irving, George (I)', 'Kibbee, Guy', 'Warren, Harry (I)', 'Village Barn Hill Billies, The', 'Clark, Wallis', 'Kibbee, Milton', 'Sparks, Ned (I)', 'Sizzlers, The', 'Akst, Harry', 'Kennedy, Tom (I)', 'McWade, Robert (I)', 'Baxter, Warner', 'Nordstrom, Clarence', 'Talbot, Lyle', 'Powell, Dick (I)', 'Jenkins, Allen', "O'Brien, Dave (I)", 'Nugent, Edward J.', 'Seymour, Harry', 'Sedan, Rolfe', 'Dubin, Al', 'La Rue, Jack', 'Brent, George (I)', 'Lane, Charles (I)', 'Maynard, Kermit', 'Francis, Dixie', 'Hovey, Ann', 'Lacy, Adele', 'Layson, Lorena', 'White, Dorothy (I)', 'Wellman, Dorothy Coonan', 'Evans, Renee', 'Halsey, Mary', 'Daniels, Bebe', 'Keeler, Gertrude', 'Rogers, Barbara (I)', 'Roberts, Donna Mae', 'Barclay, Joan', 'Jans, Alice', 'Keeler, Helen', 'Cantway, Maxine', 'Joice, Evelyn', 'Ray, Agnes', 'Browning, Lynn', 'Merkel, Una', 'Rogers, Ginger', 'Wing, Pat', 'Wing, Toby', 'Eddings, Ruth', 'Ellis, Patricia (I)', 'Dabney, Virginia', 'Whitney, Renee', 'Shadduck, Jayne', 'Marcy, Eve', 'Callaghan, Edna', 'Andrews, Loretta', 'La Marr, Margaret', 'Glory, June', 'Farnum, Patsy', 'Beavers, Louise', 'Keeler, Ruby', 'Tobin, Grace']
# 48 Hrs. (1982) ['Johnston, John Dennis', 'Dowd, Ned', 'Keane, James (I)', 'Pettinger, Gary', 'Catlett, Loyd', 'Contreras, Luis (I)', 'Remar, James', 'Landers, Matt', 'Thibeau, Jack', 'Nolte, Nick', 'Dimitri, Nick', 'Sánchez, Marcelino', 'Fisher, B.G.', 'Landham, Sonny', 'Zacha, W.T.', 'Murphy, Eddie (I)', 'James, Brion (I)', 'Scott, Walter (I)', 'St. Elwood, Jon', 'Cruickshanks, Reid', 'Dobbins, Bennie E.', 'Haynie, Jim', 'Dearth, Bill', 'Allen, Todd (I)', "O'Neal, Kevin (II)", 'Cross, Bill (IV)', 'Call, R.D.', 'McRae, Frank', 'Loundermon, Gus', 'Huston, J. Wesley', 'Turner, Bjaye', 'Moordigian, Dave', "O'Neal, Brian (I)", 'Yanez, Bob', 'Smith, Clint (I)', 'Mulkey, Chris', 'Hauk, John', 'Walker, Rock A.', 'Lightsy, Jack', 'Kelly, David Patrick', 'Banks, Jonathan', 'Jason, Peter', 'Wallace, Marquerita', 'Regard, Suzanne M.', 'Robinson, Angela (I)', 'Martin, Sandy (I)', 'Plaza, Begoña', 'Brown, Olivia (I)', 'Crosby, Denise', 'Ray, Ola', 'Rose, Margot', 'Gifford, Gloria (I)', 'Venus, Brenda', 'Nono, Clare', 'Blackburn, Greta', "O'Toole, Annette", 'King, Tara (I)', 'Sherman, Kerry']
# 50 First Dates (2004) ['Magwili, Dom', 'Chung, Esmond', 'Nakashima, Joe', 'Clark, Blake', 'Astin, Sean', 'Loughran, Jonathan', 'Chen, Peter (IV)', 'Covert, Allen', 'Federman, Wayne (I)', 'James, Kevin (III)', 'Abesamis, Americus', 'Shulak, John Patrick', 'Fujimori, Darin', 'Puluti Sr., Aukuso Gus', 'Dante, Peter', "Brown, Pomaika'i", "Olmos, Keali'i", 'Osborn, Michael K.', 'Donaruma, J.D.', 'Aykroyd, Dan', 'Sandler, Adam (I)', 'Suapaia, David', 'Avenido, Kent', 'Chi, Albert', 'Yan, Lin', 'Uesugi, Tache', 'Pinkosh, Mark', 'Guiterrez, Christian', 'Keaulana, Brian L.', 'Patricio, Anthony', 'Lee, James (IV)', 'Chin, Glen', 'Schneider, Rob', 'Christopher, Chantell D.', 'Omi, Sharon', 'Rose, Nectar', 'Lee, Michelle (III)', 'Soerjoko, Meilinda', 'Cazin, Marguerite', 'Moore, Kylie', 'Pyle, Missi', 'Sandler, Jackie (I)', 'Williams, Shenika', 'Hersh, Nicola', 'Strus, Lusia', 'Morris, Julianne', 'Uhvana, Ishtar', 'Collins, Lynn', 'Hill, Amy', 'Bauer, Kristin', 'Bowman, Jessica', 'Vivian, Brenda', 'Lawner, Melissa', 'Winnick, Katheryn', 'Barrymore, Drew (I)', 'Bee, Denise', 'Rudolph, Maya', 'Reece, Virginia', 'Segal, Linda', 'Stedman, Anne']
# 51st State, The (2001) ['Jackson, Samuel L.', 'Tomlinson, Ricky', 'Muslim, Sonny', 'McDonald, Mac (I)', 'Ifans, Rhys', 'Roach, James (V)', 'Anwar, Marc', 'Starke, Michael', 'Fyfe, Robert', 'Pavlou, Stel', 'Carlyle, Robert (I)', 'Hunter, Christopher (III)', 'Reynolds, Michael J.', 'Swartz, Aaron (I)', 'Meat Loaf', 'Barber, Paul (I)', 'Inocian, Junix', 'Jezek, Robert (I)', 'Broughton, Paul (I)', 'Walters, Stephen (I)', 'Webber, David (I)', 'Routledge, Matt', 'Pertwee, Sean', 'Whitmey, Nigel', 'Murray, Paul T. (I)', 'MacInnes, Angus', 'Abraham, Jake (II)', 'Bartlett, Nick', 'Ade', 'Grøtta Grav, Gaute', "O'Neill, Terry (I)", 'Barnes, Barbara (II)', 'Mortimer, Emily', 'Keaveney, Anna', 'Campion, Joan']
# 54 (1998) ['Fiorucci, Elio', 'Jeremy, Ron', 'Sutherland, Victor (II)', 'Devon, Tony', 'Bosco, Mario', 'Van Der Wal, Michel', 'Ruffalo, Mark', 'Lapaine, Daniel', 'Miller, George F.', 'Johnson, John (IV)', 'Friedman, Bruce Jay', 'Mark, Emmanuel', 'York, Michael (I)', 'Blacker, David', 'Fruitman, Jason', 'Miguel, Bruno', 'Binkley, James', 'Nascarella, Arthur J.', 'Baldwin, Heath Jacob', 'Trump, Donald', 'Sullivan, Sean Gregory', 'Reynolds, Anthony', 'Browne, Victor', 'Krystyan, Vieslav', 'Ingram, Chris (II)', 'Mathison, Cameron', 'Jenkins, Noam', 'Sudduth, Kohl', 'Sudduth, Skipp', 'MacVittie, Bruce', 'Garfunkel, Art', 'Myers, Mike (I)', 'Boccaletti, Andrea', 'Negin, Louis', 'Nuke, Steve', 'Bogdanovich, Peter', 'Phillippe, Ryan', 'Mundi, Coati', 'Taylor, Patrick (II)', 'Freeman, Morgan (II)', 'Bauer, Robert (III)', 'Henderson, Michael T.', 'Tensen, Justin', 'Goede, Jay', 'Grote, Andy', 'Hines, John (II)', 'Andrews, Jason (I)', 'Pitt, Michael (II)', 'Paige, Jordan', 'Carrier, Don', 'Lombardozzi, Domenick', 'Thorens, Drake', 'Meyer, Breckin', 'Enríquez, Jocelyn', 'Holt, Niki', 'Hayek, Salma', 'Crow, Sheryl', 'Rose, Crystal', 'Lilly, Kabriel', 'Giornofelice, Lina', 'Grenville, Georgina', 'Robinson, Aemilia', 'Johnson, Beverly (III)', 'Hutton, Lauren', 'Houston, Thelma', 'Amber (IV)', 'Lewis, Brooke (I)', 'Stringfield, Sherry', 'Kess, Georgina', 'Webb, Veronica', 'Risi, Michelle', 'Naté, Ultra', 'Vajakas, Lena', 'Longley, Janine', 'Miller, Ilana', 'Van Der Wal, Frederique', 'Griffin, Mary (II)', 'Boyd, Sheila', 'Radecki, Barbara', 'Alexander, Erika', 'Ling', 'Campbell, Neve', 'Albertini Dow, Ellen', 'Klum, Heidi', 'Matarazzo, Heather', 'Luft, Lorna', 'Bagley, Lorri', 'Rousseau, Sophie (I)', 'Perrine, Valerie', 'Crawford, Cindy (I)', 'Catalano, Laura', 'Torgersen, Tone', 'Thomsen, Cecilie', 'Ward, Sela']
# 5x2 (2004) ['Chollet, Pierre', 'Brissart, Jean-Pol', 'Ruchmann, Marc', 'Tavassoli, Jason', 'Lonsdale, Michael (I)', 'Cesolari, Andrea', 'Freiss, Stéphane', 'Belkacem, Yannis', 'Angloni, Carlo-Antonio', 'Neisser, Jean', 'Sannino, Domenico', 'Chappey, Antoine', 'Fabian, Françoise', 'Pailhas, Géraldine', 'Kherris, Eliane', 'Bruni Tedeschi, Valeria', 'Brétécher, Ninon', 'Debrun, Sylvie', 'Fouquet, Marie-Madeleine']
# ...
# Money Pit, The (1986) ['Ponazecki, Joe', 'Rath, Lutz (I)', 'Metzman, Irving', 'Plavin, Doug', 'Pierce, Wendell', 'Tuttle, Chris', 'Serrano, Nestor', 'Smirnoff, Yakov', 'Balin, Joey', 'Lombardo, Billy', 'Omilami, Afemo', 'Backer, Brian', 'Watson, Douglass', 'Maraden, Frank', 'Hyde, Michael (I)', 'Dimant, Grisha', 'Starr, Mike (I)', 'Iannone, Bruno', 'Godunov, Alexander', 'Baker, Henry Judd', 'Jeter, Michael', 'Faison, Frankie', 'Gavor, Radu', 'Hanks, Tom', 'Filiault, Tom', 'Wolffe, Tazariah', 'Ma, Tzi', 'Russo, Michael (I)', 'Bosco, Philip', 'Van Dreelen, John', 'Caridi, Carmine', 'Mantegna, Joe', 'Steinfeld, Jake', 'Foster, Ron (I)', 'Cowles, Matthew', 'Tremont, Mike', 'Vadas, Ed', 'Turchin, Scott', 'Altshuld, Alan', 'Mostel, Josh', 'West, Leslie', 'Wilson, Mary Louise', 'Stapleton, Maureen', 'Browning, Susan', 'Dillon, Mia', 'Dobrin, Lucille', 'Robey, Louise', 'Brooks, J. Cynthia', 'Agbayani, Tetchie', 'Long, Shelley']
# Money Talks (1997) ['Benninghoffen, Mark', 'Hankin, Larry', 'Brown, Andre Rosey', 'McLain, David Lee', 'Gleason, Paul (I)', 'Martin, Johnny (I)', 'Chapa, Damian', 'Hooker, Buddy Joe', 'Tucker, Chris (I)', 'Sheen, Charlie (I)', 'Noyce, Richard', 'Guyot, Paul', 'Chardiet, Jon', 'Berberian, Vahe', 'Odum, Ralph W.', 'Briggs, Gary (I)', 'Brockton, Jeff', 'Dean, Robertson', 'Nicosia, Mojoe', 'Tucker, Dexter', 'Love, Faizon', 'Brandstein, Matt', 'Levy, Marty', 'Warner, David (I)', 'Howard, Rance', 'Thal, Tycho', 'Tucker, Norris', 'Wright, Michael (I)', 'Anderson, Nathan (I)', 'Lowe, Kevin (I)', 'Jake (I)', 'Llewelyn, Doug', 'Huff, Tommy J.', 'Ismaël, Gérard', 'Roebuck, Daniel', 'Gage, Edward James', 'Ferrerira, Victor', 'Price, Gary (I)', 'Bruynbroek, Frank', 'Sorvino, Paul', 'Cartwright, Veronica', 'Little, Tawny', 'Berberian, Vance', 'Locklear, Heather', 'Comarcho, Melanie', 'Paulin, Viveca', 'Neal, Elise']
# Money Train (1995) ['Tawil, David', 'Blake, Robert (I)', 'Cenatiempo, John', 'Thomas, John Norman', 'Colantoni, Enrico', 'Gilliard Jr., Larry', 'Bacino, Joe', 'Soto, Jose (I)', 'Cooper, Chris (I)', 'Grove, Richard (I)', 'Backman, Anthony', 'McKinney, Gregory', 'Zúñiga, José (I)', 'Nunn, Bill', 'Ryan, Ron', 'Harrelson, Woody', 'Artura, Michael', 'Siverio, Manny', 'Gill, Cody', 'Alexander, Flex', "O'Connell, Jack (II)", 'Kolpan, Mitch', 'McKinley, Scott', 'Charlton, William (I)', 'Norris, Dean', 'Weil, Mark', 'Sudduth, Skipp', 'Pastore, Vincent', 'Grifasi, Joe', 'Vasquez, Nelson', 'Waites, Thomas G.', 'Snipes, Wesley', 'Roberts, Jeremy (I)', 'Ayesu, Joseph Wilson', 'Caban, Angel', 'Sowers, Scott', 'Williams, Keith Leon', 'Laresca, Vincent', 'Porter, Moss', 'Patrick, Vincent (II)', 'Young, Christopher Anthony', 'Stein, Saul', 'Brown, Kevin Guy', 'Randazzo, Steven', 'Lopez, Jennifer (I)', 'Dudley, Catherine', 'Mark, Leikili', 'Turturro, Aida', 'Guess, Alvaleta', 'Schaffer, Sharon', 'Gill, Katie', 'Lampley, Oni Faida']
# Monkey Business (1931) ['Barber, Bobby (I)', 'White, Leo (I)', 'Clark, Davison', 'Hall, Sherry', 'Marx, Groucho', 'Flosso, Al', 'Willis, Leo', 'Bradbury Jr., James', 'Ring, Cyril', 'Romanoff, Constantine', 'Fries, Otto', 'Minjir, Harold', 'Sullivan, Frederick', 'Marx, Harpo', 'Baker, Eddie (I)', 'Taggart, Ben', 'Bletcher, Billy', 'Sedan, Rolfe', 'Dunn, Bobby (I)', 'Marx, Zeppo', 'Harmon, Pat', "O'Brien, William H.", 'Borden, Eddie', 'Kennedy, Tom (I)', 'Marx, Sam (II)', 'Fellowes, Rockliffe', 'Chevalier, Maurice (I)', 'Marx, Chico', 'Woods, Harry', 'Laidlaw, Ethan', 'Cunningham, Cecil', 'Castle, Maxine', 'Todd, Thelma', 'Flowers, Bess', 'Pierce, Evelyn', 'Mineau, Charlotte', 'Hall, Ruth (I)']
# Monkey Business (1952) ['Maxey, Paul', 'Carter, Harry (II)', 'Lee, Rudy', 'Goodman, Terry (I)', 'Keating, Larry (I)', 'Roebuck, Jimmy', 'Little, Mickey', 'Moore, Roger (II)', 'Paris, Jerry', 'Williams, Mack (I)', 'McKee, John (II)', 'Coburn, Charles', 'Letondal, Henri', 'Bartell, Harry', 'Greer, Dabbs', 'Clark, Ronnie', 'Hawks, Howard', 'Soule, Olan', 'Cornthwaite, Robert', 'Eldredge, George', 'Winslow, George', 'McLean, Bill', 'Carey Jr., Harry', 'Clark, Russ (I)', 'Spencer, Douglas', 'Mell, Joseph', 'Lettieri, Louis', 'Murray, Forbes', 'Nichols, Robert (I)', 'Stratton, Gil', 'Morrow, Brad', 'Minardos, Nico', 'Sheldon, Jerry', 'Grant, Cary', 'Conklin, Heinie', 'Seymour, Harry', 'Montgomery, Ray (I)', 'Marlowe, Hugh', 'Lynn, Emmett', 'Warren, Ruth', 'Prickett, Maudie', 'Austin, Charlotte', 'Rogers, Ginger', 'Monroe, Marilyn', 'Plowman, Melinda', 'Holliday, Marjorie', 'Dale, Esther', 'Binney, Faire', 'Withers, Isabel', 'Carey, Olive', 'Freeman, Kathleen (I)']
# Monkeybone (2001) ['Brotherton, Phil (I)', 'Panterra, Tony', 'Laderach, Leon', 'Gil, Arturo', 'Mitchell, Mike (I)', 'Turturro, John', 'Marshall, Skyler', 'Hedger, Leslie', 'Jackson, Roger (VI)', 'Hammond, Michael L.', 'Foley, Dave (I)', 'Kundig, Jim', 'Burns, Brendan', 'Knowles, Harry Jay', 'St. Michael, Jody', 'Franciosa, Christopher', 'Outerbridge, Jen Sung', 'Logan, Kristopher', 'Guiles, Paul', 'Rogers, Scott (I)', 'Bosley, Randall', 'Gelfant, Alan', 'Kattan, Chris', 'Viniello, Mark', 'Assapiomonwait, Rachen', 'Volokh, Ilia', 'Pierce, Fred', 'Kilbane, Pat', 'Fuller, Frit', 'Roisman, Harper', 'Fuller, Frat', 'Donovan, Jamie', 'Fisher, Tom (I)', 'Esposito, Giancarlo', 'Maar, Pons', 'Wilderson, Wayne', 'Sylvain, John', 'Dingler, Jym', 'Jones, Doug (I)', 'Rooney, Ted (I)', 'Hogan, Chris (II)', 'Romano, Lou', 'Stein, Nathan (I)', 'Jackson, Michael Anthony', 'Church, Thomas Haden', 'Griffo, Joseph S.', 'Gleason, Toby', 'Reddick, Rex (I)', 'Poe IV, Edgar Allan', 'Odenkirk, Bob', 'Gardner, Peter (IV)', 'Fraser, Brendan', 'Masterson, Owen', 'Trautman, Allan', 'Steele, Brian (I)', 'Tilden, Leif', "Carpenter, Robert 'Duckie'", 'Kravits, Jason', 'Holmes, Ed', 'Tangen, Tom', 'Bruno, Jon', 'Workman, Scott', 'Ranft, Joe', 'Doba, Wayne', 'Lanoil, Bruce', 'King, Stephen (I)', 'Shaffer, Michelle', 'Soler, Dawn', 'Zane, Lisa', 'Torok, Dina', 'Goldberg, Whoopi', 'Fletcher, Anne (II)', 'Zahoryin, Tracy', 'Thomas-Palomino, Cris', 'Higgins, Amy (I)', 'Abebe, Meron', 'Norton, Kristin (I)', 'Mullally, Megan', 'Mink, Claudette', 'Milton, Melinda', 'Jones, Shawnee Free', 'Holmes, LaTonya', 'Rice, Caroline A.', 'Bishasha, Veena', 'Thigpen, Sandra', 'Fowler, Wendy', 'Bryan, Lindsay', 'Fonda, Bridget', 'Mizota, Diane', 'Lau, Etty', 'Stein, Mary (I)', 'Ebeyer, Lisa', 'Matta, Leslee Jean', 'Gudis, Erica', 'Kringelbach, Mie', 'Pine, Frankie', 'Watanbe, Miko', 'Azur, Sybil', 'Durst, Debi', 'Butler, Lucy', 'Timbers-Patteri, Kim', 'Armstrong, Lee (IV)', 'Gash, Jo Haugen', 'Tutt, Sunshine Deia', 'King, Anne (I)', 'McGowan, Rose', 'Boisse, Brooke']
# Mononoke-hime (1997) ['Rasner, David', 'Arquette, Lewis', 'Di Maggio, John', 'Thornton, Billy Bob', 'Satô, Mitsuru', 'McKenzie, Matt (I)', 'Burton, Corey', 'Fletcher, Jack (III)', 'DeMita, John', 'Watanabe, Tetsu', 'Schultz, Dwight', 'Crudup, Billy', 'Fraley, Pat (II)', 'Miller, Matt K.', 'Lee, John Rafter', 'Kondo, Yoshimasa', 'Nishimura, Masahiko', 'Hostetter, John', 'David, Keith (I)', 'Morishige, Hisaya', 'Miwa, Akihiro', 'Matsuda, Yôji', 'Fernandez, Alex (I)', 'Kamijô, Tsunehiko', 'McShane, Michael (I)', 'Kobayashi, Kaoru', 'Paul, Adam (I)', 'Nagoya, Akira', 'Fuji, Takako', 'Vogt, K.T.', 'MacNeille, Tress', 'Derryberry, Debi', 'Mosiman, Marnie', 'Lynn, Jessica (I)', 'Cihi, Jennifer', 'Pinkett Smith, Jada', 'Adlon, Pamela', 'Shimamoto, Sumi', 'Ishida, Yuriko', 'McGlynn, Mary Elizabeth', 'Ishii, Leslie', 'Fletcher, Julia', 'Mori, Mitsuko', 'Tanaka, Yûko', 'Driver, Minnie', 'Anderson, Gillian (I)', 'Lynn, Sherry (I)', 'Strong, Tara', 'Danes, Claire']
# Monsieur Ibrahim et les fleurs du Coran (2003) ['Sitbon, Jérémy', 'Caravaca, Eric', 'Vincent, Pascal (I)', 'Toumarkine, François', 'Merlin, Claude', 'Bôle du Chaumont, Gérard', 'Açikbas, Önder K.', 'Znyk, Daniel', 'Gallienne, Guillaume', 'Rannou, Guillaume', 'Le Lièvre, Manuel', 'Melki, Gilbert', 'Boulanger, Pierre (I)', 'Sharif, Omar', 'Naymark, Lola', 'Herbert, Sylvie', 'Deol, Maryse', 'Renauld, Isabelle', 'Debrun, Sylvie', 'Volkine, Tessa', 'Samie, Céline', 'Suarez, Anne', 'Gabin, Mata', 'Armelle, Françoise', 'Ahmadi, Marie-Sophie', 'Adjani, Isabelle']
# Monsieur Verdoux (1947) ["D'Arno, Albert", 'Norton, Barry (I)', 'Craven, James (I)', 'Frawley, William', 'Shaw, C. Montague', 'Cramer, Julius', 'Kenny, Colin', 'Self, William (I)', 'Petit, Albert', 'Karno Jr., Fred', 'Dee, George', 'Farnum, Franklyn', 'Stevens, Bert (I)', 'Abbott, Richard (I)', 'Nedell, Bernard', 'Smalley, Phillips', 'Hitler, Adolf', 'Granby, Joseph', 'Chambers, Wheaton', 'Lewis, Robert (I)', 'Wagenheim, Charles', 'Mills, Edwin', 'Sherwood, Millard', 'De Jonghe, Daniel', 'Watkin, Pierre', 'Schipa, Carlo', 'Reicher, Frank', 'Sayre, Jeffrey', 'Mussolini, Benito', 'Bacon, Irving', 'Vigran, Herb', 'Evans, Herbert', 'Crehan, Joseph', 'Irwin, Boyd', 'Dryden, Wheeler', 'Newlan, Paul', 'Richards, Addison', 'Hohl, Arthur', 'Ashe, Warren', 'Montgomery, Ralph', 'LeBaron, Bert', 'Delevanti, Cyril', 'Harmon, John (I)', 'Wilson, Tom (I)', 'Chaplin, Charles', 'Evans, Charles (IV)', 'Matthews, Lester', 'Leiber, Fritz', 'Heigh, Helene', 'Marshe, Vera', 'Lee, Ruth (I)', 'Conklin, Lois', 'Vallon, Nanette', 'Lyon, Therese', 'Dudgeon, Elspeth', 'May, Ada', 'Nash, Marilyn (I)', 'Elsom, Isobel', 'Bennett, Marjorie', 'Hoffman, Margaret', 'Purviance, Edna', 'Roddan, Allison', 'Morgan, Eula', 'Correll, Mady', 'Brissac, Virginia', 'Betz, Audrey', 'Slater, Barbara (I)', 'Sessions, Almira', 'Deegan, Josette', 'Ell, Christine', 'Raye, Martha', 'Ethridge, Ella', 'Ridgeway, Suzanne']
# Monsoon Wedding (2001) ['Laroiya, Jyotsana', 'Seth, Roshan', 'Gupta, Rajiv', 'Sindhu, Madan Bala', 'Bhattacharya, Dibyendu', 'Bandhu, Deepak Kumar', 'Bhadli, Nishi Singh', 'Sand, Paritosh', 'Kidwai, Rumaan', 'Moudgill, Milan', 'Capoor, Ambar B.', 'Kapur, Ram', 'Kapoor, Rajat', 'Arora, Jas', 'Jha, Pankaj', 'Chintamani, Nilambari', 'Nair, Vikram', 'Dabas, Parvin', 'Nair, Ishaan', 'Bhattacharya, Shubro', 'Raaz, Vijay', 'Nair, Urvashi', 'Hooda, Randeep', 'Suri, Rajiv', 'Khare, Motilal', 'Arya, Sameer', 'Vohra, Rahul', 'Bal, Rajeev', 'Chawla, Raman', 'B., Inderjit', 'Shah, Naseeruddin (I)', 'Kharbanda, Kulbhushan', 'Krishen, Mitva', 'Shome, Tilotama', 'Mathur, Mohini', 'Mehta, Veetu', 'Pandey, Ira', 'Chopra, Gita', 'Gyani, Rimlu', 'Kidwai, Kemaya', 'Singh, Sonali (I)', 'Nair, Mira', 'Chopra, Priya', 'Rastogi, Natasha', 'Khanna, Kamini', 'Khanna, Neelu', 'Shetty, Shefali (I)', 'Dehlvi, Himani', 'Sarin, Aparna', 'Nair, Sahira', 'Renuka', 'Dhawan, Sabrina', 'Prabhu, Lavanya', 'Bhushan, Vimla', 'Rekha (IV)', 'Dubey, Lillete', 'Singh, Reena (I)', 'Desoares, Sharda', 'Das, Vasundhara', 'Singh, Chitvan', 'Razdan, Soni', 'Dubey, Neha']
# Monster (2003) ['Blackwell, Rus', 'Ware, Tim', 'Coleman, Jim R.', 'Wilder, Glenn R.', 'Vaccarino, Chad', 'Vince, Pruitt Taylor', 'Brown, Adam (IV)', 'Stern, Jesse (I)', 'Hodder, Kane', 'Baker, Bubba', 'Rice, Brett', 'Macaulay, Marc', 'Boylan, Bill (I)', 'Gibston, Khris', 'Cannonball', 'Tergesen, Lee', 'Chamberlain, Robb', 'Pigott, T. Robert', 'Stephenson, Gene R.', 'St. John, Marco', 'Stokes, Christian', 'Wilson, Scott (I)', 'Dern, Bruce', 'Al (II)', 'Jones, Stephan', 'Donovan, Ed (I)', 'Ivey, Cree', 'Barcaski, Lyllian', 'McDonald, Lori (II)', 'Theron, Charlize', 'Stebbins, Elaine', 'Manville, Magdalena', 'Ricci, Christina', 'Corley, Annie', 'Riley, Kaitlin', 'Mangan, Catherine', 'Davis, Nonalee', 'Leigh, Chandra', 'Shaver, Romonda']
# Monster House (2006) ['Cannon, Nick (I)', 'Lee, Jason (I)', 'Heder, Jon (I)', 'Lerner, Sam (I)', 'James, Kevin (III)', 'Walker, Erik', 'Fahey, Matthew', 'Buscemi, Steve', 'McConnel, Ian', 'Musso, Mitchel', 'Willard, Fred', 'Musso, Marc', 'Schultz, Woody', 'Locke, Spencer (I)', 'Newman, Ryan (III)', 'Gyllenhaal, Maggie', 'Curran, Brittany', "O'Hara, Catherine (I)", 'Turner, Kathleen (I)']
# Monster Squad, The (1987) ['Barringer, Daniel W.', 'Anderson, Daryl (I)', 'Gries, Jon', 'Proval, David', 'Carl, Adam', 'Wendel, David', 'Regehr, Duncan', 'Gwillim, Jack', 'Donaldson, J. Mark', 'Faustino, Michael', 'MacKay, Michael Reid', 'Mattson, Denver', 'Thibault, Carl', 'Richards, Gwill', 'Chalem, Brent', 'Van Camp, Paul', 'LeFlore, Julius', 'Macht, Stephen (I)', 'Lively, Ernie (I)', 'Hervey, Jason', 'Noonan, Tom', 'Stephen, Jim', 'Lesser, Robert', 'Culotta, Phil', 'Lambert, Ryan', 'Cimino, Leonardo', 'Rebstock, Gary', 'Shaw, Stan (I)', 'Kestner, Bryan', 'Kiger, Robby', 'Gower, Andre', 'Woodruff Jr., Tom', 'Fuller, Lisa', 'Albee, Mary', 'De Camp, Marianne', 'Bank, Ashley', 'Trainor, Mary Ellen', 'Curtis, Sonia', 'Morgan, Charly', 'Baron, Brynn', 'Galayini, Riad', 'Merrill, Julie', 'Baron, Joan-Carrol', 'Lewis, Diana (II)']
# Monster's Ball (2001) ['Haven, James (I)', 'Cain, Marshall', 'Thornton, Billy Bob', 'Wilmot, John', 'Poret, Troy', 'Boyle, Peter (I)', 'Brown, Marcus Lyle', "Combs, Sean 'P. Diddy'", 'Def, Mos', 'Toups, T.J.', 'McConnell, John (I)', 'Smith, Paul (XVI)', 'LaGrange, Taylor', 'Montgomery, Ritchie', 'Johnson, Bernard (II)', 'Clements, Dennis', 'Ledger, Heath', 'Rokos, Will', 'Cowan Jr., Charles', 'Frederick, Anthony Michael', 'Lee, Larry (VIII)', 'Addica, Milo', 'Bean, Anthony', 'Calhoun, Coronji', 'Daniels, Clara Infinity', 'Witcher, Gabrielle', 'Loftin, Leah', 'Sutton, Carol', 'Simpson, Taylor', 'Kontomitras, Jeanette', 'Berry, Halle', 'Rules, Amber', 'Segal, Francine', 'Claire, Stephanie']
# Monster-in-Law (2005) ['Caccialanza, Lorenzo', 'Nardelli, Michael', 'Garritano, George', 'Dunham, Stephen', 'Gray, Bruce (I)', 'Scott, Adam (I)', 'Moses, Mark', 'Arnett, Will', 'Vartan, Michael', 'Jean-Louis, Jimmy', "L'Amore, Gianfranco", 'Nickel, Wayne', 'Stephens, Aaron', 'McLarty, Zach', 'Scott, Christopher (VIII)', 'Weihe, Tyson', 'Aylward, John', 'Kirkland, Mike (II)', 'Guiza, Monica', 'Poer, Marissa', 'Fraser, Tomiko', 'Wyss, Amanda', 'Flexer, Rochelle (III)', 'Masterson, Christina', 'Sykes, Wanda', 'Stritch, Elaine', 'Rowan, Pamela', 'Lopez, Jennifer (I)', 'Mazur, Monet', 'Mead, Amber', 'Harris, Harriet Sansom', 'Poer, Madison', 'Fonda, Jane', 'Wade, Jenny', 'Aldridge, Kristen', 'Waller, Wendy', 'Stewart, Kellee', 'Heller, Randee', 'Turner, Stephanie (II)', 'Parisse, Annie']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## 2) API HollywoodOracle

# %% [markdown]
# ##### A sua aplicação terá de suportar as operações listadas na API HollywoodOracle apresentada abaixo.

# %% [markdown]
# ##### 2.a) [1,5 valores] Descreva a estrutura de dados que utilizou para implementar a sua API. Apresente uma análise informal do espaço em memória total utilizado pela sua aplicação. Mais especificamente, indique quanto espaço de memória os atributos da sua classe HollywoodOracle ocupam em relação ao número de filmes e atores/atrizes que existem na base de dados analisada.
#
# Nota: Em relação ao espaço em memória, deve também apresentar uma estimativa do espaço real
# ocupado pela classe. Para isso, pode utilizar a função getsizeof() do módulo Python sys, e verificar o
# tamanho dos atributos do grafo construído e também de qualquer outro atributo que componha a sua
# implementação da classe HollywoodOracle.

# %% [markdown]
# ##### 2.b) [12 valores] Implemente cada uma das operações listadas na API HollywoodOracle abaixo. Para cada operação, deve apresentar uma análise informal da sua complexidade em relação ao tempo e ao espaço extra de memória utilizado (em relação ao número de filmes/atores).
#
# Nota 1: Pode haver vários caminhos de distância mínima entre o “centro do universo” e um ator qualquer. Neste trabalho, será suficiente apresentar um destes caminhos.
#
# Nota 2: Comece por testar cada um dos métodos com um ficheiro que tenha apenas 5-10 filmes antes de realizar testes na base de dados small_dataset.txt, para ter a certeza de que a sua resolução está
# correta. No relatório, apresente os resultados dos testes que foram realizados para cada método (exceto all_movies() e all_actors()) usando a base de dados small_dataset.txt.

# %%
#Correr para ver tabela presente no ponto 2.b) do enunciado
from PIL import Image
from IPython.display import display
img = Image.open('HollywoodOracle.png')
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=797x815>

# %%
class HollywoodOracle:

    def __init__(self, filename):
        # Obtém o grafo a partir do arquivo
        self.graph = build_graph_from_file(filename)
        self.center_of_universe = "Bacon, Kevin"

    def all_movies(self):
        """Devolve uma lista de todos os filmes no grafo."""
        movies = []
        for vertex in self.graph.vertices():
            if vertex.get_type() == "movie":
                movies.append(vertex.vertice())
        return movies

    def all_actors(self):
        """Devolve uma lista de todos os atores no grafo."""
        actors = []
        for vertex in self.graph.vertices():
            if vertex.get_type() == "actor":
                actors.append(vertex.vertice())
        return actors

    def movies_from(a):
        movies = a.get_neighbors()
        return movies

    def cast_of(m):
        cast = m.get_neighbors()
        return cast

    def set_center_of_universe(self, actor):
        self.center_of_universe = actor

    def number_of_X(self, a):
        path = self.path_to_X(a)
        total = 0
        for i in path:
            if i.get_type() == "actor":  # Conta apenas os vértices do tipo ator
                total += 1
        return total - 1  # Remove o ator inicial

    def path_to_X(self, a):
        return graph.shortest_path(self.center_of_universe, a)

    def max_number_of_X(self):
        max_number = 0
        for actor in self.all_actors():
            number = self.number_of_X(actor)
            if number > max_number:
                max_number = number
        return max_number

    def count_number_of_X(self, n):
        count = 0
        for actor in self.all_actors():
            number = self.number_of_X(actor)
            if number > n:
                count += 1
        return count

    def average_number_of_X(self):
        totalActors = len(self.all_actors())
        total = 0
        for actor in self.all_actors():
            numberX = self.number_of_X(actor)
            if numberX > 0:
                total += self.number_of_X(actor)
        return total / totalActors

# %%
# Testando a classe HollywoodOracle
oracle = HollywoodOracle('mini_dataset_utf8.txt')

# Testar o método all_actors
print(len(oracle.all_actors()))

# Testar o método get_all_movies
print(len(oracle.all_movies()))

#Testar o average_number_of_X
print(oracle.average_number_of_X())
# Out:
# 'Breaker' Morant (1980) ['Fitz-Gerald, Lewis', 'Steele, Rob (I)', 'Wilson, Frank (II)', "Tingwell, Charles 'Bud'", 'Cassell, Alan (I)', 'Rodger, Ron', 'Knez, Bruno', 'Woodward, Edward', 'Cisse, Halifa', 'Quin, Don', 'Kiefel, Russell', 'Meagher, Ray', 'Procanin, Michael', 'Bernard, Hank', 'Gray, Ian (I)', 'Brown, Bryan (I)', 'Ball, Ray (I)', 'Mullinar, Rod', 'Donovan, Terence (I)', 'Ball, Vincent (I)', 'Pfitzner, John', 'Currer, Norman', 'Thompson, Jack (I)', 'Nicholls, Jon', 'Haywood, Chris (I)', 'Smith, Chris (I)', 'Mann, Trevor (I)', 'Henderson, Dick (II)', 'Lovett, Alan', 'Bell, Wayne (I)', 'Waters, John (III)', 'Osborn, Peter', 'Peterson, Ron', 'Cornish, Bridget', 'Horseman, Sylvia', 'Seidel, Nellie', 'West, Barbara', 'Radford, Elspeth', 'Reed, Maria', 'Erskine, Ria', 'Dick, Judy', 'Walton, Laurie (I)']
# 'burbs, The (1989) ['Gage, Kevin', 'Hahn, Archie', 'Feldman, Corey', 'Gordon, Gale', 'Drier, Moosie', 'Theodore, Brother', 'Katt, Nicky', 'Miller, Dick (I)', 'Hanks, Tom', 'Dern, Bruce', 'Turner, Arnold F.', 'Howard, Rance', 'Ducommun, Rick', 'Danziger, Cory', 'Ajaye, Franklyn', 'Scott, Carey', 'Kramer, Jeffrey (I)', 'Olsen, Dana (I)', 'Gains, Courtney', 'Picardo, Robert', 'Hays, Gary', 'Davis, Sonny Carl', 'Gibson, Henry (I)', 'Jayne, Billy', 'Stevenson, Bill (I)', 'Katz, Phyllis', 'Vorgan, Gigi', 'Darbo, Patrika', 'Schaal, Wendy', 'French, Leigh', 'Fisher, Carrie', 'Benner, Brenda', 'Newman, Tracy (I)', 'Stewart, Lynne Marie', 'Haase, Heather (I)']
# 'Crocodile' Dundee II (1988) ['Carrasco, Carlos', 'Folger, Mark', 'Guzmán, Luis (I)', 'Ramsey, John (I)', 'Spindell, Ahvi', 'Creighton, Rhett', 'Shams, Homay', 'Yamamoto, Ronald', 'Asai, Hisayo', 'Serbagi, Roger', 'Skilton, Gerry', 'Skinner, Doug', 'Boutsikaris, Dennis', 'Crivello, Anthony (I)', 'Arvanites, Steven', 'Jbara, Gregory', 'Holt, Jim (I)', 'Vasquez, Alberto (I)', 'Batten, Tom (I)', 'Rios, Julio', 'Wilson, Alec', 'Jerosa, Vincent', 'Mercurio, Gus', 'Arriaga, Luis', 'Segura, Fernando', 'Dingo, Ernie', 'Sandy, Bill', 'Hogan, Paul (I)', 'Ruiz, Anthony (I)', 'Andrews, Jose', 'Alexander, Jace', 'Ubarry, Hechter', 'Cooper, Jim (I)', 'Soriero, Jim', 'Cooper, Sam (I)', 'Fernández, Juan (I)', 'Rackman, Steve', 'Meillon, John', 'Krivak, Bryan', 'Dutton, Charles S.', 'Saunders, Mark (I)', 'Maldonado, Edwin', 'Yasuda, Doug', 'Root, Stephen (I)', 'Cerullo, Al', 'Welsh, Kenneth', 'Quinn, Colin', 'Essman, Susie', 'Castle, Angela', 'Cox, Hannah', 'Blinco, Maggie', 'Lane, Rita', 'Sokol, Marilyn', 'Crittenden, Dianne', 'Kozlowski, Linda', 'Rockafellow, Stacey', 'Ali, Tatyana', 'Rogers, Maria Antoinette', 'Bobbit, Betty']
# (T)Raumschiff Surprise - Periode 1 (2004) ['Danner, Olaf', 'Queck, Maverick', 'Lesotho, Albee', 'Herbig, Michael', 'Dumont, Sky', 'Herbst, Christoph Maria', 'Terpoorten, Sigi', 'Hallwachs, Hans Peter', 'Grap, Klaus-Peter', 'Wolf, Thorsten', 'Gladhart, Eric', 'Trotman-Harewood, Errol', 'Van Ulzen, Herman', 'Silbermann, Hans-Jürgen', 'Schreiner, Jumbo', 'Bischoff, Marc', 'Sikder, Stephen', 'Schöne, Reiner', 'Figl, Anton', 'Jones, Sirone', 'Geier, Conrad F.', 'H2O2', 'Kobus, Waldemar', 'Tramitz, Christian', 'Rigauer, Gerd', 'Schweiger, Til', 'Rossié, Michael', 'Kavanian, Rick', 'Wilde, Tim', 'Rehberg, Hans-Michael', 'Seifert, Andreas', 'Herold, Diana', 'Bartholomäus, Heidrun', 'Beyeler, Brigitte', 'Schubert, Edeltraud', 'Widmer, Stacia', 'Kling, Anja']
# *batteries not included (1987) ['Vasquez, David (I)', 'Schwary, Ronald L.', 'Renensland, Howard', 'Arceri, John', 'Boutsikaris, Dennis', 'Carmine, Michael (II)', 'Guzmán, Luis (I)', 'Santana, José Angel', 'Raymond, Charles (II)', 'Pankow, John', 'Aldredge, Tom', 'Cronyn, Hume', 'Kurtz, Shelly (I)', 'LeGros, James', 'Martinsen, Dick', 'DiSanti, John', 'Hamer, Joe', 'Colon, Riki', 'Greene, Michael (I)', 'Dixon, MacIntyre', 'Imparato, Jon', 'Dear, H. Clay', 'McRae, Frank', 'Shoffner, Susan', 'Belack, Doris', 'Grafe, Judy', 'Hoffman, Jane (I)', 'Beardsley, Alice', 'Schaal, Wendy', 'Peña, Elizabeth', 'Tandy, Jessica']
# ...And Justice for All (1979) ['Blackmore, Stephen', 'Zwerling, Darrell', 'Christian, Robert', 'Forsythe, John (I)', 'Bogazianos, Vasili', 'Clute, Sidney', 'Sliwka, Frank', 'Gorrin, Michael', 'Bryggman, Larry', 'Pistilli, Carl', 'North, Alan', 'Currier, Terrence', 'Tambor, Jeffrey', 'Aquino, John (I)', 'Duncan, Angus', 'Hollander, Jack', 'Quinn, Tom (II)', 'Scott, Newton', 'Symonds, Robert', 'Saiontz, Donald', 'Levene, Sam (I)', 'Davy, Walter (II)', 'Andes, Keith', 'Patterson, Kenneth (I)', 'Warden, Jack', 'Beck, Vincent', 'Williams, Jonathan (XI)', 'Polk, Bill (I)', 'Strasberg, Lee', 'Waites, Thomas G.', 'Siebert, Charles (I)', 'Harris, Baxter', 'Haymer, Johnny', 'Pacino, Al', 'Morton, Joe', 'Arnold, Victor (II)', 'Dunbar, Julius', 'Nelson, Craig T.', 'Hawkins, McLindsey', 'Chianese, Dominic', 'Hertzler, J.G.', 'Cartwright, Bonita', 'Sanders, Beverly', 'Wooten, Terri', 'Kohler, Molly', 'Sawyer, Connie (I)', 'Lahti, Christine', 'Council, Allisha', 'Forbes, Angelyn', 'Schurr, Cathleen', 'Fredricks, Rita']
# 10 (1979) ['Anderson, Adam (I)', 'Hawker, John (I)', 'Calfa, Don', 'Carr, Laurence', 'Noble, James (I)', 'Hancock, John (I)', 'Sullivan, Owen (I)', 'Chase, Gregory', 'Jones, Sam J. (I)', 'Chappell, John (I)', 'Colombatto, S. (I)', 'Byrnes, Burke', 'Webber, Robert (I)', 'Kassul, Art', 'Dennehy, Brian', 'Moore, Dudley', 'Goldman, Lorry', 'Sheehan, Doug', 'Daly, Rad', 'Tanney, Herb', 'Showalter, Max', 'López, J. Víctor', 'Alton, Walter George', 'Champion, Michael', 'Lucking, William', 'Linton, Jon', 'Rosenberg, Arthur', 'Le May, Dorothy', 'White, Debbie (I)', 'Aron, Adrian', 'Derek, Bo', 'Farrell, Lynn', 'Andrews, Julie (I)', 'Wallace, Dee (II)', 'Bowman, Gail', 'Arnette, Jeanetta', 'Gorman, Mari', 'Chess, Lisa', 'Rush, Deborah', 'DeCarlo, Kitty', 'Cassidy, Sheila', 'Ashland, Camila', 'Serena (I)', 'Crosby, Denise', 'Zak, Sherri', 'Volz, Nedra', 'Royale, Candida', 'Alter, Julie', 'Haven, Annette', 'Galardo, Yolanda', 'Hanson, Marcy', 'Clark, Ellen', 'Ellis, Antonia (I)', 'Money, Constance', 'Kiser, Virginia', 'Farren, Vivian']
# 10 Things I Hate About You (1999) ['Kennedy, Aidan', 'Inglis, Joster', 'Ledger, Heath', 'Mosley, Dennis', 'Therol, Aaron', 'Karczag, Ari', 'Thorpe, Joshua', 'Hood, Brian', 'Gordon-Levitt, Joseph', 'Jackson, Greg (II)', 'Brown, Nick (IV)', 'Johnson, J.R.', 'Fraser, Cameron (I)', 'Bennett, Tim (III)', 'Mashburn, Brian', 'Junger, Gil', 'Eisenstein, Michael (II)', 'Cease, Kyle', 'Butler, Todd', 'Dyer, Jesse', 'Laurance, Benjamin', 'Muller, Travis', 'Kountz, Daniel', 'Kimbrough, Demegio', 'Riedmann, Eric (I)', 'Vukelic, Nick', 'Lacamara, Carlos', 'Houston, Tarance', 'Keegan, Andrew', 'Krumholtz, David', 'Maixner, Quinn', 'Miller, Larry (I)', 'Mitchell, Daryl', 'Leisure, David', 'Taylor, Heather (I)', 'Stiles, Julia', 'Evans, Alice (II)', 'Quinn, Jelani', 'Union, Gabrielle', 'Kajlich, Bianca', 'Powell, Monique', 'Gottlieb, Wendy', 'Janney, Allison', 'Kenny, Laura', "O'Neill, Bridget (III)", 'Oleynik, Larisa', 'Hanley, Kay', 'Pratt, Susan May', 'Mackay, Alisa', 'Matthews, Amber']
# 100 Girls (2000) ['Green, Johnny (V)', 'Michael, Terence (I)', 'Green, Donald (II)', 'Bleiberg, Ehud', 'Courtney, Dustin', 'Szmanda, Eric', 'Tucker, Jonathan (I)', 'Bustard, Chris', 'Howard, Walker', 'Nagel, Seth', 'Davila, Edward', "O'Hara, John (VIII)", 'Ross, Bradley K.', 'Corpas, Londonn', 'Madalone, Dennis', 'Payne, Allen (II)', 'DeBello, James', 'McNet, Mike', 'Herold, Kristin', 'Chriqui, Emmanuelle', 'Marina, Anya', 'Krinsky, Tamara Lee', 'Angelini, Josephine', 'Patterson, Deenah', 'Bozilovic, Ivana', 'Elahna, Sonnie', 'Farrokh, Farinaz', 'Grant, Tanisha', 'Lindquist, Kerstin', 'Hiraizumi, Gina', 'Rey, Adrienne', 'Rullo, Cynthia', 'Hoover, Danielle', 'Houston, Holly', 'James, Susan (II)', 'Billman, Ange', 'Ramos, Stephanie', 'Ribisi, Marissa', 'Thomas, Anita', 'Oleynik, Larisa', 'Mercedes, Alley', 'Blair, Joan (III)', 'Castro, Lydia', 'Mars, Felicity', 'Pho, Lon', 'Brandon, Madison', 'Gonzalez, Esther (I)', 'Heigl, Katherine', 'Anderson, Lorie Katherine', 'Evangelisti, Noel', 'Musiala, Agnieszka', 'Ortiz, Dorlinda', 'Mars, Rainbeau', 'Filipovic, Biljana', 'Steger, Julieanne', 'Huarte, Monica', 'Fioretta, Amy', 'Graham, Aimee', 'Tyranny, Tanya', 'Carmichael, Sarah', 'Pressly, Jaime', 'Fried, Cindy', 'Khomute, Anna', 'Anapau, Kristina', 'Walters, Nancy (II)', 'Clough, Patty', 'McLaren, Reilly', 'Gray, Laura', 'Severson, Candra', 'Kwon, Crystal', 'Strain, Maria', 'Reeves, Kimberly']
# 101 Dalmatians (1996) ['Peters, John (I)', 'Paris, Gerald', 'Haddigan, Mark', 'Shrapnel, John', 'McInnerny, Tim', 'Daniels, Jeff (I)', 'Fraser, Hugh (I)', 'Williams, Mark (I)', 'Percival, Michael (I)', 'Benfield, John', 'Mullard, Arthur', 'Capron, Brian', 'Lacey, Joe', 'Evans, John (II)', 'Laurie, Hugh', 'Readman, Andrew', 'Phillips, Neville', 'Weiss, Zohren', 'Stewart, Bill (I)', 'Welker, Frank', 'Braid, Hilda', 'Mason, Margery', 'Richardson, Joely', 'Close, Glenn', 'Plowright, Joan']
# 101 Reykjavík (2000) ['Ólafsson, Ólafur Darri', 'Einarsson, Pétur (I)', 'Guðjónsson, Bjarki', 'Sigurðsson, Atli Rafn', 'Sigurðarson, Jóhann', 'Valsson, Konráð', 'Jonsson, Hilmar', 'Sigurbjörnsson, Sigurður Pálmi', 'Egilsson, Agnar Jón', 'Þorvaldsson, Guðmundur Ingi', 'Hattari, Rósi', 'Eyjólfsson, Gunnar', 'Guðnason, Hilmir Snær', 'Sighvatsson, Sturla', 'Gunnarsson, Þröstur Leó', 'Ægisson, Steinar V.', 'Haraldsson, Ingi', 'Armannsson, Benedikt Ingi', 'Ulfsson, Ólafur Evert', 'Baltasarsson, Baltasar Breki', 'Gunnarsson, Gunnar H.', 'Kormákur, Baltasar', 'Gylfason, Halldór', 'Erlendsson, Eyvindur', 'Einarsson, Cosimo Heimir F.', 'Johnson, Elmar', 'Karlsson, Eyvindur', 'Þorsteinsson, Jón Pétur', 'Heldadóttir, Sigríður', 'Bjarnadóttir, Guðrún María', 'Vilhjálmsdóttir, Þrúður', 'Gunnarsdóttir, Ingibjörg', 'Valdimarsdóttir, Inga Maria', 'Þórarinsdóttir, Lilja Nótt', 'Maríasdóttir, Guðrún Ósk', 'Anderson, Fida Bonnie', 'Helgadóttir, Dagbjört Rós', 'Jökulsdóttir, Esther', 'Hjaltadóttir, Charlotta Maria', 'Yngvadóttir, Sólrún', 'Gunnarsdóttir, Lilja Björg', 'Björnsdóttir, Halldóra', 'Guðnadóttir, Ragnhildur', 'Abendorth, Monica', 'Sigurbjörnsdóttir, Sól', 'Steinarsdóttir, Berglind', 'Kristjánsdóttir, Lísa', 'Ólafsdóttir, Jónína', 'Þorvaldsdóttir, Elín', 'Karlsdóttir, Hanna María', 'Backman, Edda Heidrún', 'Gunnarsdóttir, Kristín Hrönn', 'Abril, Victoria']
# 102 Dalmatians (2000) ['Crompton, Ben', 'Ruskin, Ian', 'Shale, Kerry', 'Willcox, Tim', 'Depardieu, Gérard', 'Cook, Ron (I)', 'Richardson, Ian (I)', 'Meaney, Nick', 'Horovitch, David', 'Gruffudd, Ioan', 'Bluto, Tony', 'Mason, Jack (III)', 'Carter, Jim (I)', 'Simon, Charles (II)', 'Hayley, Mike', 'Gomez, John (II)', 'Lawson, Thierry', 'Brannick, Dick', 'Ball, Sherwood', 'Boo Khoo, Ian', 'Hutchison, Nicholas (I)', 'West, Timothy', 'Idle, Eric', 'Futcher, Hugh', 'Blanc, JB', 'Styles, John', 'McInnerny, Tim', 'Annaiis, Delphine', 'MacReady, Carol', 'Mills, Ann (I)', 'Vale, Tessa', 'Evans, Alice (I)', 'Phillips, Dorothea', 'de Turckheim, Delphine', 'Close, Glenn', 'Kewer, Suzy', 'Watson, June', 'Carter, Carmen', 'Bridgeman, Julia']
# 11'09''01 - September 11 (2002) ['Idani, Rodrigue André', 'Taguchi, Tomorowo', 'Seksan, Aleksandar', 'Sheffey, George R.', 'Allende, Salvador', 'Russo, Tomer', 'Pinochet, Augusto', 'Vega, Vladimir', 'Levo, Liron', 'Folikoue, Lionel Gaël', 'Baral, Anil', 'Adlah, Taleb', 'Ogata, Ken', 'Guire, Lionel Zizréel', 'Borgnine, Ernest', 'Bassinga, René Aimé', 'Tamba, Tetsuro', 'Bush, George W.', 'Haroun, Ahmed', 'Bawa, Kapil', 'Kissinger, Henry', 'Emoto, Akira', 'Horry, Jérôme', 'El-Sherif, Nour', 'Traoré, Alex Martial', 'Bern, Jake', 'Mor, Keren', 'Azmi, Tanvi', 'Mooney, Nell', 'Baisho, Mitsuko', 'Aso, Kumiko', 'Laborit, Emmanuelle', 'Sojic, Tatjana', 'Karimi, Maryam (I)', 'Pinjo, Dzana']
# 11:14 (2003) ['Foster, Ben (I)', 'Thomas, Henry (I)', 'Segel, Jason', 'Swayze, Patrick', 'Hatosy, Shawn', 'Sands, Stark (I)', 'Hanks, Colin', 'Gomez, Rick (II)', 'Gregg, Clark', 'Heron, Blake', 'Hershey, Barbara', 'Cook, Rachael Leigh', 'Swank, Hilary']
# 12 Angry Men (1957) ['Fiedler, John (I)', 'Kelly, James (V)', 'Sweeney, Joseph (I)', 'Savoca, John', 'Bond, Rudy', 'Binns, Ed', 'Cobb, Lee J.', 'Voskovec, George', 'Marshall, E.G.', 'Balsam, Martin', 'Klugman, Jack', 'Warden, Jack', 'Begley, Ed (I)', 'Fonda, Henry', 'Webber, Robert (I)', 'Nelson, Billy (I)']
# 13 Going on 30 (2004) ['Black, Alex (I)', 'Horton, Ward', 'Pfaff, Shambo', 'Kotsatos, Bill', 'Pedron, Luis (I)', 'Rambo, Bubba Dean', 'Cohn, Jeffrey Shane', 'Higgins, Michael William', 'Diorio, Keith', 'White, Kevin D.', 'Reeves, Phil', 'Grifasi, Joe', 'Summers, Stewart', 'Jobrani, Maz', 'Grant, John W.', 'Serkis, Andy', 'Yribar, Jason', 'Pavel, Philip', 'Marquette, Sean', 'Calmettes, Fabrice', 'Burke, Justin (I)', 'Otcasek, Eron', 'Gaffigan, Jim', 'Barford, Ian', 'Armas, Adrian', 'Henschel, Brandon', 'Ball, Samuel (I)', 'Whitebear, Richard', 'Ruffalo, Mark', 'Pomichter, James', 'Anderson, Timothy (II)', 'Wright, Darrel W.', 'Caldwell, Douglas', 'Tiemann, Brad', 'Stea, Kevin Alexander', 'Vigus, Larry', 'Hine, George', 'Makely, Jason', 'Allen, Christa B.', 'Swain, Sara', 'Michelle, Crystal', 'Olstead, Renee', 'Miller, Katie (I)', 'Curran, Brittany', 'Beaudoin, Sydni', 'Lee, Robinne', 'Wyatt, Kimberly', 'Chase, Corena', 'Sweeney, Kadee', 'Baker, Kathy (I)', 'Lusk, Megan', 'Mantegna, Gina', 'Ellis, Nadine', 'Roth, Julia', 'Warren, Kiersten', 'Greer, Judy', 'Bland, Rita', 'Cultraro, Candace Elaine', 'Collins, Lynn', 'Egan, Susan', "O'Meara, Nancy", 'DeBonis, Marcia', 'Garraway, Janina', 'Nall, Benita Krista', 'Gristak, Amber', 'Garner, Jennifer (I)', 'Hoffman, Irena A.', 'Rice, Caroline A.', 'Bachar, Carmit', 'Harper, Stacey (I)', 'Kyle, Alexandra', 'Guidarelli, Megan', 'Krell, Melody', 'Suyama, Michon', 'Sprung-Keyser, Madeline', 'Gleason, Mary Pat', 'Larson, Brie', 'Willes, Natalie', 'Combs, Catherine', 'Benson, Ashley', 'Loew, Sarah']
# 13th Warrior, The (1999) ['Jolly, Malcolm', 'Hausserman, Mischa', 'Elam, Scott', 'Sveinall, Oliver', 'Van der Driesen, Jeremy', 'Kulich, Vladimir', 'Hachlaf, Al', 'Southern, Daniel', 'Pedersen, Bjørn Ove', 'Acheson, Mark', "Riis, Asbjørn 'Bear'", 'Bulatti, Joe', 'Russell, Clive', 'Storhøi, Dennis', 'Angel, Chris', 'Zahara, Alex', 'Batal, Tarik', 'Maffin, Neil', 'Woodley, Dylan Gray', 'Jonsson, Michael', 'Wollter, Sven', 'Bremmer, Richard', 'Michaels, Greg (I)', 'Curtis, John Bear', 'Curran, Tony (I)', 'Skjavestad, Gunnar', 'Jensen, Brian (I)', 'Kavadas, Andrew', 'Thorsen, Sven-Ole', 'Andersen, Anders T. (I)', 'Sharif, Omar', 'Reyez, Brett', 'Banderas, Antonio (I)', 'DeSantis, John', 'Avari, Erick', 'Walstrom, Owen', 'Ooms, Richard', 'Mina, Mina E.', 'Woodington, Albie', 'Tazmini, Ghoncheh', 'Venora, Diane', 'Bavan, Yolande', 'Storhøi, Mona', 'Bonnevie, Maria', 'Lander, Alaina', 'Bertish, Suzanne', 'Alizada, Layla', 'de Zilva, Kaaren', 'Balke, Turid', 'Willis, Susan', 'Mohammed MacLeod, Natalia', 'Lapinskie, Clare', 'Gill, Akesh']
# 1492: Conquest of Paradise (1992) ['Waddington, Steven', 'Botto, Juan Diego', 'Langella, Frank', 'Mañas, Achero', 'Sullivan, Billy L.', 'Taylor, Jack (II)', 'Guillén Cuervo, Fernando', 'Dean, Loren (I)', 'Vidal, Albert', 'Ferrer, José Luis', 'Heffernan, John (I)', 'Rey, Fernando (I)', 'García Rimada, Fernando', 'Vosloo, Arnold', 'Wincott, Michael', 'Depardieu, Gérard', 'Assante, Armand', 'Margolis, Mark', 'Karyo, Tchéky', 'Moya, Bercelio', 'Salem, Kario', 'Dunn, Kevin (I)', 'Molina, Ángela', 'Rosal, Ángela', 'Montero, Maria Laura', 'Prinz, Isabel', 'Weaver, Sigourney', 'Montero, Silvia']
# 15 Minutes (2001) ['Alfieri, Joseph (II)', 'Dane, Ashton', 'Yelchin, Anton', 'Garibyan, Haik', 'DiResta, John', 'Field, Bobby', 'Haddad, Zuhair', 'Roden, Karel (I)', 'Andon, Kurt', 'Camello, Mike', 'Davis, Stephen (VIII)', 'Herman, Paul (I)', 'Handy, James', 'Caruso, Phillip V.', 'Arnett, Peter', 'Taktarov, Oleg', 'Brooks, Avery (I)', 'Grammer, Kelsey', 'Khan, Marco', 'Roché, Sebastian', 'Bush, Brantley', 'Burns, Edward (I)', 'McCrary, Darius', 'Blueian, Barry', 'Runyan, Tygh', 'Resnick, Floyd', 'Burns, William H.', 'Matthews Jr., Riley G.', 'Primus, Barry', 'Garcia, Louis F.', 'Cutler, Bruce', 'Lawrence, Everton', 'Fiore, Ben', 'Miller, George F.', 'Foster, Bryan (I)', 'De Niro, Robert', 'Dillin, Scott', 'Brown, Lennox', 'Stamboulis, Spero', 'Wall, Ron', 'Coster, Ritchie (I)', 'Poulos, George', 'Cohen, Alan (IV)', 'Casseus, Gabriel', 'Stanton, William (I)', 'Mashkov, Vladimir', 'Lisi, Joe (I)', 'Guzman, Jorge H.', 'Grier, David Alan', 'Warner, Malcolm-Jamal', 'Maglione, Dominic', 'Mulholland, Leda', 'Marin, Mindy', 'Mariani, Janean Christine', 'Colasanti, Rose', 'Greaves, Gail', 'Roseanne', 'Cattrall, Kim', 'Kalem, Toni', 'Gregoire, Celeste', 'Dobó, Kata', 'Burton-Oare, Jamie', 'Klieman, Rikki', 'Morgunova, Olga', 'Abrusci, Christine', 'Merced, Macy', 'Vann, Elma', 'Farmiga, Vera', 'Gasanova, Irina', 'Espinoza, Julieta', 'Mulqueen, Tracey', 'Kanakaredes, Melina', 'Velez-Mitchell, Jane', 'Evans, Noelle', 'Alexis, Sophia', 'Sauer, Dorit', 'Lopez, Sylvia (II)', 'Claibourne, Christine', 'Theron, Charlize', 'Ruiz, Lynette']
# 16 Blocks (2006) ['Campbell, Jimmy (I)', 'Morse, David (I)', 'Lima, Danny', 'Wenk, Richard', 'Dismond, Daryl', 'Paterson, Bradley', 'Roiz, Sasha', 'McRobbie, Peter', 'Formosa, Victor', 'Wong, Emerson', 'Nicholsen, J.D.', 'Sullivan, Jeremy J.', 'Ferguson, Aaron (IV)', 'McCarthy, Kevin P.', 'Scrymgeour, Alex', 'Donner, Richard', 'McCord, Scott', 'Fitzpatrick, Richard (I)', 'Bizik, Robert', 'Racki, Robert', 'Douglas, Scott (II)', 'Andersson, Brian', 'Alachiotis, Nick', 'Factora, Marshall', 'Siravo, Joseph', 'Li, Ben', 'Segovia, Michael', 'Collier, Richard (II)', 'Harris, Eli', 'Wulff, Ryan', 'Gibbons, Jess Mal', 'Rosario, Joe (II)', 'Otuomagie, Efosa', 'Gomez, Eduardo', 'Duic, Albert', 'Masciulli, Claudio', 'Zayas, David', 'Cozart, Cylk', 'DeBona, Joseph', 'McKeown, Denis', 'Tuerpe, Paul', 'Kung, Sam', 'Burke, Jason (I)', 'Pla, Conrad', 'McGuckian, Liam', 'Phillips, Cecil', 'Lee, Paul J.Q.', 'Moses, Sam', 'Keenan, Michael F.', 'Sander, Casey', 'Weithoff, Rob', 'Hoffman, Derek (I)', 'Wlaschiha, Tom', 'Wong, Will', 'Sparrow, David', 'Lavin, Jim (I)', 'Def, Mos', 'Louangxay, Kameron', 'Vellozzi, Sonny', 'Ubarry, Hechter', 'Henry, Bernie', 'Garrow, Patrick', 'Clohessy, Robert', 'Kahan, Steve', 'Read, Brian (II)', 'Chong, Jim', 'Vance, Schuster', 'Tolby, Joshua', 'Giacoman, Rolando Alvarez', 'Willis, Bruce', 'Chan, Kim (I)', 'Schleiffer, Norman', 'Talbolt, David', 'Fong, Tig', 'Kean', 'Lee, Alan (XII)', 'Chong, Betty', 'Pressley, Brenda', 'Dawn, Heather', 'Yuste, Beatriz', 'Ritter, Allison Lee', 'Russo, Talia', 'Lopez, Carmen', 'Craggs, Vicky', 'Mitchell, Victoria (I)', 'López, Carmen (I)', 'Labao, Cece Neber', 'Titova, Svetlana (II)', 'Orjalo, Christina', 'Stern, Jenna', 'Imrie, Kathy', 'Ellwand, Toni', 'Seto, Angela']
# 1776 (1972) ["O'Shea, Dick", 'Jentzsch, Heber', 'Duell, William', 'Hansen, William (I)', 'Madden, Donald', 'Forster, Peter (I)', 'Rhodes, Jordan', 'Holgate, Ron', 'Downs, Frederic', 'Rule, Charles', 'Bass, Emory', 'Hines, Patrick', 'Nathan, Stephen', 'Poole, Roy (I)', 'Cullum, John (I)', 'Holland, John (I)', 'Middleton, Ray', 'Keyes, Daniel (I)', 'Devol, Gordon', 'Howard, Ken (I)', 'Hill, Ralston', 'Moore, Jonathan (I)', 'De Mave, Jack', "O'Hara, Barry", 'Caine, Howard', 'Daniels, William (I)', 'Myhers, John', 'Leyden, Leo', 'Montgomery, Mark (I)', 'Da Silva, Howard', 'Noble, James (I)', 'Albin, Andy', 'Robbins, Rex', 'Slyter, Fred', 'Bassett, William', 'McMurray, Richard', 'Ford, David (I)', 'Vestoff, Virginia', 'Danner, Blythe']
# 1941 (1979) ['Tennant, Andy', 'Deezen, Eddie', 'Williams, Treat', 'Oates, Warren', 'Wolfington, Iggie', 'Fuller, Samuel', 'Cook Jr., Elisha', 'Aykroyd, Dan', 'McKee, John (II)', 'Rourke, Mickey', 'Olkewicz, Walter', 'Miller, Dick (I)', 'Beatty, Ned', 'Zika, Christian', 'Contreras, Luis (I)', 'Caan, James', 'Matheson, Tim (I)', 'Scott, Donovan (I)', 'Rydbeck, Whitney', 'Lander, David L.', 'Stander, Lionel', 'Lassick, Sydney', 'Houston, Robert (I)', 'Lang, Perry', 'Brian, Jordan', 'Cervantes, Gary', 'Carenzo, Vito (I)', 'Frishman, Brian (I)', 'Carlton, Mark', 'Thompson, Galen', 'McMillan, Ronnie', 'Lee, Christopher (I)', 'Cameron, Dave (II)', 'Calfa, Don', 'Shimizu, Hiroshi (II)', 'Cloud, Paul', 'Marias, Mark', 'Di Cicco, Bobby', 'McKean, Michael (I)', 'Belushi, John', 'Flaherty, Joe (I)', 'McNamara, J. Patrick', 'Hamilton, Murray (I)', 'Taylor, Dub (I)', 'Frederickson, Gray', 'Silva, Geno', 'Mitamura, Dr. Akio', 'Verroca, Frank', 'Hardin, Jerry', 'McNally, Dan', 'Thibeau, Jack', 'Voldstad, John', 'McRae, Frank', 'Landis, John (I)', 'Candy, John', 'Mond, Steven', 'Stack, Robert', 'Mifune, Toshirô', 'Pickens, Slim (I)', 'Beagle, E. Hampton', 'Gorman, Brad (I)', 'Taggart, Rita', 'Gannen, Barbara (I)', 'Molinari, Antoinette', 'Teefy, Maureen', 'Gaines, Marjorie', 'Kay, Dianne', 'Backlinie, Susan', 'Garland, Trish', 'Culver, Carol', 'LuPone, Patti', 'Williams, Carol Ann', 'Dooling, Lucinda', 'Hardin, Diane (I)', 'Gallup, Denise', 'Cheshire, Denise', 'Benson, Deborah (II)', 'Rothstein, Debbie', 'Marshall, Penny (I)', 'Sherman, Kerry', 'Gallup, Dian', 'Benson, Lucille', 'Sperber, Wendie Jo', 'Williams, Jenny (I)', 'Gary, Lorraine', 'Allen, Nancy (I)', 'Landers, Audrey']
# 2 Days in the Valley (1996) ['Daniels, Jeff (I)', 'Mazursky, Paul', 'Aiello, Danny', 'Stoltz, Eric', 'Horton, Peter (I)', 'Carradine, Keith', 'White, Michael Jai', 'Cruttwell, Greg', 'Stanton, William (I)', 'Williams, Cress', 'Tierney, Lawrence', 'Pendleton, Austin', 'Spader, James', 'Benson-Wald, Deborah', 'Hatcher, Teri', 'Mercurio, Micole', 'Luong, Kathleen', 'Theron, Charlize', 'Mason, Marsha', 'Maris, Ada', 'Fletcher, Louise', 'Headly, Glenne']
# 2 Fast 2 Furious (2003) ['Hauser, Cole', 'Brown, Troy (I)', 'Mann, Zachary L.', 'Perez, Jose (I)', 'Bolano, Tony', 'Auyeung, Jin', 'Maloof, Sam', 'Barry, Thom', 'Gibson, Tyrese', 'Nolasco, Amaury', 'Ludacris', 'Eubanks, Corey Michael', 'Boone Junior, Mark', 'Robinson, Troy', 'Gallini, Matt', 'Moritz, Neal H.', 'Etebari, Eric', 'Herreros, Mateo', "Foster, Walter 'Duke'", 'Walker, Paul (I)', 'Cenatiempo, John', 'Macaulay, Marc', 'Finlay, Edward (I)', 'Harper, Cobette', 'Ealy, Michael', "Sanchez, Roberto 'Sanz'", 'Remar, James', 'Hill, Tequilla', 'Agosto, Limary', 'Huffer, Bettina', 'Carroll, Tara', 'Dubuque, Nievecita', 'Ward, Sincerely A.', 'Tuyet Vo, Phuong', 'Jones, Tamara (I)', 'Mendes, Eva', 'Rafield, Felecia', 'Arreaga, Marianne M.', 'Aoki, Devon']
# 200 Cigarettes (1999) ['Janney, Eli', 'Rudd, Paul (I)', 'Merchant, Kiran', 'Vause, Stephen', 'Costello, Elvis', 'Meyers, Michael J.', 'Frederic, Patrick', 'Temple, Johnny (I)', 'Affleck, Casey', 'Díaz, Guillermo (I)', 'Stellate, Nick', 'McNally, Seamus', 'DuMont, James', 'Mohr, Jay', 'McCardie, Brian', 'Brown, Morgan (II)', 'Carr, Caleb', 'Johansen, David', 'McCloud, Scott (II)', 'Chappelle, Dave', 'Affleck, Ben', 'Fleisig, Alexis', 'Murphy, James F.', 'Berrebbi, Brian', 'Parker, Nicole Ari', 'Garofalo, Janeane', 'Searle, Kathy', 'Tavoularis, Oriana Nicole', 'Blong, Jenni', 'Love, Courtney', 'Kellner, Catherine', 'Wible, Patricia', 'Plimpton, Martha', 'Bonelli, Jamie', 'Featherstone, Angela', 'Hoffmann, Gaby (I)', 'Albano, Jennifer', 'Hudson, Kate (I)', 'Ricci, Christina']
# 20000 Leagues Under the Sea (1954) ['Graham, Fred (I)', 'Monaghan, T.', 'Helton, Percy', 'Douglas, Kirk (I)', 'Harvey, Harry (II)', 'Lukas, Paul', 'Mason, James (I)', 'Wilke, Robert J.', 'Vigran, Herb', 'Young, Carleton', 'Cooper, Ted (I)', 'Lummis, Dayton', 'de Corsia, Ted', 'Daheim, John', 'Lorre, Peter (I)', 'Marr, Eddie (I)', 'Kerrigan, J.M.', 'Stoney, Jack', 'Grodin, Charles (I)', 'Gargan, Jack', 'Pennick, Jack', 'Tarnell, S.', 'Pall, Gloria', 'Mitchell, Laurie']
# 2001: A Space Odyssey (1968) ['Miller, Frank (I)', 'Rain, Douglas', 'Paes, Darryl', 'Sullivan, Sean (I)', 'Beck, Glenn (I)', 'Dullea, Keir', 'Delmár, Péter', 'Hines, David (I)', 'Lockwood, Gary', 'Ashley, John (III)', 'Swindells, John', 'Grover, Danny (I)', 'Charkham, David', 'Scott, Kevin (I)', 'Amor, Martin (I)', 'MacKee, Scott', 'Marchant, Laurence', 'Beatty, Robert (I)', 'Kendall, Kenneth', 'Fleetwood, David (II)', 'Duggan, Terry (I)', 'Woods, Richard (II)', 'Bishop, Ed (I)', 'Davis, Simon (I)', 'Daw, Jonathan', 'Lovell, Mike', 'Jordan, John (X)', 'Wilyman, Bob', 'Wallace, Andy (I)', 'Richter, Daniel (I)', 'Bell, Jimmy (I)', 'Rossiter, Leonard', 'Hawley, Brian (I)', 'Clifford, John (I)', 'Sylvester, William', 'Weston, Bill (I)', 'Jackson, Tony (I)', 'Gifford, Alan', 'Anderson, S. Newton', 'Refalo, Joe', 'Tucker, Burnell', 'Marr, Krystyna', 'Marr, Irena', 'Pearl, Jane', 'Markham, Marcella', 'Neil, Kim', 'Francis, Penny', 'Tyzack, Margaret', 'Bormann, Ann', 'Hayward, Jane', 'Pearl, Penny', 'Croft, Julie', 'Gillis, Ann (I)', 'Carroll, Edwina', 'Downham, Heather', 'Kubrick, Vivian', 'Blount, Sheraton', 'Brahms, Penny']
# 2001: A Space Travesty (2000) ['Samuel, Martin (II)', 'Bisson, Jean-Marc', 'Tsar, Mike', 'Ducharme, Yvan', 'Millman, Jason', 'Suetsugu, Robert', 'Lenoir, Pierre (II)', 'Alon, Noam', 'Nielsen, Leslie', 'Laroche, Armand', 'Edwards, Pierre', 'Normandin, Stéphane', 'Stevens, Mark (XIV)', 'Canestrari, Perry', 'Papasoff, Charles', 'Campeau, Luc', 'El-Onsi, Kareem', 'Ghandi', 'Bérard, Alain', 'Dennis, Charles', 'Alvarez, Daniel (I)', 'Côté, Jean-Luc', 'Francis, David (I)', 'Jutras, Richard (I)', 'Schnurmacher, Tommy', 'Weissman, Jeffrey', 'Rainville, Paul', 'Fox, David (I)', 'Shearman, Alan', 'Ruiz, Carlos (I)', 'Vezina, Christian', 'Flatley, Michael (I)', 'Frappier, Dany', 'Egan, Peter (I)', 'Asato, Reid', 'Smiley, Matthew', 'Perron, Michel', 'Greggio, Ezio', 'Jordan, Don (I)', 'Millbern, David', 'Masson, Damien', 'Stone, Sam (I)', 'Hervieux, Marc', 'Jeperson, Rachel A.', 'Kamp-Groeneveld, Alexandra', 'Gray, Natalie', 'Winter, Ophélie', 'Dumolin-Shaw, Stephanie', 'Scarabelli, Michele', 'Feldbusch, Verona', 'Gravel, Mikael', 'Kay, Una', 'Hinz, Marion', 'Torsein, Annabelle', 'Farley, Marianne', 'Sherwood, Toni (I)', 'David, Ellen', 'Soo, Betsy', 'Davis, Cindy', 'Andre, Caroline', 'Barnwell, Teresa', 'Sudonim, Ima']
# 2010 (1984) ['McGarr, Gene', 'Dullea, Keir', 'Carroll, Larry (I)', 'Steinbach, Victor', 'Triska, Jan', 'Rain, Douglas', 'Elcar, Dana', 'Kramarov, Saveli', 'Baskin, Elya', 'Lesser, Robert', 'Balaban, Bob', 'Lithgow, John', 'Jaffe, Taliesin', 'Clarke, Arthur C.', 'Recasner, Ron', 'Scheider, Roy', 'Skomarovsky, Vladimir', 'McEachin, James', 'Rudnik, Oleg', 'Osborne, Madolyn Smith', 'Ware, Herta', 'Shneider, Natasha', 'Michaels, Delana', 'Carter, Cheryl', 'Deschanel, Mary Jo', 'Bergen, Candice', 'Mirren, Helen']
# 2046 (2004) ['Kimura, Takuya', 'Leung Chiu Wai, Tony', 'Ng, Ting Yip', 'Chang, Chen', 'McIntyre, Thongchai', 'Sum, Wang', 'Siu, Ping Lam', 'Gong, Li (I)', 'Cheung, Maggie', 'Zhang, Ziyi', 'Dong, Jie', 'Wong, Faye', 'Lau, Carina']
# 21 Grams (2003) ['Nichols, Nick (III)', 'Medina, Roberto (I)', 'Corrigan, Juan', 'Roberts, Barclay', 'Del Toro, Benicio', 'Harris, Antef A.', 'Schmidt, Jeff', 'Brown, Charlie B.', 'Irwin, Tom (II)', 'Chipman, Jerry', "O'Hare, Denis (I)", 'Marsan, Eddie', 'Guyton, Tony', 'Chapman, Kevin (I)', 'Bridgewater, Stephen', 'West, John Boyd', 'Johnson, Keith Lamont', 'Hartzog, Randall', 'Romero, Chance', 'Salter, Loyd Keith', 'Calderon, Paul (I)', 'Tran, Hai Quang', 'Huston, Danny', 'Alban, Carlo', 'Musso, Marc', 'Dee, Trent', 'Beech Jr., Wayne E.', 'Ingle, Rodney', 'Penn, Sean (I)', 'Shiver, Arron', 'Temple, Lew', 'Finnell, Michael', 'Vaughn, Tony', 'Finnell, Michael W.', 'Rubinstein, John', 'Chattam, David', 'Blair, Pamela', 'Branch, Tricia', 'Armstrong-Miles, Dorothy', 'Bishop, Sharon', 'Pfalzgraff, Jennifer', 'Herin, Anastasia', 'Watts, Naomi', 'Gainsbourg, Charlotte', 'Leo, Melissa', 'Pakis, Claire', 'Davenport, Verda', 'Corley, Annie', 'Trahan, Arita', 'Sanchez, Lisa', 'DuVall, Clea', 'Dent, Catherine', 'Delgado, Teresa (I)', 'Scott, Jessica (VII)', 'Nahon, Carly']
# 24 Hour Party People (2002) ['Haslam, Dave', 'Bowser, Mr. A.', 'Murray, Conrad', 'Pop, Iggy', 'Clarke, Nick (I)', 'Cilenti, Enzo', 'Pivaro, Nigel', 'Tighe, Darren', 'McNicholas, Joshua', 'Cook, Ron (I)', 'Simm, John', 'Kay, Peter (I)', 'Swan, Paul (II)', 'Wilson, Tony (II)', 'Salaman, Toby', 'Gorman, Dave (I)', 'Hancock, Martin (I)', 'Windows, Mark', 'Coogan, Steve', 'Smith, Mark E.', 'Little, Ralf', 'Waring, Raymond', 'Riley, Sam (II)', 'Hope, Dan', 'Lydon, John (I)', 'Coghill, Chris', 'Cross, Aidan', 'Coogan, Martin', 'James, Lennie', 'Considine, Paddy', 'Brydon, Rob', 'Boon, Clint', 'Roberts, Smug', 'Whitworth, Duncan', 'Severin, Steven', 'Roberts, Gary (IV)', 'Mani (III)', 'Allen, Keith (I)', 'Kennedy, Roger (III)', 'Johnson, Trevor (I)', 'Davey, Martin Nigel', 'Horrocks, Tim', 'Dino (IV)', 'Serkis, Andy', 'Ryder, Paul (II)', 'Ryder, Shaun', 'Cartwright, James (I)', 'Thomson, John (I)', 'Baker, Kenny (I)', 'Mitchell Jr., Michael', 'Pegg, Simon', 'Tildesley, Mark', 'Weller, Paul (I)', 'Pickering, Mike (I)', 'Devoto, Howard', 'Gunn, Peter (I)', 'Burnell, Jean-Jacques', "O'Brien, Kieran", 'Bell, Neil (I)', 'Eccleston, Christopher', 'Popplewell, Paul', 'Moscrop, Martin', 'Cernow, Sean', 'Harris, Sean (I)', 'Cunningham, Danny', 'Radcliffe, Naomi', 'Tyborczyk, Anna', 'Cooper, Collette', 'Sioux, Siouxsie', 'Henderson, Shirley (I)', 'Lever, Claire', 'Cunliffe, Tracy', 'Clarke, Margi', 'Kelly, Elizabeth (I)', 'Seymour, Terri', 'Schlesinger, Helen', 'Allen, Fiona', 'Magowan, Kate', 'Satchell, Rowetta']
# 25th Hour (2002) ['DeGennaro, Vinny', 'Orvis, Greg', 'Hoffman, Philip Seymour', 'Bergen, John', 'Palagonia, Al', 'Fortt, Guy A.', 'Reton, Daniel', 'Matthews, Frank (III)', 'Zhivotovsky, Igor', 'DJ Cipha Sounds', 'Norton, Edward (I)', 'Kelsch, Peter James', 'Modafferi, Louis', 'Mascall, Joseph', 'Palazzo, Jeffrey', 'Miller, Douglas (VII)', 'Cox, Brian (I)', "Jackson, Rodney 'Bear'", 'Prudius, Oleg Aleksandrovich', 'Spinghel, Radu', 'Wallace, Mark (I)', 'Taraseiwicz, Alan', 'Pierce, Jason (VII)', 'Mundi, Coati', 'Fiore, Mike (I)', 'Kuznetsov, Misha', 'Simon, Marc H.', 'Uchaneishvili, Levan', 'Diomede, Paul', 'Williams, Brad (V)', 'Rubeo, Ed', 'Bini, Carl', 'Bright, Keith (I)', 'Stanford, Aaron', 'Castillo, Doy Gabriel', 'Cecere, Sal', 'Siragusa, Tony', 'Illig, Patrick', "O'Neal, Patrice", 'Genet, Michael', 'Brazil, R.L.', 'Crowns, Howard', 'Fletcher, Andre', 'McCoy, A.J.', 'Devon, Tony', 'Whitlock Jr., Isiah', 'Pepper, Barry', 'Bullock, Lawrence', 'Rossomodo, Nicholas', 'Riesco, Armando', 'Nobbs, Keith', 'Pepe, Christine', 'Ferlito, Vanessa', 'White, Michole', 'Finley, Felicia', 'Spierer, Stacy Lynn', 'Darlow, Cynthia', 'Niles, Maja', 'Cornelisse, Tonya', 'Dawson, Rosario', 'Drekonja, Larissa', 'Paquin, Anna', 'Mullen, Jamil', 'Reston, Arloa', 'Ramirez, Dania', 'Rahman, Rumaisa']
# 28 Days (2000) ['Nayyar, Harsh', 'Gioiello, Bruno', 'Armstrong, Jack (I)', 'McCary, Rod', 'Taylor, Frank Hoyt', 'Byrd, Dan (I)', 'Santoni, Reni', 'Buscemi, Steve', 'Ponder, Brent', 'Dolan, Andrew', 'Cedeño, Matt', 'Wainwright III, Loudon', 'Dooly, Mike', 'Reitz, Ric', "O'Malley, Mike (I)", 'Moody, Jim (I)', 'Anagnos, Bill', 'Kelley, Elijah (I)', 'Tudyk, Alan', 'Wood, Stan', 'Mortensen, Viggo', 'West, Dominic', 'Pervis, Adam', 'Skye, Azura', 'Chapman, Judith', 'Yates, Suellen', 'Sutton, Lisa (I)', 'Reilly, Corinne', 'Chang, Christina', 'Payne, Kathy (I)', 'Perkins, Elizabeth (I)', 'Fairchild, Patricia M.', 'Pratt, Wendee', 'Bullock, Sandra', 'Martindale, Margo', 'McGuire, Maeve (I)', 'Scharf, Katie', 'Ladd, Diane', 'Krebs, Susan', 'Jean-Baptiste, Marianne', 'Davis, Suzanne (I)', 'Warrick, Brittani', 'Pankow, Joanne', 'Ruscio, Elizabeth', 'Deane, Meredith']
# 28 Days Later... (2002) ['Harnett, Ricci', 'Schneider, David (IV)', 'Knapp, Sebastian', 'Murphy, Cillian', 'Campbell, Marvin', 'Young, Steen', 'McQuarrie, Stuart', 'Mably, Luke', 'Dunne, Christopher', 'Rambaruth, Sanjay', 'Christopher, Adrian', 'Hiltunen, Jukka (I)', 'Lush, Jenni', 'Laniyan, Junior', 'Dwyer, Richard (I)', 'Hackney, Justin', 'Delamere, Alexander', 'Bill, Leo', 'Kasey, Paul', 'Rann, Jeffrey', 'Huntley, Noah', 'Eccleston, Christopher', 'Gleeson, Brendan', 'Lewis, Nicholas James', 'Sedgwick, Toby', 'Matthiae, Tristan', 'John, Terry', 'Panthaki, Ray', 'Palmer, Alex', 'Stokes, Al (II)', 'Ewans, Nick', 'McGarrity, Kim', 'Simpson, Joelle', 'De Stoppani, Bindu', 'Burns, Megan', 'Hitching, Emma', 'Harris, Naomie']
# 3 Men and a Little Lady (1990) ['Hunt, Neil', 'Pringle, Bryan', 'Richards, Charles David', 'Guttenberg, Steve', 'Boswall, John', 'Wong, Everett', 'Redford, Ian', 'Danson, Ted', 'Lynn, Jonathan', 'Selleck, Tom', 'Cazenove, Christopher', 'Vaughn, Steven L.', 'Allen, Rosalind (I)', 'Shaw, Fiona', 'Hancock, Sheila', 'Hurley, Melissa (I)', 'Fields, Edith (I)', 'Travis, Nancy', 'Walsh, Sydney', 'Gaul, Patricia', 'Weisman, Robin', 'Neal, Lucia', 'Moore, Edwina', 'Pulliam, Darcy', 'Marta, Lynne']
# 3 Ninjas (1992) ['Slade, Max Elliott', 'Nelson, Race', 'Swetow, Joel', 'McRae, Alan', 'Power, Chad', 'Labyorteaux, Patrick', 'Septien, Al', 'Tanaka, Professor Toru', 'Harder, D.J.', 'Caudill, Scott', 'Jackson, Baha', 'Kingsley, Rand', 'Powell, Clifton', 'Treanor, Michael', 'Chou, Tasen', 'Wong, Victor (III)', 'Sargeant, Kate', 'Franco, Margarita', 'Burr, Fritzi']
# 3 Ninjas: High Noon at Mega Mountain (1998) ['McRae, Alan', 'Roeske II, James Paul', 'Mahoney, Pat (I)', 'Brewster, Julian', 'Hogan, Hulk', 'Yerbey, Roy', 'Fiorino, Anthony', 'Ackler, Joseph', 'Wiles, Rick', 'Himber, Robert', 'Anderson, Ed (V)', 'Wong, Victor (III)', 'Carrington, Dwayne', 'Punito, Pete (I)', 'Dente, Eric C.', 'Smith, Ryan Gardner', 'Adamson, Patrick', 'Price, Craig (V)', "O'Laskey II, Michael", 'Williams, Carl L.', 'Berkfeldt, Denis', 'Hogue, Kenneth', 'McKenna, Travis', "O'Brien, Brendan (II)", 'Zondler, Andrea', 'Shugart, Craig', 'Vecqueray, Michael', 'Shadwell, Dan', 'Jackson, Duke', 'Krebs, Jeff', 'Hudson, Charles', 'Anglin, Brian', 'Galleoos, Lawrence E.', 'Swanson, Mark (II)', 'Backstrom, Greg', 'Newton, Walter', 'Gale, James', 'Baily, Kirk', 'Varney, Jim', 'Dirker, Jim', 'Morse, J. Bryan', 'Dirker, James B.', 'Botuchis, Mathew', 'Woods, Jacqueline', 'Roeske, Emily', 'Merrick, Dawn', 'Johnson, Holly (VII)', 'Anderson, Loni', 'Ryder, Syntrell', 'Franco, Margarita', 'Jasionowski, Mary (I)', 'Nelson, Aimee J.', 'Felton, Lindsay', 'Earlywine, Chelsey', 'Ross, Susan (III)']
# 3000 Miles to Graceland (2001) ['Haines, Ross', 'Owen, Jim (II)', 'McMurray, Lawrence', 'Puccio, Kerry', 'Termath, Steve J.', 'Lichtenstein, Demian', 'Staz', 'Green, Alex (I)', 'Woodbine, Bokeem', 'Misney, Timothy', 'Drummond, Brian', 'Swanson, Scott (I)', 'Casino, John', 'Skylark', 'Bryant, Peter (I)', 'Claggett, Bruce', 'Long, Howie', 'Leboeuf, Jim', 'Kopsa, Michael', 'Turner, Frank C. (I)', 'Slater, Christian', 'Russell, Kurt (I)', 'Lombardi, Louis', 'Arlt, Eric', 'von Watts, Hamilton', 'Garon, Jesse (II)', 'Hoctor, Tim', 'Babych, Dave', 'Brown, R. Nelson', 'Mastrangelo, Alberto', 'Lake, Rod', 'Lake, Rob', 'Ganeev, Raoul', 'Connolly, Steve', 'Sadler, Jody', 'Lane, Campbell', 'Gibbon, Mark (I)', 'Kent, Peter (I)', 'James, Eric (I)', 'Dorsa, Bart', 'Lovitz, Jon', 'Powers, Eddie', 'Margolis, Morgan H.', "O'Faolain, Colm", 'Honeywell, Rice', "D'Ambruoso, Dante", "Grant, 'J.G.' Jim", 'Mundy, Kevin', 'Klush, Shawn Wayne', 'Ice-T', 'Moro, Luis', 'MacKay, Don', 'Martin, Robert (XIII)', 'Carroll, J. Winston (I)', 'Andre, Charles (II)', 'Anderson, Kenneth (I)', "Zajonc, Robert 'Bobby Z'", 'St. John Smith, Michael', 'Arquette, David', 'Jordan, Aubrey', 'Sembach, Jerry', 'March, Craig', 'Alderman, Ralph J.', 'Russo, Gianni (I)', 'Chen, Terry', 'Dunlap, Dave (I)', 'Keller, Duncan', 'Allan, Jay (II)', 'Church, Thomas Haden', 'Pollak, Kevin', 'Harter, Wayne', 'Howard, Shawn Michael', 'Alves, Tony', 'Welch, Tim (I)', 'Holdridge, Larry', 'Busswood, Michael', 'Destry, John B.', 'Kaye, David (II)', 'Goldblatt, Max', 'Heaton, Tom', 'Anka, Paul', 'Costner, Kevin', 'Meeker, David (II)', 'Conti, Michael J.', 'Miller, Greg (II)', 'Abrahams, Doug', 'Acheson, Mark', 'Edwards, Johnny', 'Chatelain, Christine', 'Campbell, Norma', 'Hawthorne, Kimberly', 'McCoy, Angelina', 'Cherrier, Renee', 'Lien, Shelly', 'Harambasic, Melinda', 'Lake, Marci', 'Cox, Courteney', 'Lee, Jeanette', 'Leigh, Sharron', 'Skoll, Mary Ann', 'Swinney, Stephanie', 'Landess, Jill', 'Murray, Daniella', 'Cote, Lorraine', 'Gomez, Terri', 'Preston, Jamie', 'McCrackin, Daisy', 'Lago, Laura', 'Budde, Susse', 'Gagliano, Jennifer Crick', 'Bernasek, Georgie', 'Carlson, Kelly (I)', 'Grace, Yvonne']
# 36 Quai des Orfèvres (2004) ['Auteuil, Daniel', 'Figlarz, Alain', 'Lecluyse, Guy', 'Franek, Ivan', 'Dussollier, André', 'Prestia, Jo', 'Hertel, Cyrille', 'Guerrib, Thierry', 'Duval, Daniel', 'Berthillot, Ludovic', 'Depardieu, Gérard', 'Beuchat, Serge', 'Metzger, Stéphane', 'Hoehn, Robert (I)', 'Rouzaud, Christophe', 'Moscato, Vincent', 'Orsolani, Stéphane', 'Renaud, Francis', 'Maranber, Frédéric', 'Odone, Martial', 'Bihoreau, Jean-Louis', 'Geffroy, Christian', 'Chaubet, Philippe', 'Médioni, Patrick', 'Marchal, Olivier', 'Defosse, Eric', 'Zem, Roschdy', 'Bowen, Vincent', 'Sabah, Mickaël', 'Olmédo, Laurent', 'Sylvain, Denis', 'Biasch, Solène', "D'Annunzio, Anna", 'Golino, Valeria', 'Coubard, Stéphanie', 'Marchal, Catherine', 'Chansou, Christine', 'Demongeot, Mylène', 'Jampanoï, Mylène', 'Auteuil, Aurore', 'Consigny, Anne']
# 37°2 le matin (1986) ['Julien, André', 'Bellanti, Louis', 'Lindon, Vincent', 'Robin, Bernard', 'Bisson, Jean-Pierre', 'La Brosse, Simon de', 'Verbiest, Stéphane', 'Billerey, Raoul', 'Laudenbach, Philippe', 'Confortès, Claude', 'Berthier, Eugène', 'Bonnet, Franck-Olivier', 'Pinon, Dominique', 'Loucif, Rabah', 'Julien, Raymond', 'Anglade, Jean-Hugues', 'Mathou, Jacques', 'Hug, Bernard', 'Duneton, Claude', 'Béhar, Fabien', 'Galibert, Jacky', 'Jalowyj, Nicolas', 'Darmon, Gérard', 'Caratini, Frédéric', 'Besnehard, Dominique (I)', 'Aufaure, Claude', 'Millot, Daniel', 'Berthuit, Leonie', 'Dalle, Béatrice', 'Renn, Laurence', 'Moudiki-Moreau, Marthe', 'Dalyan, Nathalie', "D'At, Catherine", 'De Haviland, Consuelo', 'Célarié, Clémentine', 'Datnowsky, Christine', 'Palas, Bernadette', 'Forde, Jessica']
# 39 Steps, The (1935) ['Tearle, Godfrey', 'Laurie, John (I)', 'Verno, Jerry', 'Hagate, Pat', 'Knight, James (I)', 'Barnard, Ivor', 'Warmington, S.J.', 'Brambell, Wilfrid', 'Turnbull, John (I)', 'Malleson, Miles', 'Piper, Frederick', 'Hitchcock, Alfred (I)', 'Cellier, Frank', 'McPhearson, Quentin', 'Watson, Wylie', 'McNaughton, Gus', 'Donat, Robert', 'Ashcroft, Peggy', 'Inglis, Elizabeth', 'Trevelyan, Hilda', 'Mannheim, Lucie', 'Simpson, Peggy (I)', 'Carroll, Madeleine', 'Haye, Helen']
# 40 Days and 40 Nights (2002) ['Gauthier, Chris', 'Fitzgerald, Glenn', 'Trainor, Aaron', 'Costanzo, Paulo', 'Chen, Terry', 'Anderson, Stanley', 'Grundy, Rueben', 'Trese, Adam', 'Maronna, Michael C.', 'Newman, Barry (I)', 'Paul, Jarrad', 'Low, Jason', 'Draven, Alan', 'Hartnett, Josh', 'Neal, Dylan', 'Lennox, Kai', 'Dunne, Griffin', 'Malthe, Natassia', 'Chatelain, Christine', 'Zanni, Chiara', 'von Pfetten, Stefanie', 'Gross, Mary', 'Gyllenhaal, Maggie', 'Welles, Amanda', 'Shaw, Vinessa', 'Sossamon, Shannyn', 'Harrison, Michelle (II)', 'DeVettori, Gina', 'Patterson, Deenah', 'Mazur, Monet', 'Ruiz, Angie', 'Wilder, Nicole (II)', 'Vaugier, Emmanuelle', 'Tracy, Keegan Connor', 'Bain, Susan', 'Kyser, Tracy', 'Heath, Lorin', 'Alexandria, Theresa']
# 40 Year Old Virgin, The (2005) ['Marasco, Ron', 'Jazzmun', 'Masterson, Jordy', 'Hartsock, Charlie', 'Rudd, Paul (I)', 'Wainwright III, Loudon', 'McKane, Matthew', 'Killham, Brandon', 'Nunez, Joe (I)', 'Malco, Romany', 'Bierman, Michael', 'Hill, Jonah', 'Carell, Steve', 'Foster, Julian', 'Malil, Shelley', 'Hart, Kevin (I)', 'Lashaway, Nick', 'Kahn, Jeff (I)', 'Bannos, Steve', 'Rogen, Seth', 'Yarbrough, Cedric', 'Weaver, Lee (II)', 'Wood, Christopher T.', 'Bednob, Gerry', 'Koechner, David', 'Berman, Loren (II)', 'Mastrolia, Joseph T.', 'Smith, Wyatt (II)', 'Federman, Wayne (I)', 'Kaling, Mindy', 'Goines, Siena', 'Banks, Elizabeth (II)', 'Lynch, Jane', 'Mia, Miki', 'Dennings, Kat', 'Fischer, Jenna', 'Drake, Penny', 'Abdoo, Rose', 'Dominczyk, Marika', 'Johnson, Nicole Randall', 'Collins, Mo (I)', 'Luyben, Kate', 'Brown, Brianna', 'Page, Kimberly', 'Mann, Leslie', 'Mann, Jamie Elle', 'Lemelin, Stephanie', 'Carey, Elizabeth', 'Smith, Chelsea (II)', 'Smith, Phyllis', 'Gallo, Carla', 'Skye, Brittany', 'Guterman, Marisa', 'Phillips, Erica Vittina', 'Jones, Gloria Helena', 'Stormy (III)', 'Vigman, Gillian', 'Keener, Catherine', 'Walls, Nancy', 'DeCicco, Elizabeth', 'Bottrell, Laura', 'Hamlin, Brooke', 'Bradley, Shannon (I)', 'Turnage, Kira', 'Swatek, Barret', 'Freund, Mandy', 'Shepard, Hilary', 'Nakamura, Suzy', 'Dodds Frank, Marilyn', 'Shimosawa, Miyoko', 'Meyerson, Denise']
# 42nd Street (1933) ['Stone, George E. (I)', 'Walthall, Henry B.', 'Irving, George (I)', 'Kibbee, Guy', 'Warren, Harry (I)', 'Village Barn Hill Billies, The', 'Clark, Wallis', 'Kibbee, Milton', 'Sparks, Ned (I)', 'Sizzlers, The', 'Akst, Harry', 'Kennedy, Tom (I)', 'McWade, Robert (I)', 'Baxter, Warner', 'Nordstrom, Clarence', 'Talbot, Lyle', 'Powell, Dick (I)', 'Jenkins, Allen', "O'Brien, Dave (I)", 'Nugent, Edward J.', 'Seymour, Harry', 'Sedan, Rolfe', 'Dubin, Al', 'La Rue, Jack', 'Brent, George (I)', 'Lane, Charles (I)', 'Maynard, Kermit', 'Francis, Dixie', 'Hovey, Ann', 'Lacy, Adele', 'Layson, Lorena', 'White, Dorothy (I)', 'Wellman, Dorothy Coonan', 'Evans, Renee', 'Halsey, Mary', 'Daniels, Bebe', 'Keeler, Gertrude', 'Rogers, Barbara (I)', 'Roberts, Donna Mae', 'Barclay, Joan', 'Jans, Alice', 'Keeler, Helen', 'Cantway, Maxine', 'Joice, Evelyn', 'Ray, Agnes', 'Browning, Lynn', 'Merkel, Una', 'Rogers, Ginger', 'Wing, Pat', 'Wing, Toby', 'Eddings, Ruth', 'Ellis, Patricia (I)', 'Dabney, Virginia', 'Whitney, Renee', 'Shadduck, Jayne', 'Marcy, Eve', 'Callaghan, Edna', 'Andrews, Loretta', 'La Marr, Margaret', 'Glory, June', 'Farnum, Patsy', 'Beavers, Louise', 'Keeler, Ruby', 'Tobin, Grace']
# 48 Hrs. (1982) ['Johnston, John Dennis', 'Dowd, Ned', 'Keane, James (I)', 'Pettinger, Gary', 'Catlett, Loyd', 'Contreras, Luis (I)', 'Remar, James', 'Landers, Matt', 'Thibeau, Jack', 'Nolte, Nick', 'Dimitri, Nick', 'Sánchez, Marcelino', 'Fisher, B.G.', 'Landham, Sonny', 'Zacha, W.T.', 'Murphy, Eddie (I)', 'James, Brion (I)', 'Scott, Walter (I)', 'St. Elwood, Jon', 'Cruickshanks, Reid', 'Dobbins, Bennie E.', 'Haynie, Jim', 'Dearth, Bill', 'Allen, Todd (I)', "O'Neal, Kevin (II)", 'Cross, Bill (IV)', 'Call, R.D.', 'McRae, Frank', 'Loundermon, Gus', 'Huston, J. Wesley', 'Turner, Bjaye', 'Moordigian, Dave', "O'Neal, Brian (I)", 'Yanez, Bob', 'Smith, Clint (I)', 'Mulkey, Chris', 'Hauk, John', 'Walker, Rock A.', 'Lightsy, Jack', 'Kelly, David Patrick', 'Banks, Jonathan', 'Jason, Peter', 'Wallace, Marquerita', 'Regard, Suzanne M.', 'Robinson, Angela (I)', 'Martin, Sandy (I)', 'Plaza, Begoña', 'Brown, Olivia (I)', 'Crosby, Denise', 'Ray, Ola', 'Rose, Margot', 'Gifford, Gloria (I)', 'Venus, Brenda', 'Nono, Clare', 'Blackburn, Greta', "O'Toole, Annette", 'King, Tara (I)', 'Sherman, Kerry']
# 50 First Dates (2004) ['Magwili, Dom', 'Chung, Esmond', 'Nakashima, Joe', 'Clark, Blake', 'Astin, Sean', 'Loughran, Jonathan', 'Chen, Peter (IV)', 'Covert, Allen', 'Federman, Wayne (I)', 'James, Kevin (III)', 'Abesamis, Americus', 'Shulak, John Patrick', 'Fujimori, Darin', 'Puluti Sr., Aukuso Gus', 'Dante, Peter', "Brown, Pomaika'i", "Olmos, Keali'i", 'Osborn, Michael K.', 'Donaruma, J.D.', 'Aykroyd, Dan', 'Sandler, Adam (I)', 'Suapaia, David', 'Avenido, Kent', 'Chi, Albert', 'Yan, Lin', 'Uesugi, Tache', 'Pinkosh, Mark', 'Guiterrez, Christian', 'Keaulana, Brian L.', 'Patricio, Anthony', 'Lee, James (IV)', 'Chin, Glen', 'Schneider, Rob', 'Christopher, Chantell D.', 'Omi, Sharon', 'Rose, Nectar', 'Lee, Michelle (III)', 'Soerjoko, Meilinda', 'Cazin, Marguerite', 'Moore, Kylie', 'Pyle, Missi', 'Sandler, Jackie (I)', 'Williams, Shenika', 'Hersh, Nicola', 'Strus, Lusia', 'Morris, Julianne', 'Uhvana, Ishtar', 'Collins, Lynn', 'Hill, Amy', 'Bauer, Kristin', 'Bowman, Jessica', 'Vivian, Brenda', 'Lawner, Melissa', 'Winnick, Katheryn', 'Barrymore, Drew (I)', 'Bee, Denise', 'Rudolph, Maya', 'Reece, Virginia', 'Segal, Linda', 'Stedman, Anne']
# 51st State, The (2001) ['Jackson, Samuel L.', 'Tomlinson, Ricky', 'Muslim, Sonny', 'McDonald, Mac (I)', 'Ifans, Rhys', 'Roach, James (V)', 'Anwar, Marc', 'Starke, Michael', 'Fyfe, Robert', 'Pavlou, Stel', 'Carlyle, Robert (I)', 'Hunter, Christopher (III)', 'Reynolds, Michael J.', 'Swartz, Aaron (I)', 'Meat Loaf', 'Barber, Paul (I)', 'Inocian, Junix', 'Jezek, Robert (I)', 'Broughton, Paul (I)', 'Walters, Stephen (I)', 'Webber, David (I)', 'Routledge, Matt', 'Pertwee, Sean', 'Whitmey, Nigel', 'Murray, Paul T. (I)', 'MacInnes, Angus', 'Abraham, Jake (II)', 'Bartlett, Nick', 'Ade', 'Grøtta Grav, Gaute', "O'Neill, Terry (I)", 'Barnes, Barbara (II)', 'Mortimer, Emily', 'Keaveney, Anna', 'Campion, Joan']
# 54 (1998) ['Fiorucci, Elio', 'Jeremy, Ron', 'Sutherland, Victor (II)', 'Devon, Tony', 'Bosco, Mario', 'Van Der Wal, Michel', 'Ruffalo, Mark', 'Lapaine, Daniel', 'Miller, George F.', 'Johnson, John (IV)', 'Friedman, Bruce Jay', 'Mark, Emmanuel', 'York, Michael (I)', 'Blacker, David', 'Fruitman, Jason', 'Miguel, Bruno', 'Binkley, James', 'Nascarella, Arthur J.', 'Baldwin, Heath Jacob', 'Trump, Donald', 'Sullivan, Sean Gregory', 'Reynolds, Anthony', 'Browne, Victor', 'Krystyan, Vieslav', 'Ingram, Chris (II)', 'Mathison, Cameron', 'Jenkins, Noam', 'Sudduth, Kohl', 'Sudduth, Skipp', 'MacVittie, Bruce', 'Garfunkel, Art', 'Myers, Mike (I)', 'Boccaletti, Andrea', 'Negin, Louis', 'Nuke, Steve', 'Bogdanovich, Peter', 'Phillippe, Ryan', 'Mundi, Coati', 'Taylor, Patrick (II)', 'Freeman, Morgan (II)', 'Bauer, Robert (III)', 'Henderson, Michael T.', 'Tensen, Justin', 'Goede, Jay', 'Grote, Andy', 'Hines, John (II)', 'Andrews, Jason (I)', 'Pitt, Michael (II)', 'Paige, Jordan', 'Carrier, Don', 'Lombardozzi, Domenick', 'Thorens, Drake', 'Meyer, Breckin', 'Enríquez, Jocelyn', 'Holt, Niki', 'Hayek, Salma', 'Crow, Sheryl', 'Rose, Crystal', 'Lilly, Kabriel', 'Giornofelice, Lina', 'Grenville, Georgina', 'Robinson, Aemilia', 'Johnson, Beverly (III)', 'Hutton, Lauren', 'Houston, Thelma', 'Amber (IV)', 'Lewis, Brooke (I)', 'Stringfield, Sherry', 'Kess, Georgina', 'Webb, Veronica', 'Risi, Michelle', 'Naté, Ultra', 'Vajakas, Lena', 'Longley, Janine', 'Miller, Ilana', 'Van Der Wal, Frederique', 'Griffin, Mary (II)', 'Boyd, Sheila', 'Radecki, Barbara', 'Alexander, Erika', 'Ling', 'Campbell, Neve', 'Albertini Dow, Ellen', 'Klum, Heidi', 'Matarazzo, Heather', 'Luft, Lorna', 'Bagley, Lorri', 'Rousseau, Sophie (I)', 'Perrine, Valerie', 'Crawford, Cindy (I)', 'Catalano, Laura', 'Torgersen, Tone', 'Thomsen, Cecilie', 'Ward, Sela']
# 5x2 (2004) ['Chollet, Pierre', 'Brissart, Jean-Pol', 'Ruchmann, Marc', 'Tavassoli, Jason', 'Lonsdale, Michael (I)', 'Cesolari, Andrea', 'Freiss, Stéphane', 'Belkacem, Yannis', 'Angloni, Carlo-Antonio', 'Neisser, Jean', 'Sannino, Domenico', 'Chappey, Antoine', 'Fabian, Françoise', 'Pailhas, Géraldine', 'Kherris, Eliane', 'Bruni Tedeschi, Valeria', 'Brétécher, Ninon', 'Debrun, Sylvie', 'Fouquet, Marie-Madeleine']
# ...
# Adventures of Ford Fairlane, The (1990) ['Loder, Kurt', 'Seymour, Douglas', 'Lawrence, Lee (I)', 'Neil, Vince', 'Menzano, John', 'Crenshaw, Randy', 'West, Hot Tub Johnny', 'Loc, Tone', 'Kahn, Michael Alan', 'Fountain, Thom', 'Mangiardi, Robert', "D'Lorenzo, Edward", 'Wasserman, Allan', 'Dale, James (II)', 'Vance, Ladd', 'Escovedo, Juan Jose', 'Zavala, Jimmy', 'Knowlden, Kirk', 'Jarrett, Cody (I)', 'Gottfried, Gilbert', 'McLaurin, David (I)', 'Hammond, John (IV)', 'Kelly, Dana', 'Reilly, J.D.', 'Clay, Andrew Dice', 'Escovedo, Peter Michael', 'Lund, Jordan', "Smith, William 'Smitty'", 'Harlin, Renny', 'Newton, Wayne', 'Kelly, David Patrick', 'Bowe, David', 'Day, Morris', 'Cavazo, Carlos', 'Hawke, Charlie', 'Zuelke, Mark', 'Childers, Christopher D.', 'Thornberg, Lee', 'Marotta, Rick', 'Arnott, David (I)', 'Zendejas, Rene', 'Call, Brandon', 'Goldstein, Mark (I)', 'Englund, Robert', 'Kaner, Jaz', 'Christopher, Paul', 'Soussan, Phil', "O'Neill, Ed (I)", 'Castillo, Randy', 'Villa, Edmund E.', 'Stefka, Kurt James', 'White, Steve (I)', 'Shockley, William (I)', 'Garson, Willie', 'Matthews, Shanelle', 'Barrows, Diana', 'Corman, Maddie', 'Presley, Priscilla', 'Sloatman, Lala', 'Lala (II)', 'Pond, Pamela', 'Holly, Lauren', 'Park, Hili', 'Escovedo, Zina', 'E., Sheila', 'Sheppard, Delia', 'Bland, Rita', 'Adlon, Pamela', 'Monica, Kathleen', 'Mannen, Monique', 'Sissons, Kimber', 'Almeida, Diane', 'Johnson, Connie (I)', 'Pfeiffer, Lori', 'Mahoney, Leeann', 'Park, Gry', 'Sheeler, Sandra', 'Nance, Consuela', 'Allain, Aurorah', 'Pearcey, Kristin', 'Wuhrer, Kari', 'Kärkkäinen, Kata', 'Lehre, Cindy', 'Boyer, Boni']
# Adventures of Pluto Nash, The (2002) ['Rudder, Michael (I)', 'Reid, Roger E.', 'Sol, Alex', 'Pantoliano, Joe', 'Donnelly, Brent', 'Corday, Bill', 'Rebhorn, James', 'Baldwin, Alec', 'Jordan, Don (I)', 'Mohr, Jay', 'Houde, Serge (I)', 'Varnado, Victor', 'Franklyn, Ezra', 'Guzmán, Luis (I)', 'Hoziel, Eric', 'Boyle, Peter (I)', 'Yuen, Russell', 'Brancato, Lillo', 'Long, Marlon Sterling', 'Spinuzza, Doug', 'Camacho, Mark', 'Stark, Jonathan (II)', 'Wright, Brian D.', 'Bregman, Christopher', 'Topor, John', 'Mayer, Marcus', 'Haig, Terry', 'Núñez Jr., Miguel A.', 'LaFortune, Roc', 'Kimmel, Josh', "Riley, Stu 'Large'", 'Murphy, Eddie (I)', 'Goar, Johnny', 'Kerton, Patrick', 'Bisping, Alexander', 'Young, Burt', 'Quaid, Randy', 'Fournier, Michel (II)', 'Cleese, John', 'Simons, Lorca', 'Douglas, Illeana', 'Perzow, Angela', 'Krämer, Heidi', 'Smith, Linda (VII)', 'Wasilewski, Audrey', 'Underwood, Lana', 'Sharpe, Cornelia', 'Bellange, Tetchena', 'René, Jacynthe', 'Hammett, Mary', 'White, Diane (II)', 'Fafard, Andrée', 'Dawson, Rosario', 'Grier, Pam', 'Krämer, Alissa']
# Adventures of Priscilla, Queen of the Desert, The (1994) ['Kmet, Joseph', 'Davies, Murray (I)', 'Kellie, Daniel', 'Holmes, Mark (II)', 'Boyce, Bob', 'Pearce, Guy (I)', 'Barrie, Trevor', 'Chappel, Tim', 'Clark, Al (II)', 'Radley, Ken', 'Elliott, Stephan', 'Cornelius, Frank', 'Weaving, Hugo', 'Casey, John (II)', 'Stamp, Terence', 'Hunter, Bill (I)', 'Picken, Leighton', 'Stead, Christian', 'Dargin, Alan', 'Bennett, June Marie', 'Kmet, Maria', 'Gardiner, Lizzy', 'Russell, Rebel', 'Corbett, Hannah', 'Pomeranz, Margaret', 'Chadwick, Sarah', 'Webster, Nikki', 'Cortez, Julia']
# Adventures of Robin Hood, The (1938) ['Rathbone, Basil', 'Stanton, Val', 'De Ruiz, Nick', 'Belmore, Lionel', 'Simpson, Ivan F.', 'Flynn, Errol (I)', 'Rich, Dick', 'Benge, Wilson', 'Hytten, Olaf', 'Hunter, Kenneth (I)', 'Deery, Jack', 'St. Angelo, Robert', 'Hodgson, Leyland', 'Adams, Lowden', "Corrigan, D'Arcy", 'North, Joseph', 'Richardson, Jack (I)', 'Mundin, Herbert', 'Hobbes, Peter', 'Trigger (I)', 'Hill, Howard (I)', 'Kenny, Colin', 'Hale, Alan (I)', 'Bunny, George', 'Harford, Alec', 'Lamont, Marten', 'Love, Montagu', 'Irwin, Charles (I)', 'Baron, Sidney', 'Stanton, Ernie', 'Cooper, Melville', 'Baker, Frank (I)', 'Herbert, Holmes', 'Evans, Herbert', 'Mills, Thomas R.', 'Baker, James (IV)', 'Pallette, Eugene', 'Hunter, Ian (I)', 'Cavendish, David (I)', 'Dew, Eddie', 'Mudie, Leonard', 'Warwick, Robert (I)', 'Willey, Leonard', 'Thursby, David', 'Knowles, Patric', 'Matthews, Lester', 'Baylor, Hal', 'Howard, Harold (II)', 'Power, Paul (I)', 'Brazeale, Hal', 'Bennett, Charles (II)', 'Entwistle, Harold', 'Sheffield, Reginald', 'Noble, Robert (II)', 'Rogers, Gerald (I)', 'Kent, Crauford', 'Thornton, Cyril', 'Rains, Claude', 'Hordern, Michael', 'Wisberg, Claude', 'Fairman, Austin', 'McNaughton, Charles', 'Henderson, Ivo', 'Stevenson, Bob (I)', 'Hagney, Frank', 'Cording, Harry', 'Sutton, John (I)', 'Coghlan, Phyllis', "O'Connor, Una", 'Leon, Connie', 'de Havilland, Olivia', 'Shaw, Janet (I)']
# Adventures of Rocky & Bullwinkle, The (2000) ['Pike, Gary', 'Biermann, Rod', 'Jones, Doug (I)', 'Woltz, Randy (I)', 'Bachar, Dian', 'Proctor, Phil', 'Ross, Jeffrey (I)', 'Donner, Jack', 'Thompson, Kenan', 'Gibbs, Nigel', 'Young, Harrison', 'Rebhorn, James', 'Mitchell, Kel', 'Bundy, Robert', 'Holton, Mark (I)', 'Rankin, Steve', 'Grodénchik, Max', 'Crystal, Billy', 'Mann, Wesley', 'Lowe Jr., Arvie', 'Alper, Eugene', 'Williams, Ellis', 'Beardsley, Michael', 'Alexander, Jason (I)', 'Goodman, John (I)', 'Maxwell, Jeremy', 'Campion, John', 'Gale, Ed', 'Miller, Adam (II)', 'Chinery, Chip', 'Scott, Keith (I)', 'Foxx, Corey', 'Finney, Brian (I)', 'Polito, Jon', 'Quaid, Randy', 'Grier, David Alan', 'Keller, Chad', 'De Niro, Robert', 'Novello, Don', 'Doud, Jared', 'Raider-Wexler, Victor', 'Lloyd, Norman (I)', 'Edwards, Elwood', 'Reiner, Carl', 'Thyne, T.J.', 'Slone, Victor M.', 'Kain, Rick', 'Caruso, Phillip V.', 'Winters, Jonathan (I)', 'Brandon, John (I)', 'Brisbin, David (I)', 'Brillhart, Patric', 'Kakebeen, Jason', 'Austin, Jennifer (IV)', 'De Niro, Drena', 'Garofalo, Janeane', 'Brookshire, Amanda', 'Henson, Taraji P.', 'Couch, Teresa', 'Nicksay, Lily', 'Perabo, Piper', 'Brewster, Paget', 'Goldberg, Whoopi', 'Berman, Susan (I)', 'Russo, Rene', 'Billingham, Dar', 'McKee, Danielle', 'Wilson, Jane Edith', 'Sells, Kelly', 'Foray, June', 'Lowman, Kristen', 'McAnuff, Julia', 'Niles, Myrna', 'Thorpe, Alexis']
# Adventures of Sharkboy and Lavagirl 3-D, The (2005) ['Davich, Jacob', 'Rodriguez, Rocket', 'Scott, Spencer (I)', 'Lautner, Taylor', 'Arquette, David', 'Lopez, George (I)', 'Boyd, Cayden', 'Musso, Marc', 'Torres, Rico', 'Rodriguez, Rebel', 'Rodriguez, Racer', 'Graham, Shane', 'Haddad, Tania', 'Fitzgerald, Mackenzie', 'Chung, Chloe Gunther', 'Davis, Kristin (I)', 'Darrow, Tiger', 'Dooley, Taylor', 'Hayslip, Peyton', 'McCray, Joanna', 'Pieterse, Sasha']
# Affair to Remember, An (1957) ['Bolognese, Dino', 'Lally, Mike (I)', 'Kelman, Terry Ross', 'Denning, Richard (I)', 'Moore, Matt (I)', 'Pietro, Don', 'Stevens, Bert (I)', 'Bonanova, Fortunio', 'Mercier, Louis (I)', 'Mazzola, Anthony (I)', 'Allen, Richard (V)', 'Lomas, Jack', 'Nolan, Tom (I)', 'Snegoff, Marc', 'Corcoran, Brian', 'Morin, Alberto (I)', 'Snow, Marc', 'Morrow, Scotty', 'Watts, Charles (I)', 'Raine, Jack', 'De Mario, Tony', 'King, Walter Woolf', 'Lynn, Robert (I)', 'Champion III, Norman', 'Egan, Michka', 'Grant, Cary', 'Kane, Ken', 'Lewis, Robert Q.', 'Bain, Al', 'Bernard, Butch', 'Scott, Danny', 'Bradley, Paul (I)', 'Til, Roger', 'Winslow, George', 'Garcia, Priscilla', 'Ellis, Juney', 'Ellers, Suzanne', 'Patterson, Neva', 'Kerr, Deborah', 'Fax, Jesslyn', 'Nesbitt, Cathleen', 'Nixon, Marni', 'Powell, Patricia (I)', 'Wall, Geraldine', 'Durfee, Minta', 'Selby, Sarah', 'Carroll, Mary (I)', 'Murray, Alena', 'Aumont, Geneviève', 'Charney, Kathleen', 'Mayon, Helen', 'Emerson, Theresa', 'Adams, Dorothy', 'Marlowe, Nora (I)', 'Mathews, Nita', 'Thompson, Tina']
# Affliction (1997) ['Osborne, Holmes', 'Jeannin, Marcel', 'Post, Tim', 'Reiter, Donovan', 'Nolte, Nick', 'True-Frost, Jim', 'Coburn, James', 'Dafoe, Willem', 'Powell, Charles Edwin', 'Robson, Wayne', 'Lipinski, Eugene', 'Nolte, Brawley', 'Caloz, Michael (I)', 'Camacho, Mark', 'McCann, Sean (I)', 'Heyerdahl, Christopher', 'Stewart, Paul (II)', 'Allison, Ralph', 'Adams, Steve (I)', 'Kleinhans, Martha-Marie', 'Désormeaux, Danielle', 'Spacek, Sissy', 'Noyes, Joanna', 'Almgren, Susan', 'Tierney, Brigid', 'Seldes, Marian', 'Mancuso, Penny', 'Theriault, Janine', 'Larkin, Sheena', 'Hurt, Mary Beth']
# African Queen, The (1951) ['John, Errol', 'Bull, Peter (I)', 'Gotell, Walter', 'Morley, Robert (I)', 'Marner, Richard', 'Bogart, Humphrey', 'Bikel, Theodore', 'von Kotze, John', 'Swanwick, Peter', 'Onn, Gerald', 'Hepburn, Katharine']
# After Hours (1985) ['Evans, Clarke', 'Marin, Cheech', 'Redglare, Rockets', 'Block, Larry (I)', 'Elverman, Bill (I)', 'Heard, John', 'Baker, Henry Judd', 'Dunne, Griffin', 'Codiglia, John P.', 'Sisto, Rocco', 'Catalano, Maree', 'Miller, Dick (I)', 'Pinchot, Bronson', 'Aquilino, Frank', 'Carr, Rand', 'Moston, Murray', 'Scorsese, Martin', 'Scorsese, Charles', 'Bumbalo, Victor', 'Felder, Clarence', 'Jason, Joel', 'Lim, Stephen', 'Patton, Will (I)', 'Argo, Victor', 'Chong, Tommy', 'Magnotta, Victor', 'Plunket, Robert', 'Arquette, Rosanna', "O'Hara, Catherine (I)", 'Fiorentino, Linda', 'Bloom, Verna', 'Raflo, Paula', 'Johnson, Robin (I)', 'Winkler, Margo', 'Garr, Teri']
# After the Sunset (2004) ['Bruynbroek, Frank', 'Payton, Gary', 'Day, Jared', 'Ledard, Tony', 'Reynolds, Anthony', "O'Neal, Shaquille", 'Bowen, Michael (I)', 'Harrelson, Woody', 'Dale, Alan (I)', 'Moses, Mark', 'Curtis-Brown, Robert', 'Garlin, Jeff', 'Babatundé, Obba', 'Korda, Paul', 'Donahue, Jon', 'Penn, Chris (I)', 'Garity, Troy', 'Woller, Kirk B.R.', 'Detwiler, Ted', 'Marayati, Kamal', 'Foley, Tom Sean', 'Fiscella, Andrew', 'Jackson, Phil (II)', 'Norton, Edward (I)', 'Miller, Donald (IV)', 'Linn, Rex', 'Sweitzer, Keith', 'Benedict, Paul', 'Reivers, David', "O'Neal McKnight, Rodney", 'Hornsby, Russell', 'Gabriel, Chad', 'Russo, Gianni (I)', 'McGowan, Tom (II)', 'McKinnon Miller, Joel', 'Cheadle, Don', 'Williamson, Mykelti', 'Brosnan, Pierce', 'Malone, Karl', 'Higgins, John Michael', 'Ledard, Shakara', 'Lenoir, Noémie', 'Cannon, Dyan', 'Onweagba, Oluchi', 'Harris, Rachael (I)', 'Omahyra', 'Conlon, Nicola', 'Tomlinson, LeShay N.', 'Hayek, Salma', 'Walsh, Kate (I)', 'Quock, Audrey', 'Harris, Naomie', 'Vigman, Gillian', 'Thornhill, Lisa']
# Against All Odds (1984) ['Kelly, Tom (V)', 'Karras, Alex', 'Corley, Pat', 'Scott-Thomas, Mel', 'Bower, Stone', 'St. Elwood, Jon', 'Harewood, Dorian', 'Scarber, Sam', 'Creole, Kid (I)', 'McKinney, Bill', 'Bridges, Jeff (I)', 'Widmark, Richard', 'Woods, James (I)', 'Dayan, David (I)', 'Terry, Jonathan', 'Valentine, Paul (I)', 'Rubinek, Saul', 'Williams, Allen (I)', 'White, Ted (I)', 'Mundi, Coati', 'Ward, Rachel (I)', 'LaBrie, Ginger', 'Greer, Jane', 'Kurtz, Swoosie', 'Poirier, Cheryl', 'Stafford, Tamara', 'Kaegi, Adriana', 'McCarthy, Barnetta', 'Hagey, Taryn']
# Against the Ropes (2004) ['Lennox, Doug', 'Van Zanten, Martin', 'Marcus, Egerton', 'Danby, Noah', 'Fresolone, Arturo', 'Kittles, Tory', 'DeLeon, Edwin (II)', 'Mondesir, Merwin', 'Vanderpool, Syd', 'Carr, Keith', 'McCallany, Holt', 'Pinnock, Arnold', 'Marsh, Ray (I)', 'Amos, Michael (II)', 'Carty, Everol', 'Scott, Julian (III)', 'Epps, Omar', 'Durand, Jared', 'Hernández, Juan Carlos (I)', 'Johnston, Rogue', 'Green, Howard (V)', 'Teodorescu, Adrian (I)', 'Lawrence, Shawn', 'Pajkic, Neven', 'Keens-Douglas, Chad', 'Varela Jr., Carlos', 'Zolnierczyk, Rocky', 'McEwan, Everton', 'Alachiotis, Nick', 'Mascoll, Alwin', 'Daly, Timothy (I)', 'Boucher, Donovan', 'Tucci, Angelo', 'Jade, Denver', 'Wayne, Big Daddy', 'Wylie, Peter (I)', 'Mota, Paul', 'Ferri, Anthony', 'Perez, Hector (II)', 'Fuentes, Diego', 'Richardson, Joseph (I)', 'Terry, John Christopher', 'Bujalski, Derek', 'Dunbar, Dave (II)', 'Nyarko, Moses', 'Gooch, Bruce', 'Harris, Joel (II)', 'Daigle, Jean', 'Lupish, Marc', 'Shalhoub, Tony', 'Devine, Aidan', 'Dutton, Charles S.', 'Ironi, Jeff', 'Lentz, Danny', 'Mack, Gene', 'Buffer, Michael', 'DiCarlo, Remo', 'Jardine, James (I)', 'Lawrie, Paul (I)', 'Kraft, Mike', 'Bell, Sean (I)', 'Yodkerepauprai, Suchart', 'Crone, Neil', 'McEntire, Timothy', 'McDermott, Dean', 'Kalbhenn, John', 'Dreger, Reg', 'Reynolds, Eric (II)', 'Ezerzer, Patrick', 'Etters, Jef', 'Rhoades, Michael', 'Starr, Beau', 'Cortese, Joseph (I)', 'Tiefenbach, Dov', 'Dion, Michael (II)', 'Jones, Jason (I)', 'Leigh, Gillian', 'Washington, Kerry', 'Tyson, Tami', 'Kallen, Jackie', 'MacKay, Lisa (II)', 'Robinson, Karen (I)', 'Keshock, Adrianne', 'Waterhouse, Tracy', 'Verlyn, Hayley', 'Hickey, Tamara', 'McCole Bartusiak, Skye', 'Ryan, Meg (I)']
# Age of Innocence, The (1993) ['Day-Lewis, Daniel', 'McCowen, Alec', 'Davis, Michael Rees', 'Davies, Brian (I)', 'McLoughlin, John (I)', 'Wilson, Stuart (II)', 'Scorsese, Martin', 'Scorsese, Charles', 'Gough, Michael (I)', 'Barbour, Thomas', 'Brydon, W.B.', 'Nilsson, Christopher', 'Cook, Terry (I)', 'Gibson, Thomas (I)', 'Leonard, Robert Sean', 'Erskine, Howard', 'Sanders, Kevin (I)', 'Garrison, Jon', 'Cajano, Pasquale', 'Pryce, Jonathan', 'Lloyd, Norman (I)', 'Fehren, Henry', 'Fowler, Clement', 'Grant, Richard E.', 'Trout, Michael', 'Squibb, June', 'Woodward, Joanne', 'Farina, Carolyn', 'Ellis, Tracey', 'Farkas, Linda Faye', 'Katz, Cindy (I)', 'Bloom, Claire (I)', 'Scorsese, Catherine', 'Pronzati, Cristina', 'Margolyes, Miriam', 'Day-Lewis, Tamasin', 'Chaplin, Geraldine', 'Dunnock, Patricia', 'Phillips, Siân', 'Zoe (I)', 'Ryder, Winona', 'Cameron-Scorsese, Domenica', 'Orange, Mac', 'Pfeiffer, Michelle', 'Hurt, Mary Beth', 'Smith, Alexis (I)']
# Agent Cody Banks (2003) ['Caughlan, Dennis', 'Kelly, Terence', 'Nadon, Branden', 'Solberg, Shayn', 'Peterman, Gary', 'Francis, Andrew (I)', 'Vosloo, Arnold', 'Diakun, Alex', 'McShane, Ian', 'David, Keith (I)', 'Donovan, Martin (II)', 'Kalvari, Saul', 'Ratner, Benjamin', 'Van Snellenberg, Jared', 'Cromien, Michael', 'Zukovic, Dan', 'Olsson, Ty', 'Muniz, Frankie', 'Keenleyside, Eric', 'Boissonnault, Tyler', 'Thompson, Andy (I)', 'Roebuck, Daniel', 'Johnston, Andrew (II)', 'Krowchuk, Chad', 'Quao, Anthony', 'Swanson, Scott (I)', 'Gauthier, Chris', 'Peterson, Alan C.', 'Kalvari, Justin', 'Fisher, Noel (I)', 'Ballard, Jeffrey', 'New, Peter', 'Hammond, Darrell', 'Tseng, Chang (I)', 'Miller, Stephen E.', 'Jackson, Dee Jay', 'Widdows, Connor', 'Prevail', 'Taylor, Bill (XI)', 'Shelton, Marc', 'Angus, Forbes', 'Van Gorkum, Harry', 'Stevenson, Cynthia', 'Worobets, Gail', 'Norbury, Eliza', 'Gale, Lorena', 'Bakker, Sonja', 'Sellers, Natalie', 'Kershaw, Annabel', 'Harmon, Jessica', 'Calder, Lisa (I)', 'Bouey, Hayley', 'Delain, Moneca', 'Purvis, Alexandra', 'Radley, Xantha', 'Smith, Miriam', 'Harmon, Angie', 'Duff, Hilary', 'Hogan, Fiona (I)']
# 4536
# 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       8 print(len(oracle.all_movies()))
#      10 #Testar o average_number_of_X
# ---> 11 print(oracle.average_number_of_X())
#
# Cell In[7], line 66, in HollywoodOracle.average_number_of_X(self)
#      64 total = 0
#      65 for actor in self.all_actors():
# ---> 66     numberX = self.number_of_X(actor)
#      67     if numberX > 0:
#      68         total += self.number_of_X(actor)
#
# Cell In[7], line 38, in HollywoodOracle.number_of_X(self, a)
#      36 path = self.path_to_X(a)
#      37 total = 0
# ---> 38 for i in path:
#      39     if i.get_type() == "actor":  # Conta apenas os vértices do tipo ator
#      40         total += 1
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# ## 3) Testes

# %% [markdown]
# ##### 3.1) [1 valor] Usando a base de dados large_dataset.txt, implemente um script/função que utiliza a API HollywoodOracle e apresenta um histograma do número de atores com o mesmo “número de Bacon” (paratodos os “números de Bacon” diferentes de infinito). Considere como o “centro do universo” o ator “Bacon, Kevin”.
#
# Nota 1: Para além do gráfico, imprima os resultados encontrados, ou seja, imprima o número de atores
# com cada “número Bacon” possível (numa linha diferente).
#
# Nota 2: Imprima também “número de Bacon” médio encontrado (ou seja, o resultado da operação
# average_number_of_X()).

# %% [markdown]
# ##### 3.2) [1 valor] Usando a base de dados large_dataset.txt, implemente um script/função que utiliza a API HollywoodOracle e apresenta um gráfico do “número de X” médio considerando como o “centro do universo” cada um dos 20 atores mais populares de Hollywood nos anos 2000, segundo o IMBD. Ou seja, a função average_number_of_X deve ser executada para cada um dos 20 atores de modo a obter o seu “número médio de X”. A lista de atores mais populares encontra-se no ficheiro top20imbd.csv anexado.
#
# Nota 1: Para além do gráfico, imprima os resultados, ou seja, imprima os valores do “número de X” médio de cada um dos 20 atores (numa linha diferente).
#
# Nota 2: Se, por qualquer razão, não for possível executar este teste na base de dados large_dataset.txt, deve justificar a razão do problema e, em alternativa, executar o teste utilizando
# o ficheiro small_dataset.txt. Só serão aceites justificações sustentadas por factos (por exemplo, capturas de ecrã do erro e/ou tempo de execução).

# %% [markdown]
# ##### 3.3) [1 valor] Se a teoria dos seis graus de separação for verdadeira para Hollywood, isso implicaria que a maioria dos atores terá um “número de X” de 6 ou menos, o que significa que o “número de X” médio seria menor do 6. Para testar esta teoria, implemente um script/função que utiliza a API HollywoodOracle com a base de dados small_dataset.txt, e apresenta um gráfico do “número de X” médio considerando como o “centro do universo” 1000 atores selecionados de forma aleatória da base de dados.
#
# Nota: Este teste pode demorar bastante tempo a ser concluído. Por esta razão, sugerimos que escreva os resultados num ficheiro para que seja possível recuperá-los caso a execução seja interrompida.

# %% [markdown]
# ## 4) Questões Éticas

# %% [markdown]
# ##### Tente resolver os problemas apenas com os integrantes do seu grupo antes de colaborar. Escreva as suas respostas por suas próprias palavras. Nunca deve partilhar o ficheiro fonte com as suas soluções com integrantes de outros grupos.

# %% [markdown]
# ##### 4.a) Se colaborou com alguém fora do seu grupo, indique aqui os respetivos nomes.

# %% [markdown]
# ##### 4.b) Deve citar todas as fontes que utilizou fora do material da UC.
